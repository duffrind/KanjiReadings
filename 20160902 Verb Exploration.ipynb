# %%
import pandas as pd
#import numpy as np
#import matplotlib as plt
#%inline

# %%
verbs = pd.read_csv('../data/verb/verbs.csv') # we can change to verb.csv

# %%
verbs.to_csv('../data/verb/verb.csv')

# %%
verbs.tail()
# Out:
#     pronunciation       verb              meaning  type    delete1  \
# 500   kizutsukeru  傷つけるきずつける  wound, damage, harm     2  Conjugate
# 501      tsutsumu      包むつつむ                 wrap     1  Conjugate
# 502        mogiru        NaN               wrench     1  Conjugate
# 503        sujiru        NaN              wriggle     1  Conjugate
# 504          kaku       書くかく                write     1  Conjugate
#
#                delete2
# 500  Example sentences
# 501  Example sentences
# 502  Example sentences
# 503  Example sentences
# 504  Example sentences

# %%
#help(verbs.drop)
verbs.drop(['delete1','delete2'],axis=1,inplace=True)
#verbs.drop('delete2',axis=1,inplace=True)
verbs.head()
# Out:
#   pronunciation     verb                meaning  type
# 0     nonoshiru     ののしる  abuse verbally, curse     1
# 1        takeru      たける          act violently     1
# 2          tasu     足すたす                    add     1
# 3       kuwaeru  加えるくわえる        add to, include     2
# 4      mitomeru  認めるみとめる       admit, recognize     2

# %%
#verb column is incomplete so let's populate a new column of hiragana based off of the romaji pronunciation.
#let's just use some premade library for this...
# Out:
#     pronunciation verb                          meaning  type    delete1  \
# 25         kuneru  NaN                       be crooked     1  Conjugate
# 33       tamagiru  NaN                    be frightened     1  Conjugate
# 44     kutsugaeru  NaN                    be overturned     1  Conjugate
# 51         numeru  NaN                      be slippery     1  Conjugate
# 56          uramu  NaN                    bear a grudge     1  Conjugate
# 60        shikeru  NaN                      become damp     1  Conjugate
# 61         kageru  NaN                      become dark     1  Conjugate
# 66        kishiru  NaN                     become misty     1  Conjugate
# 69          ikiru  NaN                    become sultry     1  Conjugate
# 74       mikubiru  NaN                belittle, despise     1  Conjugate
# 82         tagiru  NaN                     boil, seethe     1  Conjugate
# 86       yabureru  NaN           break, lose, be beaten     2  Conjugate
# ...

# %%
import romkan

# %%
verbs[verbs.verb.isnull()].apply()
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func, axis=0, broadcast=False, raw=False, reduce=None, args=(), **kwds) method of pandas.core.frame.DataFrame instance
#     Applies function along input axis of DataFrame.
#
#     Objects passed to functions are Series objects having index
#     either the DataFrame's index (axis=0) or the columns (axis=1).
#     Return type depends on whether passed function aggregates, or the
#     reduce argument if the DataFrame is empty.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column/row
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         * 0 or 'index': apply function to each column
#         * 1 or 'columns': apply function to each row
#     broadcast : boolean, default False
#         For aggregation functions, return object of same size with values
#         propagated
#     raw : boolean, default False
# ...

# %%
verbs['verb'][verbs.verb.isnull()] = verbs['pronunciation'][verbs.verb.isnull()].apply(lambda x: romkan.to_hiragana(x))
#romkan.to_hiragana()
# Out:
# /Users/duffrind/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
verbs['verb'][verbs.verb.isnull()]
# Out:
# Series([], Name: verb, dtype: object)

# %%
verbs.loc[25]
# Out:
# pronunciation        kuneru
# verb                    くねる
# meaning          be crooked
# type                      1
# Name: 25, dtype: object
