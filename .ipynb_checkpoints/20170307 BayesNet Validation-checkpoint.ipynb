# %%
import re
import pickle
import json
from collections import namedtuple, Counter
import romkan
import csv

# %%
true_dict = pickle.load(open('true.p','rb')) # This is the dictionary that contains all of the regular vocab

# %%
with open('word_dictionary.json', 'r') as f:
    try:
        word_dict = json.load(f)
    except ValueError:
        word_dict = {}

# %%
list(true_dict.keys())[:10]
# Out:
# ['首飾り', '脅迫', '傾', '整える', '口ずさむ', '磁気', '淡水', '模範', '対照', '隣']

# %%
word_dict['振り'].split('\t')
# Out:
# ['ぶり', 'suffix', 'style']

# %%
i = set()

for word, pronunciation in true_dict.items():
    pos = word_dict.get(word, None)
    if pos != None:
        i = i | {pos.split('\t')[1]}
print(i)
# Out:
# {'noun, used as a prefix', 'adverbial noun (fukushitekimeishi)', 'interjection (kandoushi)', 'numeric', "Godan verb with `nu' ending", 'auxiliary verb', "Godan verb with `u' ending", "Godan verb with `mu' ending", 'noun or verb acting prenominally', "`taru' adjective", "Yodan verb with `ku' ending (archaic)", 'noun (temporal) (jisoumeishi)', 'counter', "nouns which may take the genitive case particle `no'", "Godan verb with `ru' ending", "Godan verb with `bu' ending", 'pronoun', 'auxiliary adjective', "Nidan verb (lower class) with `ru' ending (archaic)", 'suru verb - special class', "Godan verb with `tsu' ending", 'noun (common) (futsuumeishi)', 'adjective (keiyoushi)', 'Ichidan verb', 'su verb - precursor to the modern suru', 'noun or participle which takes the aux. verb suru', 'expressions (phrases, clauses, etc.)', 'Godan verb - Iku/Yuku special class', 'adjectival nouns or quasi-adjectives (keiyodoshi)', 'noun, used as a suffix', "Godan verb with `gu' ending", "Godan verb with `su' ending", "adverb taking the `to' particle", 'suru verb - irregular', 'conjunction', 'pre-noun adjectival (rentaishi)', 'Godan verb - -aru special class', 'Ichidan verb - zuru verb (alternative form of -jiru verbs)', "Godan verb with `ru' ending (irregular verb)", "Godan verb with `ku' ending", 'prefix', 'Ichidan verb - kureru special class', 'particle', 'archaic/formal form of na-adjective', 'adverb (fukushi)', 'suffix', "Godan verb with `u' ending (special class)"}

# %%
def descToPOS(description):
    if 'fix' in description:
        description = '-fix'
    elif 'pronoun' in description:
        description = 'pronoun'
    elif 'noun' in description:# or 'suffix' in description or 'prefix' in description:
        description = 'noun'
    elif 'adverb' in description or 'adjective' in description:
        description = 'adjective'
    elif 'verb' in description:
        description = 'verb'
    elif 'interjection' in description:
        description = 'interjection'
    elif 'expression' in description:
        description = 'expression'
    return description

# %%
for line in i:
    line = descToPOS(line)
    #if 'verb' not in line and 'noun' not in line and 'adjective' not in line:
    print(line)
# Out:
# noun
# noun
# interjection
# numeric
# verb
# verb
# verb
# verb
# noun
# adjective
# verb
# noun
# counter
# noun
# verb
# verb
# pronoun
# adjective
# verb
# verb
# verb
# noun
# adjective
# verb
# verb
# noun
# expression
# verb
# noun
# noun
# verb
# verb
# adverb
# verb
# conjunction
# noun
# verb
# verb
# verb
# verb
# prefix
# verb
# particle
# adjective
# adverb
# suffix
# verb

# %%
POSvector = namedtuple('POSvector', ['kanji', 'curPron', 'pos', 'nextPron', 'prevPron', 'curIndex', 'lastChar', 'onKun', 'oneChar', 'allKanji'])

# %%
listOfVectors = list()
for word, pronunciation in true_dict.items():
    pos = word_dict.get(word, None) # can change to 'unknown'
    if pos != None:
        pos = descToPOS(pos.split('\t')[1])
        oneChar = False
        if len(word) == 1:
            oneChar = True
        allKanji = False
        if re.search("""[\u3040-\u30ff]+""", word) == None:
            allKanji = True
        onKun = oneChar or not allKanji
        lastChar = word[-1]
        if re.search("""[\u3040-\u30ff]+""", lastChar) == None:
            lastChar = 'KANJI'
        for i in range(len(word)):
            curPron = pronunciation[i]
            prevPron = 'START'
            if i != 0:
                prevPron = romkan.to_roma(pronunciation[i-1])[-1]
            nextPron = 'END'
            if i < len(pronunciation) - 1:
                nextPron = romkan.to_roma(pronunciation[i+1])[0]
            listOfVectors.append(POSvector(kanji=word[i], curPron=curPron, pos=pos, nextPron=nextPron, \
                                           prevPron=prevPron, curIndex=i, lastChar=lastChar, onKun=onKun, \
                                           oneChar=oneChar, allKanji=allKanji))

# %%
for word, pron in true_dict.items():
    pos = word_dict.get(word, None) # can change to 'unknown'
    if pos != None:
        pos = pos.split('\t')[1]
    else:
        pos = 'unknown'
        #print(word)
    for i in range(len(word)):
        curPron = pron[i]
        if word[i] == '上':
            print('Word: ' + word + ' Pron: ' + curPron + ' POS: ' + pos)
# Out:
# Word: 屋上 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 上下 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 逆上る Pron: のぼ POS: unknown
# Word: 以上 Pron: じょう POS: adverbial noun (fukushitekimeishi)
# Word: 上げる Pron: あ POS: Ichidan verb
# Word: 上る Pron: のぼ POS: Godan verb with `ru' ending
# Word: 上司 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 上旬 Pron: じょう POS: adverbial noun (fukushitekimeishi)
# Word: 取り上げる Pron: あ POS: Ichidan verb
# Word: 上演 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 仕上がり Pron: あ POS: noun (common) (futsuumeishi)
# Word: 目上 Pron: うえ POS: noun (common) (futsuumeishi)
# Word: 上陸 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 持ち上げる Pron: あ POS: Ichidan verb
# Word: 上位 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 上がり Pron: あ POS: noun, used as a suffix
# Word: 上京 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 上空 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 向上 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: お手上げ Pron: あ POS: expressions (phrases, clauses, etc.)
# Word: 上り Pron: のぼ POS: noun (common) (futsuumeishi)
# Word: 申し上げる Pron: あ POS: Ichidan verb
# Word: 差し上げる Pron: あ POS: auxiliary verb
# Word: 真上 Pron: うえ POS: noun (common) (futsuumeishi)
# Word: 上等 Pron: じょう POS: adjectival nouns or quasi-adjectives (keiyodoshi)
# Word: 上がる Pron: あ POS: Godan verb with `ru' ending
# Word: 上手 Pron: じょう POS: adjectival nouns or quasi-adjectives (keiyodoshi)
# Word: 上達 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 引き上げる Pron: あ POS: Ichidan verb
# Word: 上着 Pron: うわ POS: noun (common) (futsuumeishi)
# Word: 途上 Pron: じょう POS: adverbial noun (fukushitekimeishi)
# Word: 参上 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 仕上がる Pron: あ POS: Godan verb with `ru' ending
# Word: 上級 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 立ち上がる Pron: あ POS: Godan verb with `ru' ending
# Word: 読み上げる Pron: あ POS: Ichidan verb
# Word: 召し上がる Pron: あ POS: Godan verb with `ru' ending
# Word: 出来上がり Pron: あ POS: noun (common) (futsuumeishi)
# Word: 盛り上がる Pron: あ POS: Godan verb with `ru' ending
# Word: 頂上 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: 出来上がる Pron: あ POS: Godan verb with `ru' ending
# Word: 上 Pron: じょう POS: noun, used as a suffix
# Word: 上昇 Pron: じょう POS: noun (common) (futsuumeishi)
# Word: その上 Pron: うえ POS: noun (temporal) (jisoumeishi)
# Word: 仕上げる Pron: あ POS: Ichidan verb
# Word: 上回る Pron: うわ POS: Godan verb with `ru' ending
# Word: 仕上げ Pron: あ POS: noun (common) (futsuumeishi)

# %%
listOfVectors[1]
# Out:
# POSvector(kanji='飾', curPron='かざ', pos='noun', nextPron='r', prevPron='i', curIndex=1, lastChar='り', onKun=True, oneChar=False, allKanji=False)

# %%
csvFile = open('posVector.csv', 'w')
csvWriter = csv.writer(csvFile, quoting=csv.QUOTE_ALL)
csvWriter.writerow(['kanji','curPron','pos','nextPron','prevPron','curIndex','lastChar','onKun','oneChar','allKanji'])
for v in listOfVectors:
    csvWriter.writerow([v.kanji,v.curPron,v.pos,v.nextPron,v.prevPron,v.curIndex,v.lastChar,v.onKun,v.oneChar,v.allKanji])

# %%
csvFile = open('posVectorUp.csv', 'w')
csvWriter = csv.writer(csvFile, quoting=csv.QUOTE_ALL)
csvWriter.writerow(['kanji','curPron','pos','nextPron','prevPron','curIndex','lastChar','onKun','oneChar','allKanji'])
for v in listOfVectors:
    if v.kanji == '上':
        csvWriter.writerow([v.kanji,v.curPron,v.pos,v.nextPron,v.prevPron,v.curIndex,v.lastChar,v.onKun,v.oneChar,v.allKanji])

# %%
for thing in listOfVectors[1]:
    print(thing)
# Out:
# 飾
# かざ
# noun
# r
# i
# 1
# り
# True
# False
# False

# %%
lastCharPOS = dict()
onKunPOS = dict()
oneCharPOS = dict()
allKanjiPOS = dict()
curKanjiPOS = dict()

for v in listOfVectors:
    lastCharPOS[v.lastChar] = lastCharPOS.get(v.lastChar, Counter())
    lastCharPOS[v.lastChar][v.pos] += 1# lastCharPOS[v.lastChar].get(v.POS, 0) + 1
    onKunPOS[v.onKun] = onKunPOS.get(v.onKun, Counter())
    onKunPOS[v.onKun][v.pos] += 1
    oneCharPOS[v.oneChar] = oneCharPOS.get(v.oneChar, Counter())
    oneCharPOS[v.oneChar][v.pos] += 1
    allKanjiPOS[v.allKanji] = allKanjiPOS.get(v.allKanji, Counter())
    allKanjiPOS[v.allKanji][v.pos] += 1
    curKanjiPOS[v.kanji] = curKanjiPOS.get(v.kanji, Counter())
    curKanjiPOS[v.kanji][v.pos] += 1

# %%
lastCharPOS# do the bayes net to make this into probabilities. rerun over all vectors, using ALL of the features and
# see if mode matches actual POS. try again with my feature selection.
# look at percentages. Maybe try cross validation/train&test sets.
# Out:
# {'KANJI': Counter({'adjective': 12,
#           'adverb': 101,
#           'conjunction': 3,
#           'counter': 22,
#           'expression': 27,
#           'interjection': 9,
#           'noun': 7948,
#           'numeric': 15,
#           'particle': 1,
#           'prefix': 18,
#           'pronoun': 15,
#           'suffix': 43,
#           'verb': 1}),
#  'い': Counter({'adjective': 490,
#           'adverb': 2,
#           'expression': 29,
#           'noun': 126,
#           'suffix': 4}),
#  'う': Counter({'interjection': 5, 'noun': 3, 'suffix': 2, 'verb': 210}),
#  'え': Counter({'noun': 37}),
#  'か': Counter({'adverb': 3, 'expression': 5, 'noun': 63, 'pronoun': 2}),
#  'が': Counter({'conjunction': 2}),
#  'き': Counter({'adverb': 9, 'noun': 74}),
#  'ぎ': Counter({'noun': 12}),
#  'く': Counter({'adverb': 26,
#           'expression': 9,
#           'noun': 4,
#           'suffix': 2,
#           'verb': 182}),
#  'ぐ': Counter({'noun': 6, 'verb': 53}),
#  'け': Counter({'expression': 5, 'noun': 42, 'suffix': 2}),
#  'げ': Counter({'expression': 4, 'noun': 3}),
#  'こ': Counter({'noun': 4}),
#  'さ': Counter({'noun': 7}),
#  'し': Counter({'adverb': 4, 'conjunction': 4, 'noun': 83}),
#  'じ': Counter({'noun': 7}),
#  'す': Counter({'expression': 12, 'suffix': 2, 'verb': 454}),
#  'ず': Counter({'adverb': 26}),
#  'せ': Counter({'noun': 28}),
#  'そ': Counter({'adverb': 2}),
#  'た': Counter({'expression': 6, 'noun': 5}),
#  'だ': Counter({'adverb': 4}),
#  'ち': Counter({'adverb': 4, 'noun': 21, 'suffix': 2}),
#  'つ': Counter({'adverb': 4,
#           'expression': 4,
#           'noun': 4,
#           'numeric': 18,
#           'verb': 34}),
#  'て': Counter({'adverb': 37, 'conjunction': 5, 'expression': 8, 'noun': 23}),
#  'で': Counter({'adverb': 11, 'conjunction': 2}),
#  'と': Counter({'adverb': 9, 'expression': 11}),
#  'ど': Counter({'noun': 2}),
#  'な': Counter({'noun': 8}),
#  'に': Counter({'adverb': 68, 'conjunction': 3, 'expression': 8}),
#  'ぬ': Counter({'verb': 2}),
#  'ね': Counter({'noun': 3}),
#  'の': Counter({'noun': 2}),
#  'は': Counter({'adverb': 3,
#           'conjunction': 6,
#           'expression': 5,
#           'interjection': 3}),
#  'ば': Counter({'adverb': 6, 'noun': 2}),
#  'ぱ': Counter({'noun': 3}),
#  'び': Counter({'adverb': 2, 'conjunction': 2, 'noun': 10}),
#  'ぶ': Counter({'verb': 27}),
#  'べ': Counter({'noun': 9}),
#  'ぽ': Counter({'noun': 3}),
#  'ま': Counter({'interjection': 5, 'noun': 5}),
#  'み': Counter({'noun': 64, 'suffix': 2}),
#  'む': Counter({'verb': 231}),
#  'め': Counter({'adverb': 2, 'noun': 18, 'suffix': 2}),
#  'も': Counter({'adverb': 33, 'conjunction': 4, 'expression': 8}),
#  'や': Counter({'noun': 2}),
#  'ら': Counter({'adverb': 13, 'expression': 6, 'interjection': 4, 'noun': 7}),
#  'り': Counter({'adverb': 15, 'expression': 3, 'noun': 216, 'suffix': 7}),
#  'る': Counter({'adverb': 6,
#           'expression': 15,
#           'noun': 8,
#           'suffix': 9,
#           'verb': 1975}),
#  'れ': Counter({'noun': 62}),
#  'ろ': Counter({'adverb': 5, 'noun': 2}),
#  'ん': Counter({'expression': 5, 'noun': 29}),
#  'ム': Counter({'noun': 4})}

# %%
help(plt.axes)
# Out:
# Help on function axes in module matplotlib.pyplot:
#
# axes(*args, **kwargs)
#     Add an axes to the figure.
#
#     The axes is added at position *rect* specified by:
#
#     - ``axes()`` by itself creates a default full ``subplot(111)`` window axis.
#
#     - ``axes(rect, facecolor='w')`` where *rect* = [left, bottom, width,
#       height] in normalized (0, 1) units.  *facecolor* is the background
#       color for the axis, default white.
#
#     - ``axes(h)`` where *h* is an axes instance makes *h* the current
#       axis.  An :class:`~matplotlib.axes.Axes` instance is returned.
#
#     =========   ==============   ==============================================
#     kwarg       Accepts          Description
#     =========   ==============   ==============================================
#     facecolor   color            the axes background color
#     frameon     [True|False]     display the frame?
#     sharex      otherax          current axes shares xaxis attribute
#                                  with otherax
#     sharey      otherax          current axes shares yaxis attribute
#                                  with otherax
#     polar       [True|False]     use a polar axes?
#     aspect      [str | num]      ['equal', 'auto'] or a number.  If a number
#                                  the ratio of x-unit/y-unit in screen-space.
#                                  Also see
#                                  :meth:`~matplotlib.axes.Axes.set_aspect`.
#     =========   ==============   ==============================================
#
#     Examples:
#
#     * :file:`examples/pylab_examples/axes_demo.py` places custom axes.
#     * :file:`examples/pylab_examples/shared_axis_demo.py` uses
#       *sharex* and *sharey*.

# %%
labels, values = zip(*lastCharPOS['KANJI'].items())

index = np.arange(len(labels))

plt.figure(figsize=(50, 50))
plt.tick_params(labelsize=100)
plt.bar(index, values, 1)
plt.xticks(index , labels, rotation=90)
plt.yscale('log')
plt.title('POS of words with the last character being Kanji')
plt.ylabel('freq (log)')
plt.xlabel('pos')
plt.show()

# %%
#lastCharPOS
lastCharPOS['KANJI'].values()
# Out:
# dict_values([7948, 15, 22, 12, 101, 15, 43, 1, 18, 9, 27, 3, 1])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def getProbabilities(kanji=None,prevPron=None,prevChar=None,nextPron=None,nextChar=None,allKanji=None):
    """Inputs: kanji, prevPron?, prevChar?, nextPron?, nextChar?, allKanji?
? = optional
Output: A List of Dictionaries of occurences
TODO: Feed the list of dictionaries to computeProbabilities
This function returns all of the statistics for the current Kanji in
all contexts, independent of each other. This means that the nextPronunciation
dictionary will not be affected by the presence of an allKanji flag.

The order of the dictionaries are:
curPron, prevPron, prevChar, nextPron, nextChar, allKanji
"""
    dictionary_list = []
    keys = set(currentPronunciation.get(kanji, dict()).keys())
    dictionary_list.append(occurencesToPercentages(currentPronunciation.get(kanji, dict())))
    argument_list = []
    if prevPron != None:
        argument_list.append(prevPron)
        keys = keys | set(currentPronunciationPreviousPronunciation.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationPreviousPronunciation.get(kanji, dict())))
    if prevChar != None:
        argument_list.append(prevChar)
        keys = keys | set(currentPronunciationPreviousCharacter.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationPreviousCharacter.get(kanji, dict())))
    if nextPron != None:
        argument_list.append(nextPron)
        keys = keys | set(currentPronunciationNextPronunciation.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationNextPronunciation.get(kanji, dict())))
    if nextChar != None:
        argument_list.append(nextChar)
        keys = keys | set(currentPronunciationNextCharacter.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationNextCharacter.get(kanji, dict())))
    if allKanji != None:
        argument_list.append(allKanji)
        keys = keys | set(currentPronunciationAllKanji.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationAllKanji.get(kanji, dict())))
    return bayesTheorem(dictionary_list, keys, argument_list)

# %%
def bayesTheorem(dictionary_list, keys, argument_list): #kanji
    """Inputs: dictionary_list, keys, argument_list
Outputs: Sorted list of probabilities
This function follows the Bayesian Theorem that as defined
in the following paper https://dl.dropboxusercontent.com/u/62448029/DAG_for_email.pdf
Basic formula:
P(pronunciation|feature1, feature2, ...) =
P(pronunciation)*P(feature1|pronunciation)*P(feature2|pronunciation)* ...
Arguments is synonymous with features in this example
"""
    #print(dictionary_list)
    return_dict = dict()
    for key in keys:
        return_dict[key] = return_dict.get(key, 0) + dictionary_list[0].get(key, 0)
        for i in range(len(argument_list)):
            return_dict[key] = dictionary_list[i + 1].get(key, dict()).get(argument_list[i], 0) * return_dict[key]
    return_dict = occurencesToPercentages(return_dict)
    return sorted(return_dict.items(), key=lambda kv: kv[1], reverse=True)

# %%
def occurencesToPercentagesArg(dict_of_occurences):
    """Input: A single dictionary of occurences as values for some key
Output: A single dictionary of percentages as values for some key"""
    
    #for (_, value) in dict_of_occurences.items():
    #    sum = 0
    #    for (_, v) in value.items():
    #        sum += v
    sum_dict = dict()
    for (key1, value1) in dict_of_occurences.items(): 
        sum = 0
        for (key2, value2) in value1.items():
            sum = sum + value2
        sum_dict[key1] = sum_dict.get(key1, dict())
        sum_dict[key1]['sum'] = sum
        for (key2, value2) in value1.items():
            if sum_dict[key1]['sum'] != 0:
                dict_of_occurences[key1][key2] = value2 / sum_dict[key1]['sum']
    #dict_of_occurences = sorted(dict_of_occurences.items(), key=lambda kv: kv[1], reverse=True)
    return dict_of_occurences

# %%
#def init():
#    currentPronunciation = dict() # occurrences of all pronunciations...
#    previousPronunciationCurrentPronunciation = dict() # prev, curPron -- (V) curPron, prev
#    nextPronunciationCurrentPronunciation = dict() # 
#    previousCharacterCurrentPronunciation = dict() # 
#    nextCharacterCurrentPronunciation = dict() # 
#    allKanjiCurrentPronunciation = dict() # 
    # Features given pronunciation
#    currentPronunciationPreviousPronunciation = dict() #
#    currentPronunciationNextPronunciation = dict() # 
#    currentPronunciationPreviousCharacter = dict() # 
#    currentPronunciationNextCharacter = dict() # 
#    currentPronunciationAllKanji = dict() # 
#    currentKanjiPreviousPronunciation = dict() #
#    currentKanjiNextPronunciation = dict() # 
#    currentKanjiPreviousCharacter = dict() # 
#    currentKanjiNextCharacter = dict() # 
#    currentKanjiAllKanji = dict() # 
#    currentKanjiOneChar = dict()
    # New for totals... ###
#    globalPreviousPronunciation = dict() ### -> dict() -> [prevPron][curPron]
#    globalPreviousCharacter = dict() ### -> [prevChar][curPron]
#    globalNextPronunciation = dict() ### -> [nextPron][curPron]
#    globalNextCharacter = dict() ### -> [nextChar][curPron]
#    ##GLOBALGLOBALS
#    allKanjiCurrentPronunciation = dict() # [curPron]
#    allKanjiCurrentPronunciationPreviousPronunciation = dict() # [curPron][prevPron]
#    allKanjiCurrentPronunciationNextPronunciation = dict()
#    allKanjiCurrentPronunciationPreviousCharacter = dict()
#    allKanjiCurrentPronunciationNextCharacter = dict()
#    allKanjiCurrentPronunciationAllKanji = dict()

###
# number of characters in word
# 

def updateAllKanji(curKanji, curPron, allKanji):
    global allKanjiCurrentPronunciation, currentPronunciationAllKanji, currentKanjiAllKanji
    currentKanjiAllKanji[curKanji] = currentKanjiAllKanji.get(curKanji, dict())
    currentKanjiAllKanji[curKanji][allKanji] = currentKanjiAllKanji[curKanji].get(allKanji, 0) + 1
    currentPronunciationAllKanji[curKanji] = currentPronunciationAllKanji.get(curKanji, dict())
    currentPronunciationAllKanji[curKanji][curPron] = currentPronunciationAllKanji[curKanji].get(curPron, {True:0,False:0})
    currentPronunciationAllKanji[curKanji][curPron][allKanji] = currentPronunciationAllKanji[curKanji][curPron][allKanji] + 1
    allKanjiCurrentPronunciation[curKanji] = allKanjiCurrentPronunciation.get(curKanji, dict())
    allKanjiCurrentPronunciation[curKanji][allKanji] = allKanjiCurrentPronunciation[curKanji].get(allKanji, dict())
    allKanjiCurrentPronunciation[curKanji][allKanji][curPron] = allKanjiCurrentPronunciation[curKanji][allKanji].get(curPron,0) + 1
    
def updateCurPron(curKanji, curPron, oneChar):
    global currentPronunciation, v_cur_pron, currentKanjiOneChar
    currentPronunciation[curKanji] = currentPronunciation.get(curKanji, dict())
    currentPronunciation[curKanji][curPron] = currentPronunciation[curKanji].get(curPron, 0) + 1
    currentKanjiOneChar[curKanji] = currentKanjiOneChar.get(curKanji, dict())
    currentKanjiOneChar[curKanji][oneChar] = currentKanjiOneChar[curKanji].get(oneChar, dict())
    currentKanjiOneChar[curKanji][oneChar][curPron] = currentKanjiOneChar[curKanji][oneChar].get(curPron, 0) + 1
    

def updatePrevPron(curKanji, prevPron, curPron):
    global previousPronunciationCurrentPronunciation, currentPronunciationPreviousPronunciation, globalPreviousPronunciation, currentKanjiPreviousPronunciation
    currentKanjiPreviousPronunciation[curKanji] = currentKanjiPreviousPronunciation.get(curKanji, dict())
    currentKanjiPreviousPronunciation[curKanji][prevPron] = currentKanjiPreviousPronunciation[curKanji].get(prevPron, 0) + 1
    previousPronunciationCurrentPronunciation[curKanji] = previousPronunciationCurrentPronunciation.get(curKanji, dict())
    previousPronunciationCurrentPronunciation[curKanji][prevPron] = previousPronunciationCurrentPronunciation[curKanji].get(prevPron, dict())
    previousPronunciationCurrentPronunciation[curKanji][prevPron][curPron] = previousPronunciationCurrentPronunciation[curKanji][prevPron].get(curPron,0) + 1
    currentPronunciationPreviousPronunciation[curKanji] = currentPronunciationPreviousPronunciation.get(curKanji, dict())
    currentPronunciationPreviousPronunciation[curKanji][curPron] = currentPronunciationPreviousPronunciation[curKanji].get(curPron, dict())
    currentPronunciationPreviousPronunciation[curKanji][curPron][prevPron] = currentPronunciationPreviousPronunciation[curKanji][curPron].get(prevPron,0) + 1
    globalPreviousPronunciation[prevPron] = globalPreviousPronunciation.get(prevPron, dict())
    globalPreviousPronunciation[prevPron][curPron] = globalPreviousPronunciation[prevPron].get(curPron, 0) + 1
    
def updatePrevChar(curKanji, prevChar, curPron):
    global previousCharacterCurrentPronunciation, currentPronunciationNextCharacter, globalPreviousCharacter, currentKanjiPreviousCharacter
    currentKanjiPreviousCharacter[curKanji] = currentKanjiPreviousCharacter.get(curKanji, dict())
    currentKanjiPreviousCharacter[curKanji][prevChar] = currentKanjiPreviousCharacter[curKanji].get(prevChar, 0) + 1
    previousCharacterCurrentPronunciation[curKanji] = previousCharacterCurrentPronunciation.get(curKanji, dict())
    previousCharacterCurrentPronunciation[curKanji][prevChar] = previousCharacterCurrentPronunciation[curKanji].get(prevChar, dict())
    previousCharacterCurrentPronunciation[curKanji][prevChar][curPron] = previousCharacterCurrentPronunciation[curKanji][prevChar].get(curPron,0) + 1
    currentPronunciationPreviousCharacter[curKanji] = currentPronunciationPreviousCharacter.get(curKanji, dict())
    currentPronunciationPreviousCharacter[curKanji][curPron] = currentPronunciationPreviousCharacter[curKanji].get(curPron, dict())
    currentPronunciationPreviousCharacter[curKanji][curPron][prevChar] = currentPronunciationPreviousCharacter[curKanji][curPron].get(prevChar,0) + 1
    globalPreviousCharacter[prevChar] = globalPreviousCharacter.get(prevChar, dict())
    globalPreviousCharacter[prevChar][curPron] = globalPreviousCharacter[prevChar].get(curPron, 0) + 1
    
def updateNextPron(curKanji, nextPron, curPron):
    global nextPronunciationCurrentPronunciation, currentPronunciationNextPronunciation, globalNextPronunciation, currentKanjiNextPronunciation
    currentKanjiNextPronunciation[curKanji] = currentKanjiNextPronunciation.get(curKanji, dict())
    currentKanjiNextPronunciation[curKanji][nextPron] = currentKanjiNextPronunciation[curKanji].get(nextPron, 0) + 1
    nextPronunciationCurrentPronunciation[curKanji] = nextPronunciationCurrentPronunciation.get(curKanji, dict())
    nextPronunciationCurrentPronunciation[curKanji][nextPron] = nextPronunciationCurrentPronunciation[curKanji].get(nextPron, dict())
    nextPronunciationCurrentPronunciation[curKanji][nextPron][curPron] = nextPronunciationCurrentPronunciation[curKanji][nextPron].get(curPron,0) + 1
    currentPronunciationNextPronunciation[curKanji] = currentPronunciationNextPronunciation.get(curKanji, dict())
    currentPronunciationNextPronunciation[curKanji][curPron] = currentPronunciationNextPronunciation[curKanji].get(curPron, dict())
    currentPronunciationNextPronunciation[curKanji][curPron][nextPron] = currentPronunciationNextPronunciation[curKanji][curPron].get(nextPron,0) + 1
    globalNextPronunciation[nextPron] = globalNextPronunciation.get(nextPron, dict())
    globalNextPronunciation[nextPron][curPron] = globalNextPronunciation[nextPron].get(curPron, 0) + 1
    
def updateNextChar(curKanji, nextChar, curPron):
    global nextCharacterCurrentPronunciation, currentPronunciationNextCharacter, globalNextCharacter, currentKanjiNextCharacter
    currentKanjiNextCharacter[curKanji] = currentKanjiNextCharacter.get(curKanji, dict())
    currentKanjiNextCharacter[curKanji][nextChar] = currentKanjiNextCharacter[curKanji].get(nextChar, 0) + 1
    nextCharacterCurrentPronunciation[curKanji] = nextCharacterCurrentPronunciation.get(curKanji, dict())
    nextCharacterCurrentPronunciation[curKanji][nextChar] = nextCharacterCurrentPronunciation[curKanji].get(nextChar, dict())
    nextCharacterCurrentPronunciation[curKanji][nextChar][curPron] = nextCharacterCurrentPronunciation[curKanji][nextChar].get(curPron,0) + 1
    currentPronunciationNextCharacter[curKanji] = currentPronunciationNextCharacter.get(curKanji, dict())
    currentPronunciationNextCharacter[curKanji][curPron] = currentPronunciationNextCharacter[curKanji].get(curPron, dict())
    currentPronunciationNextCharacter[curKanji][curPron][nextChar] = currentPronunciationNextCharacter[curKanji][curPron].get(nextChar,0) + 1
    globalNextCharacter[nextChar] = globalNextCharacter.get(nextChar, dict())
    globalNextCharacter[nextChar][curPron] = globalNextCharacter[nextChar].get(curPron, 0) + 1

# %%
########## PARTIAL PRONUNCIATIONS ###########

def init():
    global allKanjiCurrentPronunciation, \
    currentPronunciationNextCharacter, currentKanjiAllKanji, currentPronunciationAllKanji, \
    nextCharacterCurrentPronunciation, currentPronunciationNextPronunciation, currentKanjiNextCharacter, \
    nextPronunciationCurrentPronunciation, currentKanjiNextPronunciation, currentKanjiPreviousPronunciation, \
    currentPronunciationPreviousCharacter, previousCharacterCurrentPronunciation, \
    currentKanjiPreviousCharacter, currentKanjiPreviousCharacter, globalNextPronunciation, \
    globalNextCharacter, globalPreviousPronunciation, globalPreviousCharacter, \
    currentPronunciationPreviousPronunciation, previousPronunciationCurrentPronunciation, \
    currentKanjiPreviousPronunciation, currentKanjiOneChar, currentChar, currentPronunciation, \
    currentPronunciationStart, currentPronunciationEnd, nextCharacterCurrentPronunciationEnd, \
    previousCharacterCurrentPronunciationStart, previousPronunciationEndCurrentPronunciationStart, \
    nextPronunciationStartCurrentPronunciationEnd
    ################ END OF GLOBALS ##############
    previousPronunciationEndCurrentPronunciationStart = dict()
    nextPronunciationStartCurrentPronunciationEnd = dict()
    previousCharacterCurrentPronunciationStart = dict()
    nextCharacterCurrentPronunciationEnd = dict()
    currentPronunciationStart = dict()
    currentPronunciationEnd = dict()
    currentPronunciation = dict()
    currentChar = dict()
    previousPronunciationCurrentPronunciation = dict() # prev, curPron -- (V) curPron, prev
    nextPronunciationCurrentPronunciation = dict() # 
    previousCharacterCurrentPronunciation = dict() # 
    nextCharacterCurrentPronunciation = dict() # 
    allKanjiCurrentPronunciation = dict() # 
    # Features given pronunciation
    currentPronunciationPreviousPronunciation = dict() #
    currentPronunciationNextPronunciation = dict() # 
    currentPronunciationPreviousCharacter = dict() # 
    currentPronunciationNextCharacter = dict() # 
    currentPronunciationAllKanji = dict() # 
    currentKanjiPreviousPronunciation = dict() #
    currentKanjiNextPronunciation = dict() # 
    currentKanjiPreviousCharacter = dict() # 
    currentKanjiNextCharacter = dict() # 
    currentKanjiAllKanji = dict() # 
    currentKanjiOneChar = dict()
    # New for totals... ###
    globalPreviousPronunciation = dict() ### -> dict() -> [prevPron][curPron]
    globalPreviousCharacter = dict() ### -> [prevChar][curPron]
    globalNextPronunciation = dict() ### -> [nextPron][curPron]
    globalNextCharacter = dict() ### -> [nextChar][curPron]
    ##GLOBALGLOBALS
    allKanjiCurrentPronunciation = dict() # [curPron]
    allKanjiCurrentPronunciationPreviousPronunciation = dict() # [curPron][prevPron]
    allKanjiCurrentPronunciationNextPronunciation = dict()
    allKanjiCurrentPronunciationPreviousCharacter = dict()
    allKanjiCurrentPronunciationNextCharacter = dict()
    allKanjiCurrentPronunciationAllKanji = dict()

def updatePreviousPronunciation(curPron, prevChar, prevPron, curKanji):
    global previousPronunciationEndCurrentPronunciationStart, previousCharacterCurrentPronunciationStart, currentPronunciationStart
    if len(prevPron) > 1 and prevPron != 'START':
        if prevPron[-1] in ['ゃ','ゅ','ょ']:
            if len(prevPron) > 2 and prevPron[-3] == 'っ':
                prevPron = prevPron[-3:]
            else:
                prevPron = prevPron[-2:]
        elif prevPron[-2] == 'っ':
            prevPron = prevPron[-2:]
        else:
            prevPron = prevPron[-1]
    if len(curPron) > 1:
        if curPron[0] == 'っ':
            if len(curPron) > 2 and curPron[2] in ['ゃ','ゅ','ょ']:
                curPron = curPron[:3]
            else:
                curPron = curPron[:2]
        elif curPron[1] in ['ゃ','ゅ','ょ']:
            curPron = curPron[:2]
        else:
            curPron = curPron[0]
    previousPronunciationEndCurrentPronunciationStart[prevPron] = previousPronunciationEndCurrentPronunciationStart.get(prevPron,dict())
    previousPronunciationEndCurrentPronunciationStart[prevPron][curPron] = previousPronunciationEndCurrentPronunciationStart[prevPron].get(curPron,0) + 1
    previousCharacterCurrentPronunciationStart[prevChar] = previousCharacterCurrentPronunciationStart.get(prevChar,dict())
    previousCharacterCurrentPronunciationStart[prevChar][curPron] = previousCharacterCurrentPronunciationStart[prevChar].get(curPron,0) + 1
    currentPronunciationStart[curKanji] = currentPronunciationStart.get(curKanji, dict())
    currentPronunciationStart[curKanji][curPron] = currentPronunciationStart[curKanji].get(curPron, 0) + 1
    
def updateNextPronunciation(curPron, nextChar, nextPron, curKanji):
    global currentPronunciationEnd, nextCharacterCurrentPronunciationEnd, nextPronunciationStartCurrentPronunciationEnd
    if len(nextPron) > 1 and nextPron != 'END':
        if nextPron[0] == 'っ':
            if len(nextPron) > 2 and nextPron[2] in ['ゃ','ゅ','ょ']:
                nextPron = nextPron[:3]
            else:
                nextPron = nextPron[:2]
        elif nextPron[1] in ['ゃ','ゅ','ょ']:
            nextPron = nextPron[:2]
        else:
            nextPron = nextPron[0]
    if len(curPron) > 1:
        if curPron[-1] in ['ゃ','ゅ','ょ']:
            if len(curPron) > 2 and curPron[-3] == 'っ':
                curPron = curPron[-3:]
            else:
                curPron = curPron[-2:]
        elif curPron[-2] == 'っ':
            curPron = curPron[-2:]
        else:
            curPron = curPron[-1]
    nextPronunciationStartCurrentPronunciationEnd[nextPron] = nextPronunciationStartCurrentPronunciationEnd.get(nextPron,dict())
    nextPronunciationStartCurrentPronunciationEnd[nextPron][curPron] = nextPronunciationStartCurrentPronunciationEnd[nextPron].get(curPron,0) + 1
    nextCharacterCurrentPronunciationEnd[nextChar] = nextCharacterCurrentPronunciationEnd.get(nextChar,dict())
    nextCharacterCurrentPronunciationEnd[nextChar][curPron] = nextCharacterCurrentPronunciationEnd[nextChar].get(curPron,0) + 1
    currentPronunciationEnd[curKanji] = currentPronunciationEnd.get(curKanji, dict())
    currentPronunciationEnd[curKanji][curPron] = currentPronunciationEnd[curKanji].get(curPron, 0) + 1

# %%
def createBayes():
    """Creates the Bayesian Network by creating dictionaries of occurences"""
    global currentChar, currentPronunciation, current
    init()
    for kanji, pronunciation in true_dict.items():
        oneChar = False
        if len(kanji) == 1:
            oneChar = True
        if re.search("""[\u3040-\u30ff]+""", kanji) == None and len(kanji) != 0: # Finds kana
            kanjiWord = True
        else: # either kana is present or the word is a singular character
            kanjiWord = False
        for i in range(len(kanji)):
            updateCurPron(kanji[i], pronunciation[i], oneChar)
            currentChar[kanji[i]] = currentChar.get(kanji[i], 0) + 1
            #currentPronunciation[kanji[i]] = currentPronunciation.get(kanji[i], []) + [pronunciation[i]]
            if i == 0: # First and last characters are special cases
                updatePrevPron(kanji[i], 'START', pronunciation[i])
                updatePrevChar(kanji[i], 'START', pronunciation[i])
                updatePreviousPronunciation(pronunciation[i], 'START', 'START', kanji[i])
            else:
                updatePrevPron(kanji[i], pronunciation[i-1], pronunciation[i])
                updatePrevChar(kanji[i], kanji[i-1], pronunciation[i])
                updatePreviousPronunciation(pronunciation[i], kanji[i-1], pronunciation[i-1], kanji[i])
            if i == (len(kanji) - 1):
                updateNextPron(kanji[i], 'END', pronunciation[i])
                updateNextChar(kanji[i], 'END', pronunciation[i])
                updateNextPronunciation(pronunciation[i], 'END', 'END', kanji[i])
            else:
                updateNextPron(kanji[i], pronunciation[i+1], pronunciation[i])
                updateNextChar(kanji[i], kanji[i+1], pronunciation[i])
                updateNextPronunciation(pronunciation[i], kanji[i+1], pronunciation[i+1], kanji[i])
        updateAllKanji(kanji[i], pronunciation[i], kanjiWord)

# %%
createBayes()

# %%
previousPronunciationEndCurrentPronunciationStart
# Out:
# {'START': {'あ': 196,
#   'い': 182,
#   'う': 121,
#   'え': 58,
#   'お': 243,
#   'か': 437,
#   'が': 50,
#   'き': 171,
#   'きゃ': 5,
#   'きゅ': 30,
#   'きょ': 64,
#   'ぎ': 22,
#   'ぎゃ': 2,
#   'ぎゅ': 2,
#   'ぎょ': 11,
#   'く': 105,
#   'ぐ': 14,
#   'け': 115,
#   'げ': 58,
#   'こ': 287,
#   'ご': 47,
#   'さ': 187,
#   'ざ': 21,
#   'し': 250,
#   'しゃ': 15,
#   'しゅ': 79,
#   'しょ': 109,
#   'じ': 90,
#   'じゃ': 5,
#   'じゅ': 49,
#   'じょ': 50,
#   'す': 103,
#   'ず': 10,
#   'せ': 168,
#   'ぜ': 31,
#   'そ': 101,
#   'ぞ': 15,
#   'た': 211,
#   'だ': 62,
#   'ち': 64,
#   'ちゃ': 13,
#   'ちゅ': 34,
#   'ちょ': 46,
#   'つ': 145,
#   'て': 108,
#   'で': 46,
#   'と': 184,
#   'ど': 67,
#   'な': 129,
#   'に': 51,
#   'にゅ': 7,
#   'にょ': 2,
#   'ぬ': 13,
#   'ね': 44,
#   'の': 57,
#   'は': 213,
#   'ば': 36,
#   'ひ': 150,
#   'ひゃ': 1,
#   'ひょ': 12,
#   'び': 14,
#   'びょ': 5,
#   'ふ': 140,
#   'ぶ': 53,
#   'へ': 42,
#   'べ': 12,
#   'ほ': 115,
#   'ぼ': 32,
#   'ま': 135,
#   'み': 91,
#   'みゃ': 1,
#   'みょ': 3,
#   'む': 60,
#   'め': 54,
#   'も': 92,
#   'や': 68,
#   'ゆ': 71,
#   'よ': 112,
#   'ら': 12,
#   'り': 22,
#   'りゃ': 3,
#   'りゅ': 6,
#   'りょ': 29,
#   'る': 4,
#   'れ': 27,
#   'ろ': 19,
#   'わ': 56,
#   'ジ': 1,
#   'ロ': 1},
#  'あ': {'い': 7,
#   'う': 11,
#   'え': 2,
#   'か': 3,
#   'が': 9,
#   'き': 3,
#   'く': 3,
#   'け': 4,
#   'げ': 12,
#   'ざ': 1,
#   'し': 1,
#   'た': 7,
#   'て': 8,
#   'び': 1,
#   'む': 1,
#   'ら': 1,
#   'り': 1,
#   'る': 3,
#   'わ': 12},
#  'い': {'あ': 5,
#   'い': 16,
#   'う': 3,
#   'え': 4,
#   'お': 2,
#   'か': 34,
#   'が': 18,
#   'き': 29,
#   'きゅ': 6,
#   'きょ': 3,
#   'ぎ': 7,
#   'ぎょ': 1,
#   'く': 5,
#   'ぐ': 3,
#   'け': 20,
#   'げ': 8,
#   'こ': 25,
#   'ご': 7,
#   'さ': 24,
#   'ざ': 4,
#   'し': 30,
#   'しゃ': 8,
#   'しゅ': 12,
#   'しょ': 16,
#   'じ': 21,
#   'じゅ': 6,
#   'じょ': 11,
#   'す': 15,
#   'ず': 2,
#   'せ': 27,
#   'ぜ': 5,
#   'そ': 13,
#   'ぞ': 9,
#   'た': 14,
#   'だ': 10,
#   'ち': 4,
#   'ちゅ': 2,
#   'ちょ': 3,
#   'つ': 6,
#   'て': 19,
#   'で': 5,
#   'と': 14,
#   'ど': 13,
#   'な': 4,
#   'に': 7,
#   'にゅ': 1,
#   'ね': 9,
#   'の': 4,
#   'は': 5,
#   'ば': 8,
#   'ひ': 4,
#   'ひょ': 1,
#   'び': 3,
#   'ふ': 8,
#   'ぶ': 13,
#   'へ': 4,
#   'べ': 4,
#   'ほ': 10,
#   'ぼ': 8,
#   'ま': 5,
#   'み': 6,
#   'む': 1,
#   'め': 7,
#   'も': 4,
#   'や': 5,
#   'ゆ': 3,
#   'よ': 14,
#   'ら': 7,
#   'り': 13,
#   'りゃ': 1,
#   'りゅ': 2,
#   'りょ': 9,
#   'る': 11,
#   'れ': 15,
#   'ろ': 5,
#   'わ': 7},
#  'う': {'あ': 2,
#   'い': 29,
#   'う': 2,
#   'え': 18,
#   'お': 4,
#   'か': 52,
#   'が': 24,
#   'き': 22,
#   'きゃ': 1,
#   'きゅ': 7,
#   'きょ': 13,
#   'ぎ': 10,
#   'ぎょ': 9,
#   'く': 6,
#   'ぐ': 4,
#   'け': 28,
#   'げ': 11,
#   'こ': 29,
#   'ご': 12,
#   'さ': 26,
#   'ざ': 3,
#   'し': 57,
#   'しゃ': 14,
#   'しゅ': 14,
#   'しょ': 21,
#   'じ': 31,
#   'じゃ': 1,
#   'じゅ': 8,
#   'じょ': 18,
#   'す': 13,
#   'ず': 5,
#   'せ': 33,
#   'ぜ': 4,
#   'そ': 21,
#   'ぞ': 6,
#   'た': 14,
#   'だ': 15,
#   'ち': 17,
#   'ちゃ': 2,
#   'ちゅ': 3,
#   'ちょ': 9,
#   'つ': 7,
#   'て': 17,
#   'で': 1,
#   'と': 14,
#   'ど': 24,
#   'な': 5,
#   'に': 12,
#   'にゅ': 6,
#   'ね': 5,
#   'の': 1,
#   'は': 9,
#   'ば': 7,
#   'ひ': 9,
#   'ひょ': 3,
#   'び': 15,
#   'ふ': 15,
#   'ぶ': 9,
#   'へ': 3,
#   'べ': 4,
#   'ほ': 9,
#   'ぼ': 10,
#   'ま': 4,
#   'み': 6,
#   'みょ': 1,
#   'む': 5,
#   'め': 13,
#   'も': 6,
#   'や': 6,
#   'ゆ': 3,
#   'よ': 13,
#   'ら': 2,
#   'り': 25,
#   'りゃ': 1,
#   'りゅ': 3,
#   'りょ': 20,
#   'る': 2,
#   'れ': 7,
#   'ろ': 5,
#   'わ': 7},
#  'え': {'う': 1,
#   'お': 1,
#   'が': 1,
#   'し': 2,
#   'す': 9,
#   'ず': 2,
#   'っ': 2,
#   'つ': 2,
#   'て': 1,
#   'で': 1,
#   'な': 1,
#   'の': 1,
#   'ば': 1,
#   'も': 2,
#   'り': 4,
#   'る': 82},
#  'お': {'い': 16,
#   'う': 6,
#   'え': 1,
#   'か': 9,
#   'が': 1,
#   'き': 5,
#   'く': 2,
#   'ぐ': 1,
#   'げ': 1,
#   'こ': 3,
#   'さ': 6,
#   'ざ': 2,
#   'し': 9,
#   'しゃ': 1,
#   'じ': 2,
#   'じゃ': 1,
#   'じょ': 1,
#   'す': 9,
#   'せ': 2,
#   'ぜ': 1,
#   'ぞ': 1,
#   'た': 2,
#   'だ': 1,
#   'ち': 4,
#   'ちゃ': 1,
#   'っ': 1,
#   'つ': 2,
#   'て': 4,
#   'と': 3,
#   'ど': 1,
#   'ね': 1,
#   'は': 1,
#   'ひ': 1,
#   'び': 1,
#   'ふ': 1,
#   'べ': 1,
#   'ま': 4,
#   'み': 3,
#   'め': 1,
#   'や': 3,
#   'り': 12,
#   'る': 9,
#   'れ': 3,
#   'ろ': 2,
#   'わ': 2},
#  'か': {'い': 26,
#   'う': 9,
#   'え': 19,
#   'お': 1,
#   'か': 7,
#   'が': 6,
#   'き': 3,
#   'く': 8,
#   'ぐ': 2,
#   'け': 25,
#   'げ': 3,
#   'こ': 4,
#   'ご': 2,
#   'さ': 3,
#   'ざ': 2,
#   'し': 13,
#   'しゃ': 1,
#   'しゅ': 1,
#   'しょ': 4,
#   'じ': 4,
#   'じょ': 2,
#   'す': 22,
#   'せ': 7,
#   'ぜ': 1,
#   'そ': 3,
#   'ぞ': 1,
#   'た': 1,
#   'だ': 3,
#   'ち': 5,
#   'ちょ': 1,
#   'つ': 2,
#   'づ': 3,
#   'て': 5,
#   'な': 5,
#   'に': 1,
#   'にゅ': 1,
#   'ね': 3,
#   'の': 3,
#   'は': 1,
#   'ば': 4,
#   'び': 2,
#   'ふ': 1,
#   'ぶ': 1,
#   'へ': 1,
#   'べ': 1,
#   'ほ': 1,
#   'ま': 6,
#   'み': 5,
#   'む': 2,
#   'め': 3,
#   'も': 4,
#   'ゆ': 1,
#   'よ': 5,
#   'ら': 5,
#   'り': 8,
#   'る': 26,
#   'れ': 8,
#   'ろ': 1,
#   'わ': 8,
#   'ん': 2},
#  'が': {'い': 13,
#   'う': 8,
#   'え': 5,
#   'か': 3,
#   'き': 3,
#   'く': 2,
#   'け': 4,
#   'し': 3,
#   'す': 10,
#   'ち': 1,
#   'っ': 2,
#   'て': 1,
#   'な': 4,
#   'ね': 1,
#   'び': 1,
#   'ま': 2,
#   'む': 2,
#   'め': 3,
#   'ら': 3,
#   'り': 4,
#   'る': 16,
#   'れ': 6,
#   'わ': 1},
#  'き': {'あ': 9,
#   'い': 5,
#   'う': 2,
#   'え': 2,
#   'お': 5,
#   'か': 15,
#   'が': 5,
#   'き': 7,
#   'きょ': 1,
#   'ぎ': 1,
#   'ぎょ': 1,
#   'く': 2,
#   'ぐ': 1,
#   'け': 4,
#   'げ': 4,
#   'こ': 4,
#   'ご': 3,
#   'さ': 3,
#   'ざ': 1,
#   'し': 1,
#   'しゃ': 2,
#   'しょ': 2,
#   'じ': 3,
#   'じゅ': 3,
#   'じょ': 2,
#   'す': 2,
#   'ず': 2,
#   'せ': 6,
#   'そ': 4,
#   'ぞ': 2,
#   'た': 5,
#   'だ': 4,
#   'ち': 3,
#   'ちょ': 2,
#   'っ': 1,
#   'づ': 1,
#   'て': 2,
#   'と': 7,
#   'ど': 3,
#   'な': 4,
#   'に': 4,
#   'にゅ': 1,
#   'ね': 2,
#   'の': 2,
#   'は': 1,
#   'ば': 1,
#   'ひ': 2,
#   'ふ': 3,
#   'ぶ': 1,
#   'ほ': 2,
#   'ぼ': 2,
#   'ま': 9,
#   'み': 1,
#   'みょ': 1,
#   'む': 1,
#   'め': 3,
#   'も': 4,
#   'や': 1,
#   'ゆ': 1,
#   'よ': 4,
#   'ら': 2,
#   'り': 7,
#   'りゅ': 1,
#   'る': 14,
#   'れ': 8,
#   'ろ': 1,
#   'わ': 3,
#   'を': 1},
#  'きょ': {'じゅ': 1, 'ぜ': 1, 'だ': 1, 'ね': 1, 'ひ': 1, 'よ': 1, 'り': 1},
#  'ぎ': {'あ': 1,
#   'い': 3,
#   'か': 2,
#   'きょ': 1,
#   'け': 1,
#   'し': 3,
#   'じ': 1,
#   'じゅ': 1,
#   'せ': 1,
#   'ぞ': 1,
#   'だ': 1,
#   'ちょ': 1,
#   'つ': 1,
#   'の': 1,
#   'む': 1,
#   'め': 1,
#   'も': 1,
#   'や': 1,
#   'ら': 1,
#   'り': 2,
#   'る': 9,
#   'れ': 1,
#   'ろ': 1,
#   'わ': 2},
#  'ぎょ': {'ぎょ': 1, 'せ': 1, 'そ': 1},
#  'く': {'あ': 1,
#   'い': 11,
#   'う': 3,
#   'え': 1,
#   'お': 2,
#   'か': 2,
#   'が': 3,
#   'き': 1,
#   'きゅ': 1,
#   'ぎ': 3,
#   'ぎょ': 1,
#   'げ': 3,
#   'ご': 7,
#   'さ': 9,
#   'ざ': 3,
#   'し': 15,
#   'しゃ': 5,
#   'しゅ': 9,
#   'しょ': 8,
#   'じ': 8,
#   'じゃ': 1,
#   'じゅ': 3,
#   'じょ': 5,
#   'す': 9,
#   'せ': 19,
#   'ぜ': 2,
#   'そ': 3,
#   'ぞ': 1,
#   'た': 5,
#   'だ': 8,
#   'ち': 3,
#   'ちゃ': 2,
#   'ちょ': 3,
#   'っ': 2,
#   'つ': 3,
#   'て': 10,
#   'と': 5,
#   'ど': 5,
#   'な': 5,
#   'に': 6,
#   'ね': 1,
#   'の': 1,
#   'は': 6,
#   'ば': 5,
#   'ひ': 3,
#   'ひょ': 2,
#   'び': 1,
#   'びょ': 1,
#   'ふ': 4,
#   'ぶ': 6,
#   'べ': 3,
#   'ほ': 2,
#   'ぼ': 2,
#   'ま': 3,
#   'み': 8,
#   'む': 7,
#   'め': 7,
#   'も': 5,
#   'や': 1,
#   'ゆ': 2,
#   'よ': 3,
#   'ら': 8,
#   'り': 14,
#   'りゅ': 1,
#   'りょ': 6,
#   'る': 8,
#   'れ': 11,
#   'ろ': 5,
#   'わ': 2},
#  'ぐ': {'あ': 1, 'い': 1, 'た': 1, 'ち': 1, 'ま': 1, 'み': 1, 'む': 1, 'る': 4, 'れ': 4},
#  'け': {'あ': 1,
#   'い': 3,
#   'が': 3,
#   'く': 1,
#   'こ': 1,
#   'ざ': 1,
#   'し': 2,
#   'しょ': 1,
#   'す': 3,
#   'だ': 1,
#   'っ': 1,
#   'つ': 3,
#   'と': 5,
#   'な': 3,
#   'は': 1,
#   'ば': 1,
#   'び': 1,
#   'ぶ': 2,
#   'み': 1,
#   'も': 1,
#   'ら': 1,
#   'る': 66},
#  'げ': {'か': 1,
#   'く': 1,
#   'さ': 2,
#   'し': 1,
#   'しゃ': 1,
#   'しゅ': 1,
#   'じゅ': 1,
#   'す': 1,
#   'た': 1,
#   'だ': 2,
#   'ちゃ': 1,
#   'な': 1,
#   'ひ': 1,
#   'ま': 1,
#   'む': 1,
#   'り': 1,
#   'る': 28},
#  'こ': {'い': 2,
#   'う': 3,
#   'え': 3,
#   'が': 3,
#   'きゅ': 1,
#   'きょ': 1,
#   'ぎ': 1,
#   'ぐ': 1,
#   'げ': 2,
#   'こ': 3,
#   'し': 2,
#   'しょ': 2,
#   'じ': 3,
#   'す': 10,
#   'せ': 2,
#   'ぜ': 1,
#   'た': 2,
#   'だ': 1,
#   'ちょ': 1,
#   'づ': 2,
#   'て': 2,
#   'と': 2,
#   'ど': 2,
#   'な': 1,
#   'の': 6,
#   'び': 2,
#   'ぶ': 2,
#   'べ': 1,
#   'ぼ': 1,
#   'ま': 1,
#   'み': 2,
#   'む': 22,
#   'め': 1,
#   'や': 3,
#   'ゆ': 2,
#   'よ': 1,
#   'ら': 1,
#   'り': 4,
#   'る': 4},
#  'ご': {'い': 3,
#   'え': 2,
#   'か': 2,
#   'が': 1,
#   'き': 1,
#   'く': 3,
#   'げ': 1,
#   'ご': 1,
#   'さ': 1,
#   'ざ': 1,
#   'し': 1,
#   'しゅ': 1,
#   'じゅ': 1,
#   'す': 2,
#   'ぜ': 1,
#   'ぞ': 1,
#   'ち': 3,
#   'と': 1,
#   'に': 1,
#   'にゅ': 1,
#   'は': 4,
#   'ば': 1,
#   'ぶ': 2,
#   'ま': 1,
#   'み': 1,
#   'む': 1,
#   'め': 3,
#   'や': 1,
#   'ら': 4,
#   'る': 3,
#   'れ': 1},
#  'さ': {'い': 10,
#   'え': 4,
#   'が': 3,
#   'ぎ': 1,
#   'ぎょ': 1,
#   'く': 2,
#   'ぐ': 1,
#   'け': 4,
#   'げ': 4,
#   'ご': 1,
#   'さ': 1,
#   'し': 14,
#   'じ': 1,
#   'す': 7,
#   'た': 3,
#   'て': 1,
#   'と': 1,
#   'な': 2,
#   'に': 1,
#   'ね': 2,
#   'ば': 2,
#   'ぶ': 1,
#   'べ': 1,
#   'ほ': 2,
#   'ま': 9,
#   'み': 1,
#   'む': 3,
#   'め': 6,
#   'も': 1,
#   'ゆ': 1,
#   'よ': 2,
#   'ら': 6,
#   'る': 6,
#   'わ': 1,
#   'ん': 5},
#  'ざ': {'い': 1,
#   'か': 1,
#   'ぐ': 1,
#   'し': 2,
#   'す': 2,
#   'せ': 1,
#   'だ': 1,
#   'っ': 1,
#   'と': 1,
#   'に': 1,
#   'ひょ': 1,
#   'ぶ': 1,
#   'む': 1,
#   'め': 1,
#   'や': 1,
#   'り': 2,
#   'る': 4,
#   'わ': 2},
#  'し': {'あ': 14,
#   'い': 68,
#   'え': 2,
#   'か': 19,
#   'が': 1,
#   'き': 4,
#   'きゅ': 2,
#   'ぎ': 1,
#   'ぎょ': 1,
#   'く': 6,
#   'け': 2,
#   'げ': 2,
#   'こ': 6,
#   'ご': 2,
#   'さ': 2,
#   'ざ': 1,
#   'しゃ': 1,
#   'しゅ': 2,
#   'じ': 3,
#   'じゅ': 1,
#   'ず': 1,
#   'せ': 2,
#   'ぜ': 2,
#   'そ': 3,
#   'た': 7,
#   'だ': 3,
#   'ちゅ': 1,
#   'つ': 3,
#   'て': 12,
#   'で': 2,
#   'ど': 1,
#   'な': 1,
#   'にょ': 1,
#   'ぬ': 1,
#   'は': 4,
#   'ば': 1,
#   'ひ': 2,
#   'び': 1,
#   'ぶ': 4,
#   'へ': 1,
#   'ほ': 2,
#   'ぼ': 3,
#   'ま': 10,
#   'み': 5,
#   'む': 7,
#   'め': 8,
#   'も': 4,
#   'ゃ': 1,
#   'や': 2,
#   'ゆ': 2,
#   'よ': 7,
#   'ら': 2,
#   'り': 2,
#   'りょ': 1,
#   'る': 4,
#   'れ': 2,
#   'ろ': 3,
#   'わ': 3,
#   'ゴ': 1},
#  'しゃ': {'か': 2,
#   'こ': 2,
#   'ご': 1,
#   'し': 1,
#   'しょ': 1,
#   'じょ': 1,
#   'せ': 2,
#   'ぜ': 1,
#   'た': 1,
#   'ちょ': 1,
#   'の': 1,
#   'め': 1,
#   'ら': 1,
#   'り': 1},
#  'しゅ': {'え': 2,
#   'か': 1,
#   'ぎ': 1,
#   'け': 1,
#   'げ': 1,
#   'ご': 1,
#   'さ': 1,
#   'ざ': 1,
#   'し': 1,
#   'しょ': 2,
#   'じ': 2,
#   'じゅ': 1,
#   'た': 1,
#   'だ': 2,
#   'ちょ': 1,
#   'と': 1,
#   'ど': 1,
#   'に': 1,
#   'の': 1,
#   'び': 1,
#   'ふ': 1,
#   'ほ': 1,
#   'み': 1,
#   'や': 1,
#   'よ': 1,
#   'る': 1},
#  'しょ': {'か': 1,
#   'きゅ': 1,
#   'く': 1,
#   'さ': 1,
#   'ざ': 1,
#   'しょ': 1,
#   'じ': 1,
#   'じゅ': 1,
#   'せ': 1,
#   'ぞ': 1,
#   'ち': 1,
#   'て': 2,
#   'と': 1,
#   'ど': 1,
#   'は': 1,
#   'ば': 1,
#   'ひょ': 1,
#   'ぶ': 1,
#   'み': 1,
#   'む': 1,
#   'め': 1,
#   'も': 1,
#   'り': 1,
#   'る': 1},
#  'じ': {'い': 1,
#   'え': 2,
#   'か': 3,
#   'が': 1,
#   'き': 3,
#   'ぎ': 1,
#   'ぎょ': 2,
#   'け': 1,
#   'こ': 5,
#   'ご': 1,
#   'さ': 3,
#   'ざ': 1,
#   'し': 3,
#   'しゃ': 1,
#   'しゅ': 3,
#   'しょ': 2,
#   'じ': 1,
#   'じょ': 1,
#   'ぜ': 1,
#   'そ': 2,
#   'ぞ': 1,
#   'た': 3,
#   'だ': 1,
#   'ち': 1,
#   'つ': 1,
#   'て': 3,
#   'ど': 5,
#   'に': 1,
#   'ぬ': 1,
#   'ば': 1,
#   'び': 3,
#   'ぶ': 1,
#   'ま': 4,
#   'み': 1,
#   'む': 3,
#   'め': 9,
#   'も': 1,
#   'ゃ': 1,
#   'ゆ': 2,
#   'ら': 1,
#   'り': 1,
#   'る': 23,
#   'れ': 2,
#   'ろ': 1,
#   'わ': 4},
#  'じゃ': {'き': 1, 'ぐ': 1, 'ま': 2, 'り': 1},
#  'じゅ': {'ぎょ': 1, 'け': 1, 'ひ': 1, 'みょ': 1, 'も': 1, 'よ': 1, 'り': 1, 'わ': 1},
#  'じょ': {'お': 1,
#   'が': 1,
#   'きょ': 1,
#   'げ': 1,
#   'こ': 1,
#   'し': 3,
#   'しゅ': 1,
#   'せ': 1,
#   'ど': 1,
#   'ゆ': 1},
#  'す': {'い': 3,
#   'う': 1,
#   'え': 2,
#   'か': 2,
#   'き': 5,
#   'ぎ': 3,
#   'ぐ': 4,
#   'け': 2,
#   'ご': 1,
#   'っ': 2,
#   'て': 2,
#   'な': 1,
#   'ば': 3,
#   'び': 4,
#   'ぶ': 1,
#   'ぼ': 1,
#   'ま': 6,
#   'み': 8,
#   'む': 7,
#   'め': 5,
#   'り': 1,
#   'る': 22,
#   'れ': 6},
#  'ず': {'か': 6,
#   'き': 2,
#   'く': 2,
#   'け': 3,
#   'さ': 1,
#   'し': 3,
#   'す': 2,
#   'つ': 2,
#   'ね': 2,
#   'の': 1,
#   'ひょ': 1,
#   'ぶ': 1,
#   'ま': 2,
#   'む': 3,
#   'め': 1,
#   'る': 15,
#   'れ': 3},
#  'せ': {'お': 1,
#   'か': 1,
#   'ぎ': 1,
#   'ぐ': 2,
#   'け': 1,
#   'じ': 2,
#   'た': 1,
#   'だ': 1,
#   'と': 1,
#   'な': 1,
#   'び': 2,
#   'め': 3,
#   'も': 1,
#   'や': 1,
#   'る': 21,
#   'ろ': 1,
#   'わ': 1,
#   'ん': 1},
#  'ぜ': {'せ': 1, 'ひ': 2, 'る': 3},
#  'そ': {'い': 4,
#   'う': 6,
#   'え': 1,
#   'か': 2,
#   'く': 1,
#   'ぐ': 1,
#   'ざ': 1,
#   'し': 3,
#   'しょ': 1,
#   'せ': 1,
#   'ち': 1,
#   'っ': 1,
#   'つ': 1,
#   'の': 5,
#   'び': 1,
#   'ふ': 1,
#   'ぶ': 1,
#   'ぼ': 2,
#   'ま': 2,
#   'め': 1,
#   'ら': 2,
#   'り': 1,
#   'る': 1,
#   'れ': 4,
#   'ろ': 1,
#   'わ': 1},
#  'ぞ': {'い': 1, 'え': 1, 'く': 3, 'な': 1, 'ま': 1, 'み': 1, 'む': 3, 'よ': 1},
#  'た': {'い': 12,
#   'う': 3,
#   'え': 9,
#   'お': 1,
#   'か': 3,
#   'が': 3,
#   'き': 1,
#   'ぎ': 1,
#   'く': 3,
#   'ぐ': 1,
#   'げ': 1,
#   'こ': 1,
#   'ご': 2,
#   'し': 7,
#   'しょ': 1,
#   'じ': 1,
#   'す': 8,
#   'だ': 1,
#   'ち': 3,
#   'っ': 1,
#   'つ': 9,
#   'づ': 3,
#   'て': 5,
#   'ど': 2,
#   'に': 2,
#   'は': 1,
#   'び': 2,
#   'ぶ': 1,
#   'べ': 2,
#   'ほ': 1,
#   'ぼ': 1,
#   'ま': 6,
#   'み': 2,
#   'む': 3,
#   'め': 7,
#   'よ': 2,
#   'ら': 2,
#   'り': 10,
#   'る': 9,
#   'れ': 3,
#   'わ': 1},
#  'だ': {'い': 2,
#   'う': 1,
#   'え': 2,
#   'か': 3,
#   'が': 2,
#   'き': 1,
#   'きょ': 1,
#   'ぎ': 1,
#   'く': 3,
#   'け': 3,
#   'げ': 1,
#   'さ': 3,
#   'し': 10,
#   'す': 16,
#   'た': 1,
#   'ち': 4,
#   'っ': 1,
#   'つ': 4,
#   'づ': 1,
#   'て': 5,
#   'と': 1,
#   'ま': 1,
#   'め': 2,
#   'や': 1,
#   'ら': 1,
#   'り': 1,
#   'る': 2,
#   'れ': 1},
#  'ち': {'あ': 8,
#   'い': 4,
#   'え': 2,
#   'お': 2,
#   'か': 5,
#   'が': 1,
#   'き': 2,
#   'きゅ': 1,
#   'く': 1,
#   'け': 2,
#   'げ': 1,
#   'こ': 3,
#   'し': 2,
#   'じ': 4,
#   'じゅ': 1,
#   'じょ': 2,
#   'ず': 2,
#   'せ': 1,
#   'そ': 3,
#   'た': 1,
#   'だ': 1,
#   'つ': 2,
#   'て': 2,
#   'ど': 6,
#   'に': 2,
#   'の': 2,
#   'は': 1,
#   'ば': 4,
#   'ぶ': 2,
#   'へ': 1,
#   'べ': 2,
#   'ほ': 1,
#   'み': 1,
#   'め': 2,
#   'も': 1,
#   'ゃ': 2,
#   'や': 1,
#   'よ': 5,
#   'ら': 3,
#   'り': 2,
#   'りゅ': 1,
#   'りょ': 1,
#   'る': 5,
#   'れ': 1,
#   'ろ': 1,
#   'わ': 1},
#  'ちゃ': {'い': 1, 'く': 1, 'の': 2, 'わ': 1},
#  'ちょ': {'き': 1, 'しゃ': 1, 'しょ': 1, 'ぞ': 1, 'ち': 1, 'め': 1},
#  'ぢ': {'ま': 1, 'む': 1, 'め': 1, 'れ': 1},
#  'っ': {'か': 6,
#   'き': 1,
#   'きゅ': 1,
#   'く': 4,
#   'け': 1,
#   'こ': 5,
#   'さ': 1,
#   'し': 2,
#   'しょ': 1,
#   'す': 2,
#   'そ': 1,
#   'ち': 2,
#   'ちょ': 1,
#   'つ': 7,
#   'て': 9,
#   'と': 4,
#   'ぱ': 7,
#   'ぷ': 1,
#   'ぺ': 1,
#   'ぽ': 3},
#  'った': {'え': 2, 'く': 1},
#  'っと': {'い': 2, 'ぶ': 1, 'も': 2},
#  'っぱ': {'ら': 1},
#  'つ': {'あ': 1,
#   'い': 8,
#   'え': 4,
#   'お': 2,
#   'か': 8,
#   'が': 2,
#   'き': 14,
#   'ぎ': 5,
#   'ぎょ': 3,
#   'く': 14,
#   'ぐ': 7,
#   'け': 17,
#   'げ': 3,
#   'ご': 3,
#   'し': 2,
#   'じ': 3,
#   'じゅ': 1,
#   'じょ': 3,
#   'す': 3,
#   'ぜ': 2,
#   'ぞ': 3,
#   'だ': 3,
#   'っ': 2,
#   'つ': 1,
#   'て': 1,
#   'で': 1,
#   'ど': 5,
#   'な': 3,
#   'に': 2,
#   'は': 1,
#   'ば': 1,
#   'ひ': 1,
#   'び': 1,
#   'びょ': 1,
#   'ぶ': 1,
#   'べ': 1,
#   'ぼ': 5,
#   'ま': 5,
#   'み': 2,
#   'む': 2,
#   'め': 5,
#   'も': 3,
#   'や': 4,
#   'よ': 5,
#   'ら': 2,
#   'り': 6,
#   'りょ': 4,
#   'る': 9,
#   'れ': 3,
#   'ろ': 1},
#  'づ': {'き': 2, 'く': 5, 'け': 6},
#  'て': {'あ': 5,
#   'い': 1,
#   'お': 1,
#   'か': 1,
#   'が': 4,
#   'ぎ': 1,
#   'く': 1,
#   'ご': 2,
#   'じ': 2,
#   'じゅ': 1,
#   'じょ': 1,
#   'ちょ': 1,
#   'ぢ': 1,
#   'つ': 4,
#   'な': 2,
#   'ぬ': 1,
#   'は': 4,
#   'び': 1,
#   'ぶ': 1,
#   'ほ': 1,
#   'ま': 4,
#   'も': 2,
#   'ら': 1,
#   'り': 1,
#   'る': 15,
#   'わ': 1},
#  'で': {'あ': 4,
#   'い': 3,
#   'か': 2,
#   'き': 6,
#   'く': 1,
#   'ぐ': 1,
#   'た': 2,
#   'と': 1,
#   'な': 1,
#   'に': 3,
#   'は': 1,
#   'ま': 1,
#   'む': 2,
#   'も': 2,
#   'る': 4},
#  'と': {'い': 5,
#   'う': 3,
#   'え': 3,
#   'か': 4,
#   'が': 2,
#   'く': 4,
#   'ぐ': 1,
#   'け': 3,
#   'げ': 2,
#   'こ': 2,
#   'ご': 1,
#   'さ': 1,
#   'ざ': 1,
#   'し': 3,
#   'しょ': 2,
#   'じ': 3,
#   'じょ': 1,
#   'す': 2,
#   'た': 1,
#   'だ': 2,
#   'ち': 1,
#   'ちゅ': 1,
#   'っ': 1,
#   'つ': 3,
#   'づ': 3,
#   'と': 1,
#   'ど': 1,
#   'な': 2,
#   'に': 4,
#   'ば': 4,
#   'び': 2,
#   'ぶ': 2,
#   'ほ': 1,
#   'ま': 8,
#   'む': 1,
#   'め': 16,
#   'も': 8,
#   'や': 1,
#   'ら': 1,
#   'り': 33,
#   'る': 11,
#   'れ': 1},
#  'ど': {'い': 3,
#   'う': 1,
#   'か': 1,
#   'く': 2,
#   'ぐ': 1,
#   'け': 3,
#   'さ': 1,
#   'す': 4,
#   'だ': 1,
#   'て': 1,
#   'な': 1,
#   'に': 1,
#   'ひょ': 1,
#   'ぼ': 1,
#   'ま': 1,
#   'む': 1,
#   'よ': 2,
#   'り': 4,
#   'りょ': 1,
#   'る': 5,
#   'れ': 1,
#   'わ': 1},
#  'な': {'い': 19,
#   'う': 10,
#   'え': 5,
#   'が': 3,
#   'く': 10,
#   'ぐ': 1,
#   'げ': 3,
#   'さ': 4,
#   'し': 8,
#   'じ': 1,
#   'す': 6,
#   'だ': 1,
#   'つ': 1,
#   'づ': 3,
#   'で': 1,
#   'の': 2,
#   'び': 5,
#   'ふ': 1,
#   'ぶ': 1,
#   'ま': 1,
#   'み': 4,
#   'む': 1,
#   'め': 2,
#   'も': 1,
#   'や': 1,
#   'よ': 1,
#   'ら': 4,
#   'り': 4,
#   'る': 15,
#   'れ': 8,
#   'わ': 1},
#  'に': {'あ': 2,
#   'い': 1,
#   'え': 1,
#   'か': 5,
#   'が': 1,
#   'げ': 3,
#   'ざ': 1,
#   'し': 1,
#   'た': 1,
#   'づ': 1,
#   'な': 2,
#   'ぶ': 1,
#   'も': 3,
#   'よ': 2,
#   'る': 2},
#  'ぬ': {'う': 1, 'か': 1, 'く': 2, 'ぐ': 1, 'け': 2, 'ら': 1, 'る': 1, 'れ': 2},
#  'ね': {'う': 1,
#   'か': 1,
#   'き': 1,
#   'く': 1,
#   'じ': 3,
#   'だ': 1,
#   'て': 1,
#   'に': 1,
#   'び': 1,
#   'ぼ': 2,
#   'ま': 3,
#   'も': 1,
#   'る': 10},
#  'の': {'あ': 1,
#   'い': 1,
#   'う': 3,
#   'え': 1,
#   'お': 3,
#   'か': 2,
#   'が': 1,
#   'ぐ': 2,
#   'け': 1,
#   'こ': 2,
#   'ご': 2,
#   'さ': 2,
#   'し': 3,
#   'じょ': 2,
#   'す': 1,
#   'ず': 2,
#   'せ': 2,
#   'た': 2,
#   'っ': 1,
#   'つ': 1,
#   'で': 1,
#   'ど': 1,
#   'な': 1,
#   'ば': 2,
#   'ひ': 2,
#   'び': 2,
#   'べ': 2,
#   'ほ': 1,
#   'ま': 6,
#   'み': 5,
#   'む': 3,
#   'も': 1,
#   'ゆ': 1,
#   'り': 5,
#   'る': 5},
#  'は': {'あ': 1,
#   'い': 1,
#   'う': 1,
#   'え': 2,
#   'お': 1,
#   'か': 1,
#   'が': 2,
#   'き': 2,
#   'く': 3,
#   'ぐ': 2,
#   'け': 1,
#   'げ': 1,
#   'さ': 1,
#   'じ': 2,
#   'ず': 1,
#   'そ': 1,
#   'た': 2,
#   'だ': 2,
#   'て': 2,
#   'で': 1,
#   'ね': 2,
#   'へ': 1,
#   'ま': 2,
#   'み': 1,
#   'め': 2,
#   'や': 1,
#   'ら': 1,
#   'り': 2,
#   'る': 2,
#   'れ': 4},
#  'ば': {'あ': 1,
#   'い': 1,
#   'う': 1,
#   'か': 4,
#   'く': 1,
#   'け': 1,
#   'しょ': 1,
#   'す': 4,
#   'づ': 1,
#   'む': 1,
#   'め': 1,
#   'ら': 1,
#   'り': 2,
#   'る': 5,
#   'れ': 1},
#  'ぱ': {'い': 1, 'り': 1, 'る': 2},
#  'ひ': {'あ': 1,
#   'え': 1,
#   'か': 4,
#   'が': 2,
#   'き': 11,
#   'きょ': 1,
#   'く': 4,
#   'け': 1,
#   'げ': 1,
#   'こ': 4,
#   'ご': 1,
#   'さ': 1,
#   'しょ': 1,
#   'じゅ': 1,
#   'じょ': 2,
#   'っ': 8,
#   'づ': 1,
#   'て': 1,
#   'と': 1,
#   'ど': 1,
#   'な': 2,
#   'に': 2,
#   'の': 3,
#   'は': 1,
#   'ば': 1,
#   'ひょ': 1,
#   'び': 1,
#   'ふ': 1,
#   'み': 1,
#   'め': 1,
#   'や': 3,
#   'よ': 1,
#   'り': 1,
#   'りょ': 1,
#   'れ': 1,
#   'ろ': 1},
#  'び': {'え': 2,
#   'か': 3,
#   'き': 4,
#   'きょ': 1,
#   'く': 3,
#   'こ': 1,
#   'さ': 1,
#   'し': 2,
#   'しょ': 1,
#   'じ': 1,
#   'じゅ': 2,
#   'た': 1,
#   'だ': 2,
#   'つ': 3,
#   'と': 1,
#   'に': 1,
#   'みょ': 1,
#   'や': 1,
#   'よ': 1,
#   'ら': 2,
#   'りょ': 1,
#   'る': 8,
#   'れ': 1,
#   'わ': 2},
#  'ふ': {'あ': 1,
#   'い': 1,
#   'う': 1,
#   'え': 2,
#   'か': 3,
#   'き': 4,
#   'きゅ': 1,
#   'きょ': 1,
#   'く': 2,
#   'け': 5,
#   'こ': 2,
#   'ご': 2,
#   'さ': 2,
#   'ざ': 1,
#   'し': 3,
#   'しょ': 1,
#   'じ': 4,
#   'じゅ': 1,
#   'せ': 1,
#   'そ': 1,
#   'ぞ': 2,
#   'た': 1,
#   'だ': 1,
#   'ちょ': 1,
#   'つ': 2,
#   'と': 3,
#   'ど': 1,
#   'に': 1,
#   'は': 1,
#   'ひょ': 1,
#   'ふ': 1,
#   'へ': 2,
#   'べ': 1,
#   'ぼ': 1,
#   'ま': 2,
#   'む': 1,
#   'め': 1,
#   'や': 2,
#   'よ': 1,
#   'り': 5,
#   'りょ': 2,
#   'る': 2,
#   'れ': 2,
#   'ろ': 4},
#  'ぶ': {'い': 2,
#   'か': 1,
#   'き': 1,
#   'く': 1,
#   'さ': 3,
#   'し': 3,
#   'しゅ': 1,
#   'じ': 1,
#   'じょ': 1,
#   'す': 1,
#   'せ': 1,
#   'そ': 1,
#   'た': 1,
#   'ちょ': 1,
#   'つ': 1,
#   'と': 1,
#   'な': 2,
#   'ぬ': 1,
#   'ひ': 1,
#   'ぶ': 3,
#   'む': 1,
#   'も': 1,
#   'ら': 1,
#   'り': 3,
#   'りょ': 1,
#   'る': 5,
#   'れ': 3},
#  'へ': {'ら': 1, 'る': 2},
#  'べ': {'く': 1, 'て': 1, 'も': 1, 'り': 1, 'る': 9},
#  'ほ': {'い': 1,
#   'え': 1,
#   'お': 1,
#   'か': 2,
#   'きゅ': 1,
#   'きょ': 1,
#   'け': 2,
#   'げ': 1,
#   'ご': 1,
#   'し': 2,
#   'しゅ': 1,
#   'しょ': 3,
#   'じゅ': 1,
#   'じょ': 1,
#   'す': 1,
#   'そ': 2,
#   'ぞ': 1,
#   'ど': 1,
#   'ぼ': 1,
#   'め': 1,
#   'よ': 1,
#   'り': 1,
#   'りょ': 1,
#   'る': 2},
#  'ぼ': {'え': 2,
#   'き': 1,
#   'こ': 1,
#   'し': 1,
#   'しゅ': 1,
#   'す': 3,
#   'む': 1,
#   'ら': 1,
#   'り': 1,
#   'る': 6,
#   'れ': 2},
#  'ぽ': {'い': 2},
#  'ま': {'い': 7,
#   'う': 8,
#   'え': 5,
#   'か': 3,
#   'が': 1,
#   'き': 1,
#   'く': 6,
#   'ぐ': 3,
#   'け': 4,
#   'げ': 1,
#   'こ': 1,
#   'さ': 2,
#   'ざ': 2,
#   'し': 14,
#   'じ': 2,
#   'す': 14,
#   'ず': 2,
#   'せ': 2,
#   'ぜ': 3,
#   'た': 1,
#   'だ': 1,
#   'ち': 9,
#   'っ': 6,
#   'つ': 1,
#   'で': 2,
#   'ど': 1,
#   'な': 1,
#   'に': 4,
#   'ひ': 1,
#   'ぶ': 1,
#   'べ': 1,
#   'ま': 3,
#   'み': 1,
#   'も': 2,
#   'や': 2,
#   'ら': 1,
#   'り': 11,
#   'る': 40,
#   'れ': 4,
#   'ん': 3},
#  'み': {'あ': 6,
#   'え': 1,
#   'お': 4,
#   'か': 7,
#   'き': 2,
#   'く': 1,
#   'ぐ': 1,
#   'こ': 4,
#   'ご': 1,
#   'さ': 1,
#   'じ': 1,
#   'じゅ': 1,
#   'す': 1,
#   'せ': 4,
#   'そ': 1,
#   'た': 2,
#   'だ': 1,
#   'ち': 2,
#   'ぢ': 1,
#   'っ': 1,
#   'つ': 4,
#   'て': 1,
#   'と': 1,
#   'な': 3,
#   'に': 1,
#   'の': 2,
#   'は': 1,
#   'ぶ': 2,
#   'ほ': 1,
#   'ま': 6,
#   'も': 2,
#   'ら': 1,
#   'りょ': 2,
#   'る': 5,
#   'れ': 1,
#   'わ': 1},
#  'む': {'い': 5,
#   'か': 2,
#   'き': 1,
#   'く': 7,
#   'け': 3,
#   'げ': 1,
#   'こ': 2,
#   'ご': 1,
#   'し': 2,
#   'しょ': 2,
#   'じ': 1,
#   'じゃ': 1,
#   'じゅ': 1,
#   'す': 2,
#   'せ': 1,
#   'た': 2,
#   'だ': 3,
#   'ち': 1,
#   'ちゃ': 2,
#   'ちゅ': 1,
#   'ね': 1,
#   'の': 1,
#   'や': 1,
#   'よ': 1,
#   'り': 2,
#   'りょ': 2,
#   'る': 3,
#   'れ': 1,
#   'ろ': 1,
#   'を': 1},
#  'め': {'い': 1,
#   'う': 1,
#   'か': 1,
#   'き': 3,
#   'こ': 1,
#   'さ': 1,
#   'ざ': 2,
#   'し': 3,
#   'じ': 1,
#   'す': 3,
#   'た': 1,
#   'だ': 1,
#   'つ': 1,
#   'て': 4,
#   'で': 2,
#   'に': 1,
#   'ぼ': 1,
#   'ま': 1,
#   'や': 1,
#   'ら': 1,
#   'る': 66},
#  'も': {'い': 8,
#   'う': 2,
#   'え': 1,
#   'か': 2,
#   'が': 1,
#   'け': 1,
#   'さ': 1,
#   'し': 9,
#   'た': 1,
#   'だ': 1,
#   'ち': 5,
#   'っ': 1,
#   'つ': 3,
#   'て': 2,
#   'な': 3,
#   'に': 2,
#   'は': 1,
#   'ば': 1,
#   'ほ': 1,
#   'む': 1,
#   'め': 1,
#   'や': 1,
#   'よ': 1,
#   'ら': 1,
#   'り': 3,
#   'る': 6,
#   'れ': 1,
#   'わ': 1,
#   'ん': 2},
#  'ゃ': {'る': 1, 'ん': 3},
#  'や': {'い': 4,
#   'う': 1,
#   'か': 14,
#   'が': 2,
#   'く': 6,
#   'ぐ': 1,
#   'け': 3,
#   'こ': 1,
#   'さ': 1,
#   'し': 5,
#   'じ': 1,
#   'す': 7,
#   'せ': 2,
#   'た': 1,
#   'ち': 1,
#   'っ': 2,
#   'と': 1,
#   'ぬ': 1,
#   'ね': 1,
#   'ぶ': 1,
#   'ま': 3,
#   'み': 1,
#   'む': 6,
#   'め': 3,
#   'ゆ': 1,
#   'り': 2,
#   'る': 1},
#  'ゆ': {'い': 1,
#   'か': 1,
#   'き': 2,
#   'く': 1,
#   'け': 1,
#   'げ': 1,
#   'さ': 1,
#   'しゅ': 1,
#   'そ': 1,
#   'だ': 1,
#   'で': 1,
#   'にゅ': 1,
#   'の': 1,
#   'み': 1,
#   'む': 1,
#   'ら': 1,
#   'れ': 1},
#  'よ': {'あ': 1,
#   'い': 6,
#   'う': 4,
#   'か': 2,
#   'き': 3,
#   'きょ': 1,
#   'ぎ': 2,
#   'ぐ': 1,
#   'け': 1,
#   'こ': 1,
#   'さ': 1,
#   'し': 2,
#   'しゅ': 1,
#   'す': 1,
#   'せ': 3,
#   'そ': 3,
#   'ち': 1,
#   'っ': 2,
#   'つ': 1,
#   'て': 1,
#   'と': 1,
#   'な': 1,
#   'の': 1,
#   'び': 5,
#   'ふ': 2,
#   'ぶ': 3,
#   'ほ': 2,
#   'ぼ': 2,
#   'ま': 1,
#   'み': 2,
#   'む': 1,
#   'め': 1,
#   'や': 1,
#   'ゆ': 1,
#   'ら': 1,
#   'り': 4,
#   'る': 8},
#  'ら': {'い': 17,
#   'う': 12,
#   'え': 5,
#   'か': 9,
#   'が': 4,
#   'き': 2,
#   'ぎ': 1,
#   'く': 4,
#   'ぐ': 2,
#   'げ': 1,
#   'さ': 1,
#   'し': 8,
#   'す': 15,
#   'ず': 4,
#   'せ': 2,
#   'た': 2,
#   'だ': 1,
#   'っ': 3,
#   'づ': 1,
#   'な': 3,
#   'に': 2,
#   'ね': 1,
#   'び': 2,
#   'ぶ': 2,
#   'べ': 6,
#   'ま': 2,
#   'み': 1,
#   'む': 5,
#   'め': 3,
#   'わ': 3},
#  'り': {'あ': 10,
#   'い': 2,
#   'え': 1,
#   'か': 16,
#   'が': 7,
#   'き': 4,
#   'く': 2,
#   'ぐ': 3,
#   'け': 1,
#   'こ': 6,
#   'ご': 1,
#   'ざ': 2,
#   'し': 4,
#   'じゅ': 1,
#   'す': 1,
#   'せ': 1,
#   'そ': 2,
#   'た': 2,
#   'だ': 7,
#   'つ': 2,
#   'て': 1,
#   'で': 1,
#   'と': 4,
#   'ど': 1,
#   'な': 1,
#   'に': 2,
#   'の': 2,
#   'ば': 1,
#   'ひ': 2,
#   'び': 2,
#   'ま': 4,
#   'み': 3,
#   'も': 4,
#   'ゆ': 2,
#   'よ': 2,
#   'る': 5,
#   'れ': 1,
#   'ろ': 1,
#   'わ': 2},
#  'りょ': {'か': 2, 'け': 1, 'こ': 1},
#  'る': {'い': 11,
#   'う': 1,
#   'え': 1,
#   'か': 1,
#   'が': 1,
#   'く': 2,
#   'ご': 2,
#   'し': 5,
#   'す': 6,
#   'た': 2,
#   'だ': 1,
#   'っ': 1,
#   'で': 1,
#   'と': 3,
#   'に': 1,
#   'ね': 1,
#   'べ': 1,
#   'ま': 3,
#   'み': 1,
#   'む': 2,
#   'め': 2,
#   'も': 1,
#   'や': 2,
#   'わ': 1},
#  'れ': {'い': 1,
#   'か': 1,
#   'ぐ': 1,
#   'し': 2,
#   'ち': 2,
#   'つ': 1,
#   'な': 2,
#   'め': 1,
#   'も': 3,
#   'ゆ': 1,
#   'ら': 1,
#   'る': 66,
#   'わ': 1},
#  'ろ': {'あ': 1,
#   'い': 9,
#   'う': 3,
#   'え': 4,
#   'か': 2,
#   'が': 6,
#   'き': 1,
#   'く': 1,
#   'け': 1,
#   'げ': 1,
#   'こ': 1,
#   'さ': 1,
#   'し': 5,
#   'じ': 1,
#   'す': 4,
#   'づ': 1,
#   'で': 1,
#   'ば': 2,
#   'び': 2,
#   'ぶ': 1,
#   'ぼ': 3,
#   'ま': 1,
#   'み': 3,
#   'め': 1},
#  'わ': {'い': 6,
#   'う': 3,
#   'え': 4,
#   'か': 4,
#   'が': 2,
#   'き': 1,
#   'ぎ': 2,
#   'く': 4,
#   'ぐ': 1,
#   'け': 4,
#   'し': 9,
#   'す': 9,
#   'ず': 1,
#   'せ': 13,
#   'た': 1,
#   'だ': 1,
#   'ち': 1,
#   'て': 1,
#   'ば': 1,
#   'び': 2,
#   'ふ': 2,
#   'ぶ': 1,
#   'ま': 2,
#   'め': 2,
#   'や': 1,
#   'ら': 5,
#   'り': 10,
#   'る': 26,
#   'れ': 5,
#   'わ': 1},
#  'を': {'え': 1, 'つ': 1},
#  'ん': {'あ': 1,
#   'い': 14,
#   'え': 5,
#   'か': 50,
#   'が': 17,
#   'き': 20,
#   'きゃ': 1,
#   'きゅ': 8,
#   'きょ': 16,
#   'ぎ': 6,
#   'ぎょ': 6,
#   'く': 3,
#   'ぐ': 1,
#   'け': 17,
#   'げ': 17,
#   'こ': 35,
#   'ご': 17,
#   'さ': 15,
#   'ざ': 9,
#   'し': 23,
#   'しゃ': 7,
#   'しゅ': 26,
#   'しょ': 16,
#   'じ': 27,
#   'じゃ': 4,
#   'じゅ': 5,
#   'じょ': 18,
#   'す': 15,
#   'ず': 7,
#   'せ': 37,
#   'ぜ': 9,
#   'そ': 18,
#   'ぞ': 10,
#   'た': 19,
#   'だ': 17,
#   'ち': 14,
#   'ちゃ': 1,
#   'ちゅ': 3,
#   'ちょ': 10,
#   'づ': 2,
#   'て': 21,
#   'で': 6,
#   'と': 23,
#   'ど': 16,
#   'な': 8,
#   'に': 9,
#   'にゅ': 3,
#   'ね': 6,
#   'の': 5,
#   'は': 1,
#   'ば': 8,
#   'ぱ': 14,
#   'ひ': 1,
#   'び': 4,
#   'びょ': 1,
#   'ぴ': 2,
#   'ふ': 1,
#   'ぶ': 15,
#   'ぷ': 4,
#   'べ': 3,
#   'ぺ': 2,
#   'ぼ': 11,
#   'ぽ': 9,
#   'ま': 4,
#   'み': 3,
#   'みゃ': 2,
#   'みょ': 1,
#   'む': 3,
#   'め': 9,
#   'も': 4,
#   'や': 6,
#   'ゆ': 5,
#   'よ': 12,
#   'ら': 11,
#   'り': 11,
#   'りゃ': 1,
#   'りゅ': 1,
#   'りょ': 15,
#   'る': 3,
#   'れ': 8,
#   'ろ': 7,
#   'わ': 6},
#  'ェ': {'ッ': 1},
#  'ゴ': {'ム': 1},
#  'ジ': {'ェ': 1},
#  'ッ': {'ト': 1},
#  'ト': {'き': 1},
#  'マ': {'じ': 1},
#  'ロ': {'ー': 1},
#  'ー': {'マ': 1}}

# %%
key_set = set(previousPronunciationEndCurrentPronunciationStart.keys())

for key in key_set:
    key_set = key_set | set(previousPronunciationEndCurrentPronunciationStart.get(key, dict()).keys())

# %%
key_set = key_set - {'ェ', 'ゴ', 'ジ', 'ッ', 'ト', 'マ', 'ム', 'ロ', 'ー'}

# %%
key_list = list(key_set)
key_list
# Out:
# ['み',
#  'ま',
#  'ず',
#  'を',
#  'りゃ',
#  'ぞ',
#  'っぱ',
#  'ぎゅ',
#  'ちゅ',
#  'り',
#  'ん',
#  'は',
#  'へ',
#  'き',
#  'く',
#  'みゃ',
#  'ふ',
#  'だ',
#  'な',
#  'りゅ',
#  'る',
#  'ちゃ',
#  'びょ',
#  'ね',
#  'START',
#  'ち',
#  'にょ',
#  'じょ',
#  'よ',
#  'む',
#  'ほ',
#  'し',
#  'ひ',
#  'しょ',
#  'ひゃ',
#  'ろ',
#  'て',
#  'ぎょ',
#  'せ',
#  'ぎ',
#  'ぜ',
#  'ぺ',
#  'こ',
#  'ぼ',
#  'づ',
#  'ご',
#  'ゆ',
#  'しゃ',
#  'きょ',
#  'じゃ',
#  'ぢ',
#  'い',
#  'め',
#  'つ',
#  'にゅ',
#  'さ',
#  'ぱ',
#  'れ',
#  'ゃ',
#  'え',
#  'きゅ',
#  'ば',
#  'ぶ',
#  'ぷ',
#  'ぐ',
#  'も',
#  'ぴ',
#  'の',
#  'っ',
#  'みょ',
#  'す',
#  'と',
#  'ぽ',
#  'ぬ',
#  'あ',
#  'じ',
#  'け',
#  'ら',
#  'で',
#  'っと',
#  'そ',
#  'しゅ',
#  'ざ',
#  'げ',
#  'ちょ',
#  'わ',
#  'きゃ',
#  'か',
#  'ひょ',
#  'に',
#  'った',
#  'や',
#  'う',
#  'が',
#  'ど',
#  'た',
#  'りょ',
#  'べ',
#  'ぎゃ',
#  'お',
#  'じゅ',
#  'び']

# %%
import numpy as np

# %%
heatmap = np.matrix(np.arange(10404).reshape((102, 102)))

# %%
i = 0 # row
for keyi in key_list: # row
    j = 0 # column
    for keyj in key_list: # column
        heatmap[i, j] = previousPronunciationEndCurrentPronunciationStart.get(keyi, dict()).get(keyj, 0)
        j += 1
    i += 1

# %%
import matplotlib.pyplot as plt

# %%
row_sums = heatmap.sum(axis=1)
row_sums[row_sums == 0] = 1
normalized_heatmap = heatmap / row_sums

# %%
col_sums = normalized_heatmap.sum(axis=0)
col_sums[col_sums == 0] = 1
dn_heatmap = normalized_heatmap / col_sums

# %%
col_sums = heatmap.sum(axis=0)
col_sums[col_sums == 0] = 1
ddn_heatmap = heatmap / col_sums
row_sums = ddn_heatmap.sum(axis=1)
row_sums[row_sums == 0] = 1
ddn_heatmap = ddn_heatmap / row_sums

# %%
######
import pandas as pd

# %%
normalized_df = pd.DataFrame(normalized_heatmap)

# %%
normalized_df.columns = key_list
normalized_df.index = key_list

# %%
#plt.plot(normalized_df)
#plt.show()
normalized_df.transpose()[[60]]
# Out:
#         きゅ
# み      0.0
# ま      0.0
# ず      0.0
# を      0.0
# りゃ     0.0
# ぞ      0.0
# っぱ     0.0
# ぎゅ     0.0
# ちゅ     0.0
# り      0.0
# ん      0.0
# は      0.0
# へ      0.0
# き      0.0
# く      0.0
# みゃ     0.0
# ふ      0.0
# だ      0.0
# な      0.0
# りゅ     0.0
# る      0.0
# ちゃ     0.0
# びょ     0.0
# ね      0.0
# START  0.0
# ち      0.0
# にょ     0.0
# じょ     0.0
# よ      0.0
# む      0.0
# ...    ...
# ぽ      0.0
# ぬ      0.0
# あ      0.0
# じ      0.0
# け      0.0
# ら      0.0
# で      0.0
# っと     0.0
# そ      0.0
# しゅ     0.0
# ざ      0.0
# げ      0.0
# ちょ     0.0
# わ      0.0
# きゃ     0.0
# か      0.0
# ひょ     0.0
# に      0.0
# った     0.0
# や      0.0
# う      0.0
# が      0.0
# ど      0.0
# た      0.0
# りょ     0.0
# べ      0.0
# ぎゃ     0.0
# お      0.0
# じゅ     0.0
# び      0.0
#
# [102 rows x 1 columns]

# %%
normalized_df[[60]]
# Out:
#              きゅ
# み      0.000000
# ま      0.000000
# ず      0.000000
# を      0.000000
# りゃ     0.000000
# ぞ      0.000000
# っぱ     0.000000
# ぎゅ     0.000000
# ちゅ     0.000000
# り      0.000000
# ん      0.009627
# は      0.000000
# へ      0.000000
# き      0.000000
# く      0.003086
# みゃ     0.000000
# ふ      0.012500
# だ      0.000000
# な      0.000000
# りゅ     0.000000
# る      0.000000
# ちゃ     0.000000
# びょ     0.000000
# ね      0.000000
# START  0.004632
# ち      0.009901
# にょ     0.000000
# じょ     0.000000
# よ      0.000000
# む      0.000000
# ...         ...
# ぽ      0.000000
# ぬ      0.000000
# あ      0.000000
# じ      0.000000
# け      0.000000
# ら      0.000000
# で      0.000000
# っと     0.000000
# そ      0.000000
# しゅ     0.000000
# ざ      0.000000
# げ      0.000000
# ちょ     0.000000
# わ      0.000000
# きゃ     0.000000
# か      0.000000
# ひょ     0.000000
# に      0.000000
# った     0.000000
# や      0.000000
# う      0.007511
# が      0.000000
# ど      0.000000
# た      0.000000
# りょ     0.000000
# べ      0.000000
# ぎゃ     0.000000
# お      0.000000
# じゅ     0.000000
# び      0.000000
#
# [102 rows x 1 columns]

# %%
plt.figure(figsize=(50, 50))
plt.imshow(normalized_df.transpose())
plt.colorbar()
plt.xlabel("Previous")
plt.ylabel("Current")
plt.title('Pronunciation Heatmap (col normalized)')
plt.show()

# %%
plt.imshow(ddn_heatmap)
plt.colorbar()
plt.xlabel("Current")
plt.ylabel("Previous")
plt.title('Pronunciation Heatmap (col then row normalized)')
plt.show()

# %%
plt.imshow(dn_heatmap)
plt.colorbar()
plt.xlabel("Current")
plt.ylabel("Previous")
plt.title('Pronunciation Heatmap (row then col normalized)')
plt.show()

# %%
plt.imshow(heatmap)
plt.colorbar()
plt.xlabel("Current")
plt.ylabel("Previous")
plt.title('Pronunciation Heatmap (nonnormalized)')
plt.show()

# %%
#plt.figure(figsize=(100, 100))
#plt.xticks(range(len(key_set)), key_set, size='large')
#plt.yticks(range(len(key_set)), key_set, size='large')
plt.imshow(normalized_heatmap)
plt.colorbar()
plt.xlabel("Current")
plt.ylabel("Previous")
plt.title('Pronunciation Heatmap (row normalized)')
plt.show()

# %%
normalized_heatmap[25:75,50]
# Out:
# matrix([[ 0.05454545],
#         [ 0.06849315],
#         [ 0.60869565],
#         [ 0.06493506],
#         [ 0.        ],
#         [ 0.20353982],
#         [ 0.69230769],
#         [ 0.5       ],
#         [ 0.        ],
#         [ 0.11627907],
#         [ 0.5       ],
#         [ 0.        ],
#         [ 0.09375   ],
#         [ 0.25      ],
#         [ 0.48837209],
#         [ 0.10666667],
#         [ 0.25      ],
#         [ 0.025     ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.06451613],
#         [ 0.09090909],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.68041237],
#         [ 0.        ],
#         [ 0.04950495],
#         [ 0.        ],
#         [ 0.07236842],
#         [ 0.02469136],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.04166667],
#         [ 0.04      ],
#         [ 0.23076923],
#         [ 0.        ],
#         [ 0.17391304],
#         [ 0.        ],
#         [ 0.07407407],
#         [ 0.79518072],
#         [ 0.19230769],
#         [ 0.        ],
#         [ 0.3       ],
#         [ 0.6407767 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]])

# %%
def occurencesToPercentages(dict_of_occurences):
    """Input: A single dictionary of occurences as values for some key
Output: A single dictionary of percentages as values for some key"""
    sum = 0
    for (_, value) in dict_of_occurences.items(): sum += value
    if sum != 0:
        for (key, value) in dict_of_occurences.items():
            dict_of_occurences[key] = value / sum
    #dict_of_occurences = sorted(dict_of_occurences.items(), key=lambda kv: kv[1], reverse=True)
    return dict_of_occurences

# %%
getProbabilities('人',allKanji=False)
# Out:
# [('ひと', 1.0), ('にん', 0.0), ('びと', 0.0), ('り', 0.0), ('じん', 0.0)]

# %%
def globalBayesTheorem(startDict, endDict, startKeys, endKeys, startArg, endArg):
    """Inputs: dictionary_list, keys, argument_list
Outputs: Sorted list of probabilities
This function follows the Bayesian Theorem that as defined
in the following paper https://dl.dropboxusercontent.com/u/62448029/DAG_for_email.pdf
Basic formula:
P(pronunciation|feature1, feature2, ...) =
P(pronunciation)*P(feature1|pronunciation)*P(feature2|pronunciation)* ...
Arguments is synonymous with features in this example
"""
    startReturnDict = dict()
    endReturnDict = dict()
    for key in startKeys:
        for i in range(len(startArg)):
            if i == 0:
                startReturnDict[key] = startDict[0].get(key, 0)
            else:
                startReturnDict[key] = startDict[i].get(key, 0) * startReturnDict.get(key, 0)
    for key in endKeys:
        for i in range(len(endArg)):
            if i == 0:
                endReturnDict[key] = endDict[0].get(key, 0)
            else:
                endReturnDict[key] = endDict[i].get(key, 0) * endReturnDict.get(key, 0)
    startReturnDict = occurencesToPercentages(startReturnDict)
    endReturnDict = occurencesToPercentages(endReturnDict)
    return [sorted(startReturnDict.items(), key=lambda kv: kv[1], reverse=True), sorted(endReturnDict.items(), key=lambda kv: kv[1], reverse=True)]
    # Maybe also return the actual pronunciations that the Kanji can be and the probabilities for each.
    # How do I fix sparseness? Should I get global data from NHK Easy News?

# %%
def getGlobalProbabilities(kanji=None,pronsKnown=False,prevPron=None,prevChar=None,nextPron=None,nextChar=None):
    """Inputs: kanji, prevPron?, prevChar?, nextPron?, nextChar?, allKanji?
? = optional
Output: A List of Dictionaries of occurences
TODO: Feed the list of dictionaries to computeProbabilities
This function returns all of the statistics for the current Kanji in
all contexts, independent of each other. This means that the nextPronunciation
dictionary will not be affected by the presence of an allKanji flag.

The order of the dictionaries are:
curPron, prevPron, prevChar, nextPron, nextChar, allKanji
"""
    
    startDictionaryList = []
    endDictionaryList = []
    startKeys = set()
    endKeys = set()
    startArgumentList = []
    endArgumentList = []
    if pronsKnown:
        startDictionaryList.append(occurencesToPercentages(currentPronunciationStart.get(kanji, dict())))
        startKeys = set(currentPronunciationStart.get(kanji, dict()).keys())
        endDictionaryList.append(occurencesToPercentages(currentPronunciationEnd.get(kanji, dict())))
        endKeys = set(currentPronunciationEnd.get(kanji, dict()).keys())
        startArgumentList.append(pronsKnown)
        endArgumentList.append(pronsKnown)
    if prevPron != None:
        startArgumentList.append(prevPron)
        startKeys = startKeys | set(previousPronunciationEndCurrentPronunciationStart.get(prevPron, dict()).keys())
        startDictionaryList.append(occurencesToPercentages(previousPronunciationEndCurrentPronunciationStart.get(prevPron, dict())))
    if prevChar != None:
        startArgumentList.append(prevChar)
        startKeys = startKeys | set(previousCharacterCurrentPronunciationStart.get(prevChar, dict()).keys())
        startDictionaryList.append(occurencesToPercentages(previousCharacterCurrentPronunciationStart.get(prevChar, dict())))
    if nextPron != None:
        endArgumentList.append(nextPron)
        endKeys = endKeys | set(nextPronunciationStartCurrentPronunciationEnd.get(nextPron, dict()).keys())
        endDictionaryList.append(occurencesToPercentages(nextPronunciationStartCurrentPronunciationEnd.get(nextPron, dict())))
    if nextChar != None:
        endArgumentList.append(nextChar)
        endKeys = endKeys | set(nextCharacterCurrentPronunciationEnd.get(nextChar, dict()).keys())
        endDictionaryList.append(occurencesToPercentages(nextCharacterCurrentPronunciationEnd.get(nextChar, dict())))
    return globalBayesTheorem(startDictionaryList, endDictionaryList, startKeys, endKeys, startArgumentList, endArgumentList)

# %%
getGlobalProbabilities('言', pronsKnown=True, nextPron='う')
# Out:
# [[('げ', 0.36363636363636365),
#   ('こ', 0.2727272727272727),
#   ('い', 0.22727272727272727),
#   ('ご', 0.13636363636363635)],
#  [('ん', 0.6690962099125365),
#   ('い', 0.31341107871720114),
#   ('と', 0.01749271137026239),
#   ('お', 0.0),
#   ('ば', 0.0),
#   ('は', 0.0),
#   ('ぎ', 0.0),
#   ('も', 0.0),
#   ('る', 0.0),
#   ('わ', 0.0),
#   ('の', 0.0),
#   ('ろ', 0.0),
#   ('え', 0.0),
#   ('や', 0.0),
#   ('ね', 0.0),
#   ('か', 0.0),
#   ('よ', 0.0),
#   ('ら', 0.0),
#   ('ひ', 0.0),
#   ('こ', 0.0),
#   ('ど', 0.0),
#   ('む', 0.0),
#   ('く', 0.0),
#   ('し', 0.0),
#   ('ふ', 0.0),
#   ('が', 0.0),
#   ('ず', 0.0),
#   ('ゆ', 0.0),
#   ('ぬ', 0.0),
#   ('す', 0.0),
#   ('じ', 0.0),
#   ('う', 0.0),
#   ('り', 0.0),
#   ('き', 0.0),
#   ('び', 0.0),
#   ('そ', 0.0),
#   ('つ', 0.0),
#   ('だ', 0.0),
#   ('ち', 0.0),
#   ('あ', 0.0),
#   ('さ', 0.0),
#   ('ぼ', 0.0),
#   ('ぶ', 0.0),
#   ('た', 0.0),
#   ('ほ', 0.0),
#   ('な', 0.0),
#   ('ま', 0.0)]]

# %%
getGlobalProbabilities('日', pronsKnown=True, nextChar='曜')
# Out:
# [[('ひ', 0.2631578947368421),
#   ('に', 0.22807017543859648),
#   ('び', 0.21052631578947367),
#   ('か', 0.15789473684210525),
#   ('じ', 0.14035087719298245)],
#  [('ち', 0.43333333333333335),
#   ('か', 0.3),
#   ('つ', 0.26666666666666666),
#   ('び', 0.0),
#   ('い', 0.0),
#   ('ど', 0.0),
#   ('ん', 0.0),
#   ('ひ', 0.0),
#   ('く', 0.0)]]

# %%
getGlobalProbabilities('日', pronsKnown=True, prevChar='曜')
# Out:
# [[('び', 1.0), ('か', 0.0), ('ひ', 0.0), ('に', 0.0), ('じ', 0.0)],
#  [('ひ', 0.2631578947368421),
#   ('ち', 0.22807017543859648),
#   ('び', 0.21052631578947367),
#   ('か', 0.15789473684210525),
#   ('つ', 0.14035087719298245)]]

# %%
### WHY ALLKANJI MATTERS: 微笑み hoho e mi　微笑 bi shou

# %%
### take all regular and[?] irregular words and push the pronunciations through globalPreviousPronunciation
### and globalNextPronunciation while holding small characters to the previous syllable

sorted(currentChar.items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [('る', 745),
#  ('い', 283),
#  ('す', 204),
#  ('り', 166),
#  ('し', 158),
#  ('く', 122),
#  ('れ', 105),
#  ('け', 104),
#  ('う', 103),
#  ('え', 96),
#  ('む', 93),
#  ('め', 87),
#  ('か', 82),
#  ('ま', 81),
#  ('き', 73),
#  ('出', 61),
#  ('大', 60),
#  ('人', 60),
#  ('合', 57),
#  ('ら', 57),
#  ('日', 57),
#  ('手', 54),
#  ('気', 53),
#  ('物', 52),
#  ('て', 50),
#  ('上', 47),
#  ('見', 47),
#  ('地', 46),
#  ('生', 46),
#  ('分', 45),
#  ('学', 44),
#  ('付', 44),
#  ('下', 43),
#  ('み', 43),
#  ('っ', 43),
#  ('に', 43),
#  ('一', 41),
#  ('わ', 40),
#  ('行', 40),
#  ('事', 38),
#  ('引', 38),
#  ('入', 37),
#  ('取', 37),
#  ('お', 37),
#  ('間', 37),
#  ('無', 37),
#  ('用', 36),
#  ('通', 36),
#  ('な', 36),
#  ('定', 35),
#  ('中', 35),
#  ('ち', 35),
#  ('つ', 35),
#  ('不', 33),
#  ('名', 33),
#  ('会', 33),
#  ('立', 33),
#  ('げ', 33),
#  ('目', 32),
#  ('動', 31),
#  ('水', 30),
#  ('金', 30),
#  ('当', 30),
#  ('年', 30),
#  ('せ', 30),
#  ('体', 30),
#  ('度', 29),
#  ('々', 29),
#  ('が', 29),
#  ('力', 28),
#  ('じ', 28),
#  ('び', 28),
#  ('切', 28),
#  ('点', 28),
#  ('自', 28),
#  ('ぐ', 27),
#  ('来', 27),
#  ('業', 26),
#  ('先', 26),
#  ('理', 26),
#  ('の', 26),
#  ('心', 26),
#  ('本', 26),
#  ('書', 26),
#  ('方', 26),
#  ('子', 26),
#  ('場', 26),
#  ('意', 26),
#  ('も', 26),
#  ('ず', 25),
#  ('外', 25),
#  ('作', 25),
#  ('掛', 25),
#  ('産', 24),
#  ('文', 24),
#  ('長', 24),
#  ('着', 24),
#  ('さ', 23),
#  ('正', 23),
#  ('主', 23),
#  ('回', 23),
#  ('成', 23),
#  ('た', 23),
#  ('同', 23),
#  ('込', 23),
#  ('感', 22),
#  ('議', 22),
#  ('や', 22),
#  ('所', 22),
#  ('言', 22),
#  ('数', 22),
#  ('明', 22),
#  ('重', 22),
#  ('口', 21),
#  ('代', 21),
#  ('交', 21),
#  ('面', 21),
#  ('対', 20),
#  ('転', 20),
#  ('強', 20),
#  ('実', 20),
#  ('前', 20),
#  ('ぶ', 20),
#  ('公', 20),
#  ('差', 20),
#  ('語', 20),
#  ('直', 20),
#  ('調', 20),
#  ('品', 19),
#  ('原', 19),
#  ('真', 19),
#  ('仕', 19),
#  ('論', 19),
#  ('教', 19),
#  ('食', 19),
#  ('家', 18),
#  ('休', 18),
#  ('道', 18),
#  ('受', 18),
#  ('国', 18),
#  ('味', 18),
#  ('と', 18),
#  ('情', 18),
#  ('平', 18),
#  ('部', 18),
#  ('進', 18),
#  ('有', 17),
#  ('高', 17),
#  ('知', 17),
#  ('現', 17),
#  ('何', 17),
#  ('料', 17),
#  ('小', 17),
#  ('指', 17),
#  ('電', 17),
#  ('科', 17),
#  ('解', 17),
#  ('月', 17),
#  ('過', 17),
#  ('御', 17),
#  ('好', 17),
#  ('後', 16),
#  ('近', 16),
#  ('空', 16),
#  ('利', 16),
#  ('機', 16),
#  ('運', 16),
#  ('然', 16),
#  ('ん', 16),
#  ('線', 16),
#  ('和', 16),
#  ('化', 16),
#  ('風', 16),
#  ('相', 16),
#  ('集', 16),
#  ('様', 16),
#  ('止', 16),
#  ('発', 16),
#  ('者', 16),
#  ('全', 16),
#  ('反', 16),
#  ('車', 16),
#  ('員', 15),
#  ('法', 15),
#  ('字', 15),
#  ('加', 15),
#  ('連', 15),
#  ('身', 15),
#  ('火', 15),
#  ('流', 15),
#  ('制', 15),
#  ('売', 15),
#  ('話', 15),
#  ('今', 15),
#  ('消', 15),
#  ('返', 15),
#  ('決', 15),
#  ('曜', 15),
#  ('時', 15),
#  ('要', 15),
#  ('能', 15),
#  ('放', 14),
#  ('務', 14),
#  ('伝', 14),
#  ('素', 14),
#  ('保', 14),
#  ('望', 14),
#  ('特', 14),
#  ('向', 14),
#  ('割', 14),
#  ('内', 14),
#  ('民', 14),
#  ('寄', 14),
#  ('器', 14),
#  ('期', 14),
#  ('配', 14),
#  ('性', 14),
#  ('で', 14),
#  ('違', 14),
#  ('持', 14),
#  ('改', 13),
#  ('演', 13),
#  ('別', 13),
#  ('思', 13),
#  ('習', 13),
#  ('天', 13),
#  ('記', 13),
#  ('命', 13),
#  ('親', 13),
#  ('冷', 13),
#  ('戦', 13),
#  ('形', 13),
#  ('張', 13),
#  ('落', 13),
#  ('断', 13),
#  ('開', 13),
#  ('こ', 13),
#  ('確', 13),
#  ('算', 13),
#  ('予', 13),
#  ('新', 13),
#  ('応', 13),
#  ('べ', 13),
#  ('共', 13),
#  ('女', 13),
#  ('足', 12),
#  ('世', 12),
#  ('続', 12),
#  ('土', 12),
#  ('図', 12),
#  ('格', 12),
#  ('送', 12),
#  ('関', 12),
#  ('問', 12),
#  ('規', 12),
#  ('社', 12),
#  ('信', 12),
#  ('苦', 12),
#  ('観', 12),
#  ('工', 12),
#  ('支', 12),
#  ('始', 12),
#  ('経', 12),
#  ('優', 12),
#  ('申', 12),
#  ('詞', 12),
#  ('収', 12),
#  ('助', 12),
#  ('海', 12),
#  ('夜', 12),
#  ('役', 12),
#  ('便', 12),
#  ('独', 11),
#  ('速', 11),
#  ('計', 11),
#  ('質', 11),
#  ('具', 11),
#  ('根', 11),
#  ('茶', 11),
#  ('退', 11),
#  ('急', 11),
#  ('木', 11),
#  ('害', 11),
#  ('再', 11),
#  ('少', 11),
#  ('色', 11),
#  ('修', 11),
#  ('育', 11),
#  ('組', 11),
#  ('居', 11),
#  ('角', 11),
#  ('式', 11),
#  ('備', 11),
#  ('覚', 11),
#  ('打', 11),
#  ('単', 11),
#  ('番', 11),
#  ('首', 10),
#  ('変', 10),
#  ('職', 10),
#  ('追', 10),
#  ('遠', 10),
#  ('満', 10),
#  ('農', 10),
#  ('等', 10),
#  ('混', 10),
#  ('約', 10),
#  ('難', 10),
#  ('花', 10),
#  ('画', 10),
#  ('置', 10),
#  ('得', 10),
#  ('短', 10),
#  ('終', 10),
#  ('捕', 10),
#  ('任', 10),
#  ('表', 10),
#  ('待', 10),
#  ('適', 10),
#  ('元', 10),
#  ('在', 10),
#  ('防', 10),
#  ('判', 10),
#  ('造', 10),
#  ('美', 10),
#  ('増', 10),
#  ('治', 10),
#  ('服', 10),
#  ('説', 10),
#  ('安', 10),
#  ('住', 10),
#  ('未', 10),
#  ('音', 10),
#  ('週', 10),
#  ('負', 10),
#  ('だ', 10),
#  ('振', 10),
#  ('悪', 10),
#  ('容', 10),
#  ('屋', 9),
#  ('類', 9),
#  ('統', 9),
#  ('領', 9),
#  ('校', 9),
#  ('区', 9),
#  ('常', 9),
#  ('温', 9),
#  ('布', 9),
#  ('告', 9),
#  ('光', 9),
#  ('題', 9),
#  ('良', 9),
#  ('給', 9),
#  ('例', 9),
#  ('以', 9),
#  ('破', 9),
#  ('帯', 9),
#  ('野', 9),
#  ('館', 9),
#  ('丸', 9),
#  ('起', 9),
#  ('勤', 9),
#  ('養', 9),
#  ('読', 9),
#  ('山', 9),
#  ('留', 9),
#  ('歩', 9),
#  ('結', 9),
#  ('片', 9),
#  ('減', 9),
#  ('報', 9),
#  ('は', 9),
#  ('乗', 9),
#  ('案', 9),
#  ('ね', 9),
#  ('座', 9),
#  ('除', 9),
#  ('台', 9),
#  ('率', 9),
#  ('想', 9),
#  ('並', 9),
#  ('限', 9),
#  ('散', 9),
#  ('舞', 9),
#  ('突', 9),
#  ('異', 9),
#  ('ぎ', 9),
#  ('装', 9),
#  ('建', 9),
#  ('最', 9),
#  ('広', 9),
#  ('路', 9),
#  ('楽', 9),
#  ('的', 9),
#  ('慣', 9),
#  ('多', 9),
#  ('神', 9),
#  ('整', 8),
#  ('量', 8),
#  ('仮', 8),
#  ('使', 8),
#  ('弱', 8),
#  ('白', 8),
#  ('降', 8),
#  ('紙', 8),
#  ('基', 8),
#  ('準', 8),
#  ('余', 8),
#  ('労', 8),
#  ('昼', 8),
#  ('弁', 8),
#  ('飛', 8),
#  ('映', 8),
#  ('写', 8),
#  ('毎', 8),
#  ('遣', 8),
#  ('逃', 8),
#  ('四', 8),
#  ('権', 8),
#  ('夕', 8),
#  ('室', 8),
#  ('残', 8),
#  ('存', 8),
#  ('採', 8),
#  ('初', 8),
#  ('果', 8),
#  ('極', 8),
#  ('資', 8),
#  ('答', 8),
#  ('肉', 8),
#  ('痛', 8),
#  ('ご', 8),
#  ('補', 8),
#  ('半', 8),
#  ('位', 8),
#  ('訳', 8),
#  ('団', 8),
#  ('細', 8),
#  ('易', 8),
#  ('済', 8),
#  ('辞', 8),
#  ('店', 8),
#  ('盛', 8),
#  ('寝', 8),
#  ('程', 8),
#  ('勢', 8),
#  ('清', 8),
#  ('講', 8),
#  ('段', 8),
#  ('視', 8),
#  ('参', 8),
#  ('絶', 8),
#  ('順', 8),
#  ('照', 7),
#  ('級', 7),
#  ('熱', 7),
#  ('頭', 7),
#  ('密', 7),
#  ('選', 7),
#  ('製', 7),
#  ('油', 7),
#  ('逆', 7),
#  ('源', 7),
#  ('態', 7),
#  ('興', 7),
#  ('息', 7),
#  ('ば', 7),
#  ('暗', 7),
#  ('芸', 7),
#  ('術', 7),
#  ('縮', 7),
#  ('帰', 7),
#  ('遅', 7),
#  ('費', 7),
#  ('象', 7),
#  ('愛', 7),
#  ('飯', 7),
#  ('失', 7),
#  ('個', 7),
#  ('勝', 7),
#  ('石', 7),
#  ('背', 7),
#  ('商', 7),
#  ('非', 7),
#  ('活', 7),
#  ('考', 7),
#  ('評', 7),
#  ('争', 7),
#  ('若', 7),
#  ('船', 7),
#  ('頃', 7),
#  ('院', 7),
#  ('談', 7),
#  ('注', 7),
#  ('固', 7),
#  ('政', 7),
#  ('赤', 7),
#  ('比', 7),
#  ('義', 7),
#  ('雑', 7),
#  ('効', 7),
#  ('積', 7),
#  ('技', 7),
#  ('洗', 7),
#  ('そ', 7),
#  ('替', 7),
#  ('移', 7),
#  ('材', 7),
#  ('軽', 7),
#  ('恐', 7),
#  ('途', 7),
#  ('免', 7),
#  ('次', 7),
#  ('更', 7),
#  ('刺', 7),
#  ('換', 7),
#  ('印', 7),
#  ('末', 7),
#  ('深', 7),
#  ('接', 7),
#  ('構', 7),
#  ('師', 7),
#  ('園', 7),
#  ('護', 7),
#  ('病', 7),
#  ('税', 7),
#  ('三', 7),
#  ('夫', 7),
#  ('飾', 6),
#  ('模', 6),
#  ('推', 6),
#  ('締', 6),
#  ('歯', 6),
#  ('貨', 6),
#  ('識', 6),
#  ('閉', 6),
#  ('児', 6),
#  ('為', 6),
#  ('達', 6),
#  ('染', 6),
#  ('青', 6),
#  ('試', 6),
#  ('友', 6),
#  ('担', 6),
#  ('状', 6),
#  ('宿', 6),
#  ('軍', 6),
#  ('財', 6),
#  ('欲', 6),
#  ('刻', 6),
#  ('乱', 6),
#  ('葉', 6),
#  ('母', 6),
#  ('革', 6),
#  ('戸', 6),
#  ('溶', 6),
#  ('都', 6),
#  ('早', 6),
#  ('煙', 6),
#  ('嫌', 6),
#  ('乾', 6),
#  ('蔵', 6),
#  ('快', 6),
#  ('晴', 6),
#  ('測', 6),
#  ('証', 6),
#  ('眠', 6),
#  ('馬', 6),
#  ('両', 6),
#  ('走', 6),
#  ('損', 6),
#  ('暴', 6),
#  ('宅', 6),
#  ('静', 6),
#  ('了', 6),
#  ('撃', 6),
#  ('周', 6),
#  ('ろ', 6),
#  ('坊', 6),
#  ('善', 6),
#  ('裁', 6),
#  ('示', 6),
#  ('協', 6),
#  ('誤', 6),
#  ('句', 6),
#  ('停', 6),
#  ('死', 6),
#  ('柄', 6),
#  ('志', 6),
#  ('蒸', 6),
#  ('鳴', 6),
#  ('激', 6),
#  ('略', 6),
#  ('投', 6),
#  ('継', 6),
#  ('課', 6),
#  ('万', 6),
#  ('英', 6),
#  ('洋', 6),
#  ('毛', 6),
#  ('男', 6),
#  ('列', 6),
#  ('編', 6),
#  ('警', 6),
#  ('客', 6),
#  ('汚', 6),
#  ('古', 6),
#  ('概', 6),
#  ('提', 6),
#  ('危', 6),
#  ('恋', 6),
#  ('号', 6),
#  ('値', 6),
#  ('守', 6),
#  ('劇', 6),
#  ('士', 6),
#  ('悲', 6),
#  ('階', 6),
#  ('賞', 6),
#  ('払', 6),
#  ('円', 6),
#  ('曲', 6),
#  ('頼', 6),
#  ('著', 6),
#  ('衛', 6),
#  ('王', 6),
#  ('念', 6),
#  ('覧', 6),
#  ('私', 6),
#  ('標', 6),
#  ('押', 6),
#  ('傾', 5),
#  ('従', 5),
#  ('微', 5),
#  ('災', 5),
#  ('暮', 5),
#  ('酸', 5),
#  ('迎', 5),
#  ('域', 5),
#  ('景', 5),
#  ('官', 5),
#  ('必', 5),
#  ('依', 5),
#  ('兼', 5),
#  ('丈', 5),
#  ('沈', 5),
#  ('弾', 5),
#  ('星', 5),
#  ('西', 5),
#  ('禁', 5),
#  ('承', 5),
#  ('診', 5),
#  ('騒', 5),
#  ('憎', 5),
#  ('査', 5),
#  ('属', 5),
#  ('働', 5),
#  ('離', 5),
#  ('球', 5),
#  ('募', 5),
#  ('与', 5),
#  ('焼', 5),
#  ('故', 5),
#  ('他', 5),
#  ('五', 5),
#  ('偶', 5),
#  ('救', 5),
#  ('健', 5),
#  ('抜', 5),
#  ('衆', 5),
#  ('市', 5),
#  ('ざ', 5),
#  ('渡', 5),
#  ('処', 5),
#  ('可', 5),
#  ('導', 5),
#  ('十', 5),
#  ('晩', 5),
#  ('恵', 5),
#  ('焦', 5),
#  ('録', 5),
#  ('価', 5),
#  ('専', 5),
#  ('左', 5),
#  ('旅', 5),
#  ('鉄', 5),
#  ('供', 5),
#  ('検', 5),
#  ('催', 5),
#  ('辺', 5),
#  ('街', 5),
#  ('像', 5),
#  ('暖', 5),
#  ('祝', 5),
#  ('創', 5),
#  ('衣', 5),
#  ('駄', 5),
#  ('及', 5),
#  ('跡', 5),
#  ('拝', 5),
#  ('境', 5),
#  ('登', 5),
#  ('幸', 5),
#  ('亡', 5),
#  ('聞', 5),
#  ('裏', 5),
#  ('我', 5),
#  ('束', 5),
#  ('仲', 5),
#  ('延', 5),
#  ('傷', 5),
#  ('納', 5),
#  ('歌', 5),
#  ('詰', 5),
#  ('障', 5),
#  ('滅', 5),
#  ('種', 5),
#  ('認', 5),
#  ('呼', 5),
#  ('射', 5),
#  ('敬', 5),
#  ('婚', 5),
#  ('黒', 5),
#  ('雨', 5),
#  ('輸', 5),
#  ('血', 5),
#  ('輪', 5),
#  ('倒', 5),
#  ('緩', 5),
#  ('陸', 5),
#  ('設', 5),
#  ('展', 5),
#  ('医', 5),
#  ('笑', 5),
#  ('滞', 5),
#  ('膨', 5),
#  ('宜', 5),
#  ('老', 5),
#  ('封', 5),
#  ('庫', 5),
#  ('抗', 5),
#  ('越', 5),
#  ('端', 5),
#  ('釣', 5),
#  ('灯', 5),
#  ('複', 5),
#  ('植', 5),
#  ('尊', 5),
#  ('敷', 5),
#  ('二', 5),
#  ('各', 4),
#  ('占', 4),
#  ('鏡', 4),
#  ('吊', 4),
#  ('厳', 4),
#  ('介', 4),
#  ('畜', 4),
#  ('戻', 4),
#  ('就', 4),
#  ('恥', 4),
#  ('薄', 4),
#  ('砂', 4),
#  ('筆', 4),
#  ('薬', 4),
#  ('浮', 4),
#  ('裂', 4),
#  ('泳', 4),
#  ('殿', 4),
#  ('包', 4),
#  ('礼', 4),
#  ('儀', 4),
#  ('爆', 4),
#  ('犯', 4),
#  ('討', 4),
#  ('惑', 4),
#  ('完', 4),
#  ('眼', 4),
#  ('絵', 4),
#  ('普', 4),
#  ('沿', 4),
#  ('第', 4),
#  ('願', 4),
#  ('審', 4),
#  ('派', 4),
#  ('耕', 4),
#  ('飲', 4),
#  ('互', 4),
#  ('件', 4),
#  ('祖', 4),
#  ('床', 4),
#  ('則', 4),
#  ('請', 4),
#  ('棄', 4),
#  ('攻', 4),
#  ('練', 4),
#  ('側', 4),
#  ('刊', 4),
#  ('波', 4),
#  ('際', 4),
#  ('鳥', 4),
#  ('扱', 4),
#  ('腹', 4),
#  ('盤', 4),
#  ('抱', 4),
#  ('横', 4),
#  ('否', 4),
#  ('兎', 4),
#  ('毒', 4),
#  ('貸', 4),
#  ('旬', 4),
#  ('買', 4),
#  ('妙', 4),
#  ('係', 4),
#  ('箇', 4),
#  ('南', 4),
#  ('幾', 4),
#  ('驚', 4),
#  ('房', 4),
#  ('富', 4),
#  ('剥', 4),
#  ('益', 4),
#  ('織', 4),
#  ('矢', 4),
#  ('辛', 4),
#  ('悩', 4),
#  ('丁', 4),
#  ('遊', 4),
#  ('鉱', 4),
#  ('帳', 4),
#  ('鹿', 4),
#  ('券', 4),
#  ('囲', 4),
#  ('席', 4),
#  ('似', 4),
#  ('久', 4),
#  ('去', 4),
#  ('巻', 4),
#  ('歴', 4),
#  ('堂', 4),
#  ('牧', 4),
#  ('司', 4),
#  ('針', 4),
#  ('拡', 4),
#  ('励', 4),
#  ('田', 4),
#  ('燃', 4),
#  ('擦', 4),
#  ('浴', 4),
#  ('省', 4),
#  ('勘', 4),
#  ('超', 4),
#  ('察', 4),
#  ('ゃ', 4),
#  ('由', 4),
#  ('述', 4),
#  ('殺', 4),
#  ('党', 4),
#  ('朝', 4),
#  ('策', 4),
#  ('鑑', 4),
#  ('典', 4),
#  ('圧', 4),
#  ('掻', 4),
#  ('纏', 4),
#  ('荒', 4),
#  ('研', 4),
#  ('廃', 4),
#  ('泊', 4),
#  ('至', 4),
#  ('埋', 4),
#  ('群', 4),
#  ('湯', 4),
#  ('宝', 4),
#  ('魔', 4),
#  ('隔', 4),
#  ('華', 4),
#  ('看', 4),
#  ('刑', 4),
#  ('繁', 4),
#  ('太', 4),
#  ('誘', 4),
#  ('罰', 4),
#  ('干', 4),
#  ('険', 4),
#  ('溜', 4),
#  ('幹', 4),
#  ('勧', 4),
#  ('零', 4),
#  ('操', 4),
#  ('験', 4),
#  ('節', 4),
#  ('盗', 4),
#  ('液', 4),
#  ('営', 4),
#  ('響', 4),
#  ('皮', 4),
#  ('疑', 4),
#  ('馴', 4),
#  ('八', 4),
#  ('揺', 4),
#  ('婦', 4),
#  ('載', 4),
#  ('純', 4),
#  ('復', 4),
#  ('欠', 4),
#  ('乏', 4),
#  ('折', 4),
#  ('漁', 4),
#  ('簡', 4),
#  ('武', 4),
#  ('甘', 4),
#  ('紛', 4),
#  ('東', 4),
#  ('総', 4),
#  ('貧', 4),
#  ('績', 4),
#  ('祭', 4),
#  ('筋', 4),
#  ('繋', 4),
#  ('壊', 4),
#  ('授', 4),
#  ('林', 4),
#  ('頂', 4),
#  ('幼', 4),
#  ('脅', 3),
#  ('迫', 3),
#  ('磁', 3),
#  ('範', 3),
#  ('触', 3),
#  ('旧', 3),
#  ('掃', 3),
#  ('致', 3),
#  ('署', 3),
#  ('沢', 3),
#  ('孤', 3),
#  ('ぜ', 3),
#  ('脳', 3),
#  ('契', 3),
#  ('筒', 3),
#  ('崩', 3),
#  ('午', 3),
#  ('棚', 3),
#  ('七', 3),
#  ('怪', 3),
#  ('低', 3),
#  ('暦', 3),
#  ('井', 3),
#  ('岸', 3),
#  ('栄', 3),
#  ('因', 3),
#  ('六', 3),
#  ('永', 3),
#  ('界', 3),
#  ('勇', 3),
#  ('灰', 3),
#  ('訪', 3),
#  ('父', 3),
#  ('貯', 3),
#  ('皿', 3),
#  ('瓶', 3),
#  ('豊', 3),
#  ('索', 3),
#  ('米', 3),
#  ('競', 3),
#  ('噴', 3),
#  ('漏', 3),
#  ('臭', 3),
#  ('鎖', 3),
#  ('療', 3),
#  ('精', 3),
#  ('訴', 3),
#  ('候', 3),
#  ('酷', 3),
#  ('獲', 3),
#  ('捻', 3),
#  ('捜', 3),
#  ('威', 3),
#  ('施', 3),
#  ('河', 3),
#  ('購', 3),
#  ('巧', 3),
#  ('池', 3),
#  ('偏', 3),
#  ('震', 3),
#  ('呂', 3),
#  ('硬', 3),
#  ('妥', 3),
#  ('削', 3),
#  ('虫', 3),
#  ('腰', 3),
#  ('縁', 3),
#  ('ぽ', 3),
#  ('香', 3),
#  ('層', 3),
#  ('紅', 3),
#  ('炭', 3),
#  ('屈', 3),
#  ('誇', 3),
#  ('還', 3),
#  ('或', 3),
#  ...]

# %%
currentChar
# Out:
# {'首': 10,
#  '飾': 6,
#  'り': 166,
#  '脅': 3,
#  '迫': 3,
#  '傾': 5,
#  '整': 8,
#  'え': 96,
#  'る': 745,
#  '口': 21,
#  'ず': 25,
#  'さ': 23,
#  'む': 93,
#  '磁': 3,
#  '気': 53,
#  '淡': 2,
#  '水': 30,
#  '模': 6,
#  '範': 3,
#  '対': 20,
#  '照': 7,
#  '隣': 1,
#  '家': 18,
#  '屋': 9,
#  '類': 9,
#  '推': 6,
#  '改': 13,
#  '正': 23,
#  '尽': 2,
#  'き': 73,
#  '各': 4,
#  '地': 46,
#  '敏': 1,
#  '感': 22,
#  '大': 60,
#  '統': 9,
#  '領': 9,
#  '触': 3,
#  '有': 17,
#  '力': 28,
#  '主': 23,
#  '演': 13,
#  '転': 20,
#  'じ': 28,
#  '入': 37,
#  '締': 6,
#  'め': 87,
#  '産': 24,
#  '後': 16,
#  '変': 10,
#  'わ': 40,
#  '掬': 1,
#  'う': 103,
#  '休': 18,
#  '道': 18,
#  '徳': 1,
#  '職': 10,
#  '員': 15,
#  '轢': 1,
#  'く': 122,
#  '高': 17,
#  '校': 9,
#  '生': 46,
#  '追': 10,
#  '放': 14,
#  '文': 24,
#  '法': 15,
#  '卒': 2,
#  '業': 26,
#  '旧': 3,
#  '知': 17,
#  '輩': 2,
#  '区': 9,
#  '別': 13,
#  '事': 38,
#  '務': 14,
#  '従': 5,
#  '奨': 2,
#  '学': 44,
#  '金': 30,
#  '掃': 3,
#  '不': 33,
#  '動': 31,
#  '独': 11,
#  '占': 4,
#  '凝': 2,
#  '委': 2,
#  '託': 1,
#  '級': 7,
#  '塾': 1,
#  '歯': 6,
#  '思': 13,
#  'い': 283,
#  '付': 44,
#  '外': 25,
#  '貨': 6,
#  '現': 17,
#  '代': 21,
#  '近': 16,
#  'け': 104,
#  '顕': 1,
#  '微': 5,
#  '鏡': 4,
#  '常': 9,
#  '識': 6,
#  '習': 13,
#  '字': 15,
#  '上': 47,
#  '受': 18,
#  '取': 37,
#  '吊': 4,
#  'す': 204,
#  '加': 15,
#  '速': 11,
#  '度': 29,
#  '強': 20,
#  'ま': 81,
#  '合': 57,
#  '致': 3,
#  '熱': 7,
#  '量': 8,
#  '先': 26,
#  '頭': 7,
#  '一': 41,
#  '連': 15,
#  '仮': 8,
#  '定': 35,
#  '署': 3,
#  '名': 33,
#  '贅': 1,
#  '沢': 3,
#  '身': 15,
#  '計': 11,
#  '厳': 4,
#  '密': 7,
#  '閉': 6,
#  '会': 33,
#  '孤': 3,
#  '児': 6,
#  '天': 13,
#  '国': 18,
#  '使': 8,
#  '冊': 1,
#  '弱': 8,
#  '蛋': 1,
#  '白': 8,
#  '質': 11,
#  '火': 15,
#  '災': 5,
#  '介': 4,
#  '畜': 4,
#  '交': 21,
#  'ぜ': 3,
#  '暮': 5,
#  'れ': 105,
#  '空': 16,
#  '中': 35,
#  '選': 7,
#  '手': 54,
#  '味': 18,
#  '人': 60,
#  '物': 52,
#  '為': 6,
#  '記': 13,
#  '戻': 4,
#  '伝': 14,
#  '達': 6,
#  '頬': 1,
#  '染': 6,
#  '酸': 5,
#  '素': 14,
#  '下': 43,
#  '青': 6,
#  '保': 14,
#  '温': 9,
#  '遠': 10,
#  '足': 12,
#  '具': 11,
#  '布': 9,
#  '告': 9,
#  '脳': 3,
#  '降': 8,
#  '狙': 2,
#  '製': 7,
#  '品': 19,
#  '出': 61,
#  '迎': 5,
#  '光': 9,
#  '望': 14,
#  'し': 158,
#  '試': 6,
#  'み': 43,
#  '柵': 1,
#  '原': 19,
#  '油': 7,
#  '世': 12,
#  '域': 5,
#  '慕': 1,
#  '友': 6,
#  '契': 3,
#  '特': 14,
#  '景': 5,
#  '目': 32,
#  '議': 22,
#  '題': 9,
#  '就': 4,
#  '当': 30,
#  'て': 50,
#  '何': 17,
#  '々': 29,
#  'お': 37,
#  '恥': 4,
#  'ら': 57,
#  '薄': 4,
#  '分': 45,
#  '担': 6,
#  '用': 36,
#  '紙': 8,
#  '砂': 4,
#  '利': 16,
#  '理': 26,
#  '流': 15,
#  '通': 36,
#  '筒': 3,
#  '回': 23,
#  '根': 11,
#  '随': 2,
#  '筆': 4,
#  '向': 14,
#  '状': 6,
#  '基': 8,
#  '礎': 1,
#  '満': 10,
#  '宿': 6,
#  '命': 13,
#  '実': 20,
#  'ち': 35,
#  '舟': 1,
#  '長': 24,
#  '官': 5,
#  '農': 10,
#  '良': 9,
#  '薬': 4,
#  '給': 9,
#  '料': 17,
#  '前': 20,
#  '例': 9,
#  '以': 9,
#  '軍': 6,
#  '艦': 1,
#  '必': 5,
#  '需': 2,
#  '浮': 4,
#  '機': 16,
#  '罹': 1,
#  '卯': 1,
#  '運': 16,
#  '搬': 1,
#  '姓': 2,
#  '続': 12,
#  '依': 5,
#  '然': 16,
#  '破': 9,
#  '裂': 4,
#  '兼': 5,
#  '財': 6,
#  '小': 17,
#  '割': 14,
#  '頑': 2,
#  '丈': 5,
#  '親': 13,
#  '指': 17,
#  '内': 14,
#  '崩': 3,
#  '泳': 4,
#  'ぐ': 27,
#  '面': 21,
#  '沈': 5,
#  '殿': 4,
#  '土': 12,
#  '午': 3,
#  '欲': 6,
#  '刻': 6,
#  '包': 4,
#  '帯': 9,
#  '真': 19,
#  'ん': 16,
#  'ぶ': 20,
#  '茶': 11,
#  'の': 26,
#  '間': 37,
#  '野': 9,
#  '心': 26,
#  '礼': 4,
#  '儀': 4,
#  '等': 10,
#  '館': 9,
#  '渉': 2,
#  '丸': 9,
#  '鉢': 1,
#  '本': 26,
#  '棚': 3,
#  '書': 26,
#  '腐': 2,
#  '日': 57,
#  '七': 3,
#  '冷': 13,
#  'や': 22,
#  'か': 82,
#  '爆': 4,
#  '弾': 5,
#  '怪': 3,
#  '退': 11,
#  '電': 17,
#  '線': 16,
#  '混': 10,
#  '乱': 6,
#  '約': 10,
#  '民': 14,
#  '起': 9,
#  '成': 23,
#  '立': 33,
#  'つ': 35,
#  '遭': 2,
#  '難': 10,
#  '逆': 7,
#  '準': 8,
#  '急': 11,
#  '引': 38,
#  '源': 7,
#  '戦': 13,
#  '歪': 1,
#  '詫': 2,
#  'び': 28,
#  '腕': 2,
#  '形': 13,
#  '態': 7,
#  '葉': 6,
#  '勤': 9,
#  '養': 9,
#  '和': 16,
#  'げ': 33,
#  '犯': 4,
#  '母': 6,
#  '化': 16,
#  '余': 8,
#  '興': 7,
#  '木': 11,
#  '風': 16,
#  '低': 3,
#  '方': 26,
#  '討': 4,
#  '害': 11,
#  '莫': 1,
#  '惑': 4,
#  '星': 5,
#  '労': 8,
#  '花': 10,
#  '嫁': 2,
#  '西': 5,
#  '暦': 3,
#  '完': 4,
#  '璧': 1,
#  '眼': 4,
#  '科': 17,
#  '菜': 1,
#  '息': 7,
#  '禁': 5,
#  '革': 6,
#  '昼': 8,
#  '所': 22,
#  '読': 9,
#  '図': 12,
#  '絵': 4,
#  '画': 10,
#  '嚏': 1,
#  '猛': 1,
#  '烈': 2,
#  '嵩': 2,
#  '張': 13,
#  '置': 10,
#  '普': 4,
#  '遍': 1,
#  '弁': 8,
#  '解': 17,
#  '井': 3,
#  '戸': 6,
#  '墜': 1,
#  '落': 13,
#  '仕': 19,
#  '切': 28,
#  '沿': 4,
#  '岸': 3,
#  '蹴': 2,
#  '飛': 8,
#  'ば': 7,
#  '承': 5,
#  '第': 4,
#  '溶': 6,
#  '診': 5,
#  '断': 13,
#  '譲': 2,
#  '栄': 3,
#  '山': 9,
#  '岳': 1,
#  '因': 3,
#  '点': 28,
#  '格': 12,
#  '再': 11,
#  '来': 27,
#  '年': 30,
#  '願': 4,
#  '送': 12,
#  '六': 3,
#  '蓋': 2,
#  '永': 3,
#  '蚊': 1,
#  'っ': 43,
#  '暗': 7,
#  '奥': 2,
#  '制': 15,
#  '芸': 7,
#  '術': 7,
#  '映': 8,
#  '騒': 5,
#  'が': 29,
#  '月': 17,
#  '粘': 2,
#  '憎': 5,
#  '弛': 2,
#  '縮': 7,
#  '都': 6,
#  '写': 8,
#  '罵': 1,
#  '留': 9,
#  '審': 4,
#  '査': 5,
#  '少': 11,
#  '毎': 8,
#  '見': 47,
#  'せ': 30,
#  'に': 43,
#  '歩': 9,
#  '得': 10,
#  '派': 4,
#  '界': 3,
#  '耕': 4,
#  '属': 5,
#  '働': 5,
#  '帰': 7,
#  '京': 2,
#  '離': 5,
#  '飲': 4,
#  '伐': 1,
#  '賛': 2,
#  '偉': 2,
#  '球': 5,
#  '自': 28,
#  '彫': 2,
#  '勇': 3,
#  '敢': 2,
#  '言': 22,
#  '遣': 8,
#  '相': 16,
#  '互': 4,
#  '作': 25,
#  '開': 13,
#  '公': 20,
#  '募': 5,
#  '早': 6,
#  '煙': 6,
#  '関': 12,
#  '与': 5,
#  '遅': 7,
#  '過': 17,
#  '逃': 8,
#  '嫌': 6,
#  '灰': 3,
#  '色': 11,
#  '乾': 6,
#  '件': 4,
#  '訪': 3,
#  '問': 12,
#  '祖': 4,
#  '父': 3,
#  '短': 10,
#  'こ': 13,
#  '貯': 3,
#  '蔵': 6,
#  '床': 4,
#  '捩': 1,
#  '快': 6,
#  '晴': 6,
#  '規': 12,
#  '則': 4,
#  '椀': 1,
#  '焼': 5,
#  '費': 7,
#  '終': 10,
#  '修': 11,
#  '菓': 2,
#  '子': 26,
#  '昔': 1,
#  '請': 4,
#  '測': 6,
#  '結': 9,
#  '論': 19,
#  '無': 37,
#  '皿': 3,
#  '象': 7,
#  'と': 18,
#  '嬢': 2,
#  '瓶': 3,
#  '数': 22,
#  '故': 5,
#  '捕': 10,
#  '体': 30,
#  '育': 11,
#  '証': 6,
#  '明': 22,
#  '愛': 7,
#  '眠': 6,
#  'た': 23,
#  '社': 12,
#  '御': 17,
#  '飯': 7,
#  '任': 10,
#  '伴': 1,
#  '四': 8,
#  '豊': 3,
#  '索': 3,
#  '他': 5,
#  '米': 3,
#  '五': 5,
#  '寄': 14,
#  '確': 13,
#  '信': 12,
#  '羨': 2,
#  '失': 7,
#  '競': 3,
#  '馬': 6,
#  '噴': 3,
#  '個': 7,
#  '片': 9,
#  '教': 19,
#  '棄': 4,
#  '権': 8,
#  '攻': 4,
#  '苦': 12,
#  '練': 4,
#  '器': 14,
#  '偶': 5,
#  '縄': 1,
#  '食': 19,
#  '救': 5,
#  '勝': 7,
#  '両': 6,
#  '側': 4,
#  '漏': 3,
#  '健': 5,
#  '康': 1,
#  '夕': 8,
#  '刊': 4,
#  '飴': 1,
#  '抜': 5,
#  '室': 8,
#  '鋏': 1,
#  '観': 12,
#  '衆': 5,
#  '残': 8,
#  '波': 4,
#  '市': 5,
#  '場': 26,
#  '唸': 1,
#  'ざ': 5,
#  '際': 4,
#  '石': 7,
#  '渡': 5,
#  '鳥': 4,
#  '扱': 4,
#  '将': 2,
#  '煮': 2,
#  '情': 18,
#  '集': 16,
#  '様': 16,
#  '表': 10,
#  '腹': 4,
#  '処': 5,
#  '慨': 2,
#  '背': 7,
#  '期': 14,
#  '待': 10,
#  '算': 13,
#  '盤': 4,
#  '可': 5,
#  '止': 16,
#  '減': 9,
#  '報': 9,
#  '商': 7,
#  '売': 15,
#  '導': 5,
#  '臭': 3,
#  '踵': 1,
#  '鎖': 3,
#  '抱': 4,
#  '靴': 2,
#  '横': 4,
#  '綱': 2,
#  '稲': 2,
#  '工': 12,
#  '森': 2,
#  '忙': 2,
#  '療': 3,
#  '姪': 1,
#  '掴': 1,
#  '十': 5,
#  '差': 20,
#  '支': 12,
#  '晩': 5,
#  '始': 12,
#  '瓦': 2,
#  '拭': 2,
#  '適': 10,
#  '恵': 5,
#  '精': 3,
#  '非': 7,
#  '訴': 3,
#  '組': 11,
#  '囀': 1,
#  '拒': 2,
#  '否': 4,
#  '迷': 2,
#  '磨': 2,
#  '桁': 1,
#  '兎': 4,
#  '候': 3,
#  '膜': 1,
#  '重': 22,
#  '酷': 3,
#  '存': 8,
#  '焦': 5,
#  '走': 6,
#  '採': 8,
#  '獲': 3,
#  '活': 7,
#  '躍': 1,
#  '考': 7,
#  '録': 5,
#  '価': 5,
#  '元': 10,
#  '捻': 3,
#  '専': 5,
#  '絹': 1,
#  '汗': 1,
#  '左': 5,
#  '寺': 2,
#  '旅': 5,
#  '行': 40,
#  '夏': 2,
#  '話': 15,
#  '雄': 2,
#  '好': 17,
#  '意': 26,
#  '配': 14,
#  '在': 10,
#  '防': 10,
#  '毒': 4,
#  '貸': 4,
#  '捜': 3,
#  '評': 7,
#  '威': 3,
#  '匙': 1,
#  '初': 8,
#  '旬': 4,
#  '争': 7,
#  '鉄': 5,
#  '語': 20,
#  '脂': 2,
#  '肪': 1,
#  '施': 3,
#  '供': 5,
#  '誓': 1,
#  '損': 6,
#  '尿': 2,
#  '果': 8,
#  '判': 10,
#  '嘸': 1,
#  '居': 11,
#  '肌': 2,
#  '着': 24,
#  '今': 15,
#  'は': 9,
#  '若': 7,
#  '河': 3,
#  '川': 2,
#  '購': 3,
#  '買': 4,
#  '且': 1,
#  '極': 8,
#  '巧': 3,
#  '妙': 4,
#  '性': 14,
#  '資': 8,
#  '船': 7,
#  '乗': 9,
#  '造': 10,
#  '尖': 1,
#  '係': 4,
#  '眩': 1,
#  '膳': 1,
#  '消': 15,
#  '池': 3,
#  '検': 5,
#  '暴': 6,
#  '頃': 7,
#  '催': 5,
#  '院': 7,
#  '冗': 1,
#  '談': 7,
#  '予': 13,
#  '注': 7,
#  '偏': 3,
#  '敵': 2,
#  '箇': 4,
#  '経': 12,
#  '固': 7,
#  '平': 18,
#  '答': 8,
#  '案': 9,
#  '優': 12,
#  '美': 10,
#  '邸': 1,
#  '宅': 6,
#  '震': 3,
#  '呂': 3,
#  'ね': 9,
#  '雇': 2,
#  '硬': 3,
#  '政': 7,
#  '増': 10,
#  '南': 4,
#  '遷': 1,
#  '肉': 8,
#  'な': 36,
#  '寸': 1,
#  '痛': 8,
#  '静': 6,
#  '幾': 4,
#  '裕': 1,
#  '了': 6,
#  '兄': 2,
#  '弟': 2,
#  '哉': 1,
#  'ご': 8,
#  '座': 9,
#  '驚': 4,
#  '洪': 1,
#  '同': 23,
#  '房': 4,
#  '衝': 2,
#  '撃': 6,
#  '鈴': 1,
#  '富': 4,
#  '妥': 3,
#  '補': 8,
#  'ジ': 1,
#  'ェ': 1,
#  'ッ': 1,
#  'ト': 1,
#  '周': 6,
#  '辺': 5,
#  'ろ': 6,
#  '企': 2,
#  '街': 5,
#  '角': 11,
#  '治': 10,
#  '半': 8,
#  '央': 1,
#  '式': 11,
#  '削': 3,
#  '除': 9,
#  '執': 1,
#  '服': 10,
#  '砕': 2,
#  '赤': 7,
#  '像': 5,
#  '虫': 3,
#  '剥': 4,
#  '坊': 6,
#  '穴': 1,
#  '益': 4,
#  '暖': 5,
#  '説': 10,
#  '比': 7,
#  '較': 2,
#  '樹': 2,
#  '腰': 3,
#  '掛': 25,
#  '縁': 3,
#  '織': 4,
#  '善': 6,
#  '義': 7,
#  '安': 10,
#  'ぽ': 3,
#  '台': 9,
#  '矢': 4,
#  '鱈': 2,
#  '香': 3,
#  '辛': 4,
#  '裁': 6,
#  '縫': 2,
#  '位': 8,
#  '祝': 5,
#  '悩': 4,
#  '部': 18,
#  '愉': 1,
#  '層': 3,
#  '庖': 1,
#  '丁': 4,
#  '遊': 4,
#  '兆': 2,
#  '発': 16,
#  '紅': 3,
#  '葬': 2,
#  '而': 1,
#  'も': 26,
#  '炭': 3,
#  '鉱': 4,
#  '添': 2,
#  '翻': 1,
#  '訳': 8,
#  '創': 5,
#  '挟': 2,
#  '几': 1,
#  '帳': 4,
#  '申': 12,
#  '込': 23,
#  '団': 8,
#  'で': 14,
#  '率': 9,
#  '鹿': 4,
#  '雑': 7,
#  '想': 9,
#  '細': 8,
#  '券': 4,
#  '麦': 1,
#  '畑': 1,
#  '囲': 4,
#  '席': 4,
#  '効': 7,
#  '奉': 2,
#  '詞': 12,
#  '跨': 2,
#  '宙': 2,
#  '返': 15,
#  '易': 8,
#  '窮': 2,
#  '屈': 3,
#  '糧': 1,
#  '者': 16,
#  '並': 9,
#  '吹': 2,
#  '架': 2,
#  '似': 4,
#  '畳': 2,
#  '漠': 2,
#  '衣': 5,
#  '住': 10,
#  '限': 9,
#  '遥': 1,
#  '久': 4,
#  '銭': 2,
#  '駄': 5,
#  '及': 5,
#  '跡': 5,
#  '去': 4,
#  '誇': 3,
#  '還': 3,
#  '槌': 1,
#  '全': 16,
#  '拝': 5,
#  '巻': 4,
#  '歴': 4,
#  '示': 6,
#  '決': 15,
#  '齢': 1,
#  '曜': 15,
#  '惜': 2,
#  '或': 3,
#  '積': 7,
#  '叶': 2,
#  '枠': 1,
#  '堂': 4,
#  '諦': 2,
#  '牧': 4,
#  '司': 4,
#  '協': 6,
#  '髭': 1,
#  '求': 3,
#  '錯': 1,
#  '誤': 6,
#  '句': 6,
#  '垂': 2,
#  '境': 5,
#  '登': 5,
#  '薦': 1,
#  '融': 2,
#  '賜': 1,
#  '怯': 2,
#  '新': 13,
#  '散': 9,
#  '寮': 1,
#  '反': 16,
#  '備': 11,
#  '唱': 2,
#  '訓': 3,
#  '幸': 5,
#  '舞': 9,
#  '覚': 11,
#  '痩': 1,
#  '針': 4,
#  '県': 2,
#  '庁': 3,
#  '停': 6,
#  '阻': 2,
#  '突': 9,
#  '拡': 4,
#  '励': 4,
#  '冬': 2,
#  '徴': 3,
#  '収': 12,
#  '錠': 1,
#  '偽': 1,
#  '死': 6,
#  '亡': 5,
#  '田': 4,
#  '柄': 6,
#  '応': 13,
#  '援': 3,
#  '燃': 4,
#  '耳': 3,
#  '鼻': 2,
#  '匹': 1,
#  '志': 6,
#  '誉': 1,
#  '如': 1,
#  '械': 2,
#  '勉': 2,
#  'ぼ': 3,
#  '蒸': 6,
#  '呟': 1,
#  '怒': 3,
#  '鳴': 6,
#  '郡': 1,
#  '未': 10,
#  '激': 6,
#  '恨': 2,
#  '諮': 1,
#  '摩': 1,
#  '擦': 4,
#  '涙': 1,
#  '欧': 1,
#  '聞': 5,
#  '車': 16,
#  '済': 8,
#  '勿': 1,
#  '浴': 4,
#  '辞': 8,
#  '技': 7,
#  '億': 1,
#  '徐': 1,
#  '既': 2,
#  '憤': 1,
#  '条': 3,
#  '泥': 2,
#  '棒': 2,
#  '底': 3,
#  '殖': 3,
#  '粋': 2,
#  '挿': 1,
#  '裏': 5,
#  '償': 3,
#  '寧': 2,
#  'べ': 13,
#  '我': 5,
#  '音': 10,
#  '束': 5,
#  '縛': 2,
#  '慎': 2,
#  '異': 9,
#  '覆': 3,
#  '省': 4,
#  '略': 6,
#  '洗': 7,
#  '剤': 1,
#  'そ': 7,
#  '替': 7,
#  '到': 3,
#  '週': 10,
#  '助': 12,
#  ...}

# %%
max(currentChar.values())
# Out:
# 745

# %%
currentChar['々']
# Out:
# 29

# %%
true_dict
# Out:
# {'首飾り': ['くび', 'かざ', 'り'],
#  '脅迫': ['きょう', 'はく'],
#  '傾': ['けい'],
#  '整える': ['ととの', 'え', 'る'],
#  '口ずさむ': ['くち', 'ず', 'さ', 'む'],
#  '磁気': ['じ', 'き'],
#  '淡水': ['たん', 'すい'],
#  '模範': ['も', 'はん'],
#  '対照': ['たい', 'しょう'],
#  '隣': ['となり'],
#  '家屋': ['か', 'おく'],
#  '類推': ['るい', 'すい'],
#  '改正': ['かい', 'せい'],
#  '尽きる': ['つ', 'き', 'る'],
#  '各地': ['かく', 'ち'],
#  '敏感': ['びん', 'かん'],
#  '大統領': ['だい', 'とう', 'りょう'],
#  '感触': ['かん', 'しょく'],
#  '有力': ['ゆう', 'りょく'],
#  '主演': ['しゅ', 'えん'],
#  '転じる': ['てん', 'じ', 'る'],
#  '入る': ['はい', 'る'],
#  '締める': ['し', 'め', 'る'],
#  '産後': ['さん', 'ご'],
#  '変わる': ['か', 'わ', 'る'],
#  '掬う': ['すく', 'う'],
#  '産休': ['さん', 'きゅう'],
#  '道徳': ['どう', 'とく'],
#  '職員': ['しょく', 'いん'],
#  '轢く': ['ひ', 'く'],
#  '高校生': ['こう', 'こう', 'せい'],
#  '追放': ['つい', 'ほう'],
#  '文法': ['ぶん', 'ぽう'],
#  '卒業': ['そつ', 'ぎょう'],
#  '旧知': ['きゅう', 'ち'],
#  '後輩': ['こう', 'はい'],
#  '区別': ['く', 'べつ'],
#  '事務': ['じ', 'む'],
#  '従事': ['じゅう', 'じ'],
#  '奨学金': ['しょう', 'がく', 'きん'],
#  '掃く': ['は', 'く'],
#  '不動産': ['ふ', 'どう', 'さん'],
#  '生える': ['は', 'え', 'る'],
#  '独占': ['どく', 'せん'],
#  '凝る': ['こご', 'る'],
#  '委託': ['い', 'たく'],
#  '級': ['きゅう'],
#  '塾': ['じゅく'],
#  '歯': ['は'],
#  '思い付き': ['おも', 'い', 'つ', 'き'],
#  '外貨': ['がい', 'か'],
#  '現代': ['げん', 'だい'],
#  '近付ける': ['ちか', 'づ', 'け', 'る'],
#  '顕微鏡': ['けん', 'び', 'きょう'],
#  '常識': ['じょう', 'しき'],
#  '習字': ['しゅう', 'じ'],
#  '屋上': ['おく', 'じょう'],
#  '受け取り': ['う', 'け', 'と', 'り'],
#  '吊す': ['つる', 'す'],
#  '加速度': ['か', 'そく', 'ど'],
#  '強まる': ['つよ', 'ま', 'る'],
#  '合致': ['がっ', 'ち'],
#  '熱量': ['ねつ', 'りょう'],
#  '先頭': ['せん', 'とう'],
#  '一連': ['いち', 'れん'],
#  '思い付く': ['おも', 'い', 'つ', 'く'],
#  '仮定': ['か', 'てい'],
#  '署名': ['しょ', 'めい'],
#  '贅沢': ['ぜい', 'たく'],
#  '独身': ['どく', 'しん'],
#  '家計': ['か', 'けい'],
#  '厳密': ['げん', 'みつ'],
#  '閉会': ['へい', 'かい'],
#  '孤児': ['こ', 'じ'],
#  '天国': ['てん', 'ごく'],
#  '使い道': ['つか', 'い', 'みち'],
#  '冊': ['さつ'],
#  '弱': ['じゃく'],
#  '蛋白質': ['たん', 'ぱく', 'しつ'],
#  '火災': ['か', 'さい'],
#  '介入': ['かい', 'にゅう'],
#  '畜生': ['ちく', 'しょう'],
#  '交ぜる': ['ま', 'ぜ', 'る'],
#  '暮れる': ['く', 'れ', 'る'],
#  '空中': ['くう', 'ちゅう'],
#  '選手': ['せん', 'しゅ'],
#  '気味': ['き', 'み'],
#  '人物': ['じん', 'ぶつ'],
#  '為す': ['な', 'す'],
#  '記す': ['しる', 'す'],
#  '取り戻す': ['と', 'り', 'もど', 'す'],
#  '伝達': ['でん', 'たつ'],
#  '頬': ['ほほ'],
#  '染まる': ['そ', 'ま', 'る'],
#  '酸素': ['さん', 'そ'],
#  '上下': ['じょう', 'げ'],
#  '青い': ['あお', 'い'],
#  '保温': ['ほ', 'おん'],
#  '遠足': ['えん', 'そく'],
#  '道具': ['どう', 'ぐ'],
#  '布告': ['ふ', 'こく'],
#  '首脳': ['しゅ', 'のう'],
#  '降水': ['こう', 'すい'],
#  '狙う': ['ねら', 'う'],
#  '製品': ['せい', 'ひん'],
#  '出迎える': ['で', 'むか', 'え', 'る'],
#  '光る': ['ひか', 'る'],
#  '望ましい': ['のぞ', 'ま', 'し', 'い'],
#  '試みる': ['こころ', 'み', 'る'],
#  '柵': ['さく'],
#  '原油': ['げん', 'ゆ'],
#  '中世': ['ちゅう', 'せい'],
#  '領域': ['りょう', 'いき'],
#  '慕う': ['した', 'う'],
#  '友': ['とも'],
#  '契る': ['ちぎ', 'る'],
#  '特別': ['とく', 'べつ'],
#  '景気': ['けい', 'き'],
#  '目下': ['め', 'した'],
#  '議題': ['ぎ', 'だい'],
#  '就く': ['つ', 'く'],
#  '当て': ['あ', 'て'],
#  '何々': ['なに', 'なに'],
#  'お金': ['お', 'かね'],
#  '国有': ['こく', 'ゆう'],
#  '恥じらう': ['は', 'じ', 'ら', 'う'],
#  '薄い': ['うす', 'い'],
#  '分担': ['ぶん', 'たん'],
#  '用紙': ['よう', 'し'],
#  '砂利': ['じゃ', 'り'],
#  '生理': ['せい', 'り'],
#  '流通': ['りゅう', 'つう'],
#  '筒': ['つつ'],
#  '後回し': ['あと', 'まわ', 'し'],
#  '下地': ['した', 'じ'],
#  '利根': ['り', 'こん'],
#  '随筆': ['ずい', 'ひつ'],
#  '向く': ['む', 'く'],
#  '現状': ['げん', 'じょう'],
#  '恥': ['はじ'],
#  '基礎': ['き', 'そ'],
#  '満員': ['まん', 'いん'],
#  '宿命': ['しゅく', 'めい'],
#  '実物': ['じつ', 'ぶつ'],
#  '満ちる': ['み', 'ち', 'る'],
#  '舟': ['ふね'],
#  '長官': ['ちょう', 'かん'],
#  '域外': ['いき', 'がい'],
#  '回': ['かい'],
#  '農地': ['のう', 'ち'],
#  '不良': ['ふ', 'りょう'],
#  '薬品': ['やく', 'ひん'],
#  '給料': ['きゅう', 'りょう'],
#  '前例': ['ぜん', 'れい'],
#  '以て': ['もっ', 'て'],
#  '軍艦': ['ぐん', 'かん'],
#  '当選': ['とう', 'せん'],
#  '料': ['りょう'],
#  '必需品': ['ひつ', 'じゅ', 'ひん'],
#  '代用': ['だい', 'よう'],
#  '浮く': ['う', 'く'],
#  '機会': ['き', 'かい'],
#  '罹る': ['かか', 'る'],
#  '卯': ['ぼう'],
#  '戻る': ['もど', 'る'],
#  '運搬': ['うん', 'ぱん'],
#  '姓名': ['せい', 'めい'],
#  '続く': ['つづ', 'く'],
#  '前': ['まえ'],
#  '依然': ['い', 'ぜん'],
#  '破裂': ['は', 'れつ'],
#  '兼業': ['けん', 'ぎょう'],
#  '命': ['いのち'],
#  '財産': ['ざい', 'さん'],
#  '小学生': ['しょう', 'がく', 'せい'],
#  '割合': ['わり', 'あい'],
#  '頑丈': ['がん', 'じょう'],
#  '親指': ['おや', 'ゆび'],
#  '以内': ['い', 'ない'],
#  '近く': ['ちか', 'く'],
#  '生じる': ['しょう', 'じ', 'る'],
#  '照る': ['て', 'る'],
#  '崩す': ['くず', 'す'],
#  '泳ぐ': ['およ', 'ぐ'],
#  '面会': ['めん', 'かい'],
#  '沈殿': ['ちん', 'でん'],
#  '土地': ['と', 'ち'],
#  '午後': ['ご', 'ご'],
#  '欲しい': ['ほ', 'し', 'い'],
#  '刻む': ['きざ', 'む'],
#  '包帯': ['ほう', 'たい'],
#  '真ん中': ['ま', 'ん', 'なか'],
#  '学ぶ': ['まな', 'ぶ'],
#  '茶の間': ['ちゃ', 'の', 'ま'],
#  '野心': ['や', 'しん'],
#  '礼儀': ['れい', 'ぎ'],
#  '高等': ['こう', 'とう'],
#  '館': ['かん'],
#  '例外': ['れい', 'がい'],
#  '交渉': ['こう', 'しょう'],
#  '丸める': ['まる', 'め', 'る'],
#  '鉢': ['はち'],
#  '本棚': ['ほん', 'だな'],
#  '原書': ['げん', 'しょ'],
#  '腐る': ['くさ', 'る'],
#  '当日': ['とう', 'じつ'],
#  '七': ['なな'],
#  '冷やかす': ['ひ', 'や', 'か', 'す'],
#  '国連': ['こく', 'れん'],
#  '爆弾': ['ばく', 'だん'],
#  '怪しい': ['あや', 'し', 'い'],
#  '退ける': ['ど', 'け', 'る'],
#  '電線': ['でん', 'せん'],
#  '混乱': ['こん', 'らん'],
#  '契約': ['けい', 'やく'],
#  '民間': ['みん', 'かん'],
#  '起きる': ['お', 'き', 'る'],
#  '成り立つ': ['な', 'り', 'た', 'つ'],
#  '遭難': ['そう', 'なん'],
#  '逆上る': ['さか', 'のぼ', 'る'],
#  '準急': ['じゅん', 'きゅう'],
#  '引き取る': ['ひ', 'き', 'と', 'る'],
#  '水源': ['すい', 'げん'],
#  '休戦': ['きゅう', 'せん'],
#  '歪む': ['いが', 'む'],
#  '詫びる': ['わ', 'び', 'る'],
#  '腕前': ['うで', 'まえ'],
#  '日の出': ['ひ', 'の', 'で'],
#  '形態': ['けい', 'たい'],
#  '葉': ['は'],
#  '勤まる': ['つと', 'ま', 'る'],
#  '通知': ['つう', 'ち'],
#  '養う': ['やしな', 'う'],
#  '和らげる': ['やわ', 'ら', 'げ', 'る'],
#  '犯す': ['おか', 'す'],
#  '保母': ['ほ', 'ぼ'],
#  '強化': ['きょう', 'か'],
#  '水気': ['すい', 'き'],
#  '余興': ['よ', 'きょう'],
#  '土木': ['ど', 'ぼく'],
#  '風景': ['ふう', 'けい'],
#  '低下': ['てい', 'か'],
#  '方向': ['ほう', 'こう'],
#  '討つ': ['う', 'つ'],
#  '水': ['みず'],
#  '害する': ['がい', 'す', 'る'],
#  '日常': ['にち', 'じょう'],
#  '近付く': ['ちか', 'づ', 'く'],
#  '莫大': ['ばく', 'だい'],
#  '利害': ['り', 'がい'],
#  '惑星': ['わく', 'せい'],
#  '労力': ['ろう', 'りょく'],
#  '花嫁': ['はな', 'よめ'],
#  '西暦': ['せい', 'れき'],
#  '完璧': ['かん', 'ぺき'],
#  '眼科': ['がん', 'か'],
#  '野菜': ['や', 'さい'],
#  '一息': ['ひと', 'いき'],
#  '禁じる': ['きん', 'じ', 'る'],
#  '吊り革': ['つ', 'り', 'かわ'],
#  '昼休み': ['ひる', 'やす', 'み'],
#  '近所': ['きん', 'じょ'],
#  '読む': ['よ', 'む'],
#  '指図': ['さし', 'ず'],
#  '絵画': ['かい', 'が'],
#  '実現': ['じつ', 'げん'],
#  '財布': ['さい', 'ふ'],
#  '嚏': ['くしゃみ'],
#  '猛烈': ['もう', 'れつ'],
#  '嵩張る': ['かさ', 'ば', 'る'],
#  '置く': ['お', 'く'],
#  '普遍': ['ふ', 'へん'],
#  '弁解': ['べん', 'かい'],
#  '井戸': ['い', 'ど'],
#  '墜落': ['つい', 'らく'],
#  '仕切る': ['し', 'き', 'る'],
#  '沿岸': ['えん', 'がん'],
#  '蹴飛ばす': ['け', 'と', 'ば', 'す'],
#  '承知': ['しょう', 'ち'],
#  '心理': ['しん', 'り'],
#  '第': ['だい'],
#  '溶ける': ['と', 'け', 'る'],
#  '農業': ['のう', 'ぎょう'],
#  '診断': ['しん', 'だん'],
#  '譲る': ['ゆず', 'る'],
#  '栄える': ['さか', 'え', 'る'],
#  '山岳': ['さん', 'がく'],
#  '降り出す': ['ふ', 'り', 'だ', 'す'],
#  '回転': ['かい', 'てん'],
#  '因る': ['よ', 'る'],
#  '原点': ['げん', 'てん'],
#  '合格': ['ごう', 'かく'],
#  '再来年': ['さ', 'らい', 'ねん'],
#  '願書': ['がん', 'しょ'],
#  '回送': ['かい', 'そう'],
#  '六日': ['むい', 'か'],
#  '目蓋': ['ま', 'ぶた'],
#  '永遠': ['えい', 'えん'],
#  '蚊': ['か'],
#  '真っ暗': ['ま', 'っ', 'くら'],
#  '奥': ['おく'],
#  '制度': ['せい', 'ど'],
#  '六つ': ['むっ', 'つ'],
#  '芸術': ['げい', 'じゅつ'],
#  '映す': ['うつ', 'す'],
#  '騒がしい': ['さわ', 'が', 'し', 'い'],
#  '来月': ['らい', 'げつ'],
#  '粘り': ['ねば', 'り'],
#  '区域': ['く', 'いき'],
#  '一目': ['いち', 'もく'],
#  '憎しみ': ['にく', 'し', 'み'],
#  '弛む': ['たる', 'む'],
#  '統制': ['とう', 'せい'],
#  '中味': ['なか', 'み'],
#  '児': ['こ'],
#  '縮小': ['しゅく', 'しょう'],
#  '合成': ['ごう', 'せい'],
#  '都': ['と'],
#  '写す': ['うつ', 'す'],
#  '下水': ['げ', 'すい'],
#  '罵る': ['ののし', 'る'],
#  '留まる': ['と', 'ま', 'る'],
#  '正面': ['しょう', 'めん'],
#  '審査': ['しん', 'さ'],
#  '少々': ['しょう', 'しょう'],
#  '毎日': ['まい', 'にち'],
#  '見せ物': ['み', 'せ', 'もの'],
#  '大いに': ['おお', 'い', 'に'],
#  '歩': ['ふ'],
#  '所得': ['しょ', 'とく'],
#  '特派': ['とく', 'は'],
#  '不当': ['ふ', 'とう'],
#  '世界': ['せ', 'かい'],
#  'お大事に': ['お', 'だい', 'じ', 'に'],
#  '農耕': ['のう', 'こう'],
#  '受かる': ['う', 'か', 'る'],
#  '属する': ['ぞく', 'す', 'る'],
#  '働': ['どう'],
#  '記入': ['き', 'にゅう'],
#  '帰京': ['き', 'きょう'],
#  '分離': ['ぶん', 'り'],
#  '飲み物': ['の', 'み', 'もの'],
#  '伐': ['ばつ'],
#  '賛成': ['さん', 'せい'],
#  '偉大': ['い', 'だい'],
#  '電球': ['でん', 'きゅう'],
#  '自首': ['じ', 'しゅ'],
#  '彫刻': ['ちょう', 'こく'],
#  '出くわす': ['で', 'く', 'わ', 'す'],
#  '勇敢': ['ゆう', 'かん'],
#  '浮力': ['ふ', 'りょく'],
#  '言葉遣い': ['こと', 'ば', 'づか', 'い'],
#  '相互': ['そう', 'ご'],
#  '作る': ['つく', 'る'],
#  '開ける': ['あ', 'け', 'る'],
#  '公募': ['こう', 'ぼ'],
#  '早い': ['はや', 'い'],
#  '禁煙': ['きん', 'えん'],
#  '関与': ['かん', 'よ'],
#  'やっ付ける': ['や', 'っ', 'つ', 'け', 'る'],
#  '保養': ['ほ', 'よう'],
#  '弾く': ['ひ', 'く'],
#  '遅れ': ['おく', 'れ'],
#  '過密': ['か', 'みつ'],
#  '逃げ出す': ['に', 'げ', 'だ', 'す'],
#  '機嫌': ['き', 'げん'],
#  '人目': ['じん', 'もく'],
#  '灰色': ['はい', 'いろ'],
#  '地区': ['ち', 'く'],
#  '乾': ['かん'],
#  '用件': ['よう', 'けん'],
#  '小': ['しょう'],
#  '訪問': ['ほう', 'もん'],
#  '祖父': ['そ', 'ふ'],
#  '短所': ['たん', 'しょ'],
#  'この間': ['こ', 'の', 'あいだ'],
#  '貯蔵': ['ちょ', 'ぞう'],
#  '床': ['ゆか'],
#  '捩る': ['ねじ', 'る'],
#  '快晴': ['かい', 'せい'],
#  '一々': ['いち', 'いち'],
#  '不規則': ['ふ', 'き', 'そく'],
#  '椀': ['わん'],
#  '難しい': ['むずか', 'し', 'い'],
#  '日焼け': ['ひ', 'や', 'け'],
#  '費': ['ひ'],
#  '終わり': ['お', 'わ', 'り'],
#  '修理': ['しゅう', 'り'],
#  'お菓子': ['お', 'か', 'し'],
#  '昔': ['むかし'],
#  '請う': ['こ', 'う'],
#  '産物': ['さん', 'ぶつ'],
#  '測る': ['はか', 'る'],
#  '結論': ['けつ', 'ろん'],
#  '感無量': ['かん', 'む', 'りょう'],
#  '灰皿': ['はい', 'ざら'],
#  '象': ['ぞう'],
#  'すると': ['す', 'る', 'と'],
#  '嬢': ['じょう'],
#  '花瓶': ['か', 'びん'],
#  '基地': ['き', 'ち'],
#  '整数': ['せい', 'すう'],
#  '故': ['こ'],
#  '捕らえる': ['と', 'ら', 'え', 'る'],
#  '体育': ['たい', 'いく'],
#  '有りのまま': ['あ', 'り', 'の', 'ま', 'ま'],
#  '等しい': ['ひと', 'し', 'い'],
#  '修学': ['しゅう', 'がく'],
#  '証明': ['しょう', 'めい'],
#  '愛する': ['あい', 'す', 'る'],
#  '眠たい': ['ねむ', 'た', 'い'],
#  '入社': ['にゅう', 'しゃ'],
#  '形': ['かたち'],
#  '昼御飯': ['ひる', 'ご', 'はん'],
#  '任務': ['にん', 'む'],
#  '伴う': ['ともな', 'う'],
#  '会見': ['かい', 'けん'],
#  '四つ': ['よっ', 'つ'],
#  '豊作': ['ほう', 'さく'],
#  '模索': ['も', 'さく'],
#  '他人': ['た', 'にん'],
#  '米': ['こめ'],
#  '会う': ['あ', 'う'],
#  '五つ': ['いつ', 'つ'],
#  '立ち寄る': ['た', 'ち', 'よ', 'る'],
#  '確信': ['かく', 'しん'],
#  '羨ましい': ['うらや', 'ま', 'し', 'い'],
#  '失う': ['うしな', 'う'],
#  '競馬': ['けい', 'ば'],
#  '噴火': ['ふん', 'か'],
#  '力': ['ちから'],
#  '個別': ['こ', 'べつ'],
#  '片思い': ['かた', 'おも', 'い'],
#  '教育': ['きょう', 'いく'],
#  '棄権': ['き', 'けん'],
#  '攻め': ['せ', 'め'],
#  '苦労': ['く', 'ろう'],
#  '練習': ['れん', 'しゅう'],
#  '実る': ['みの', 'る'],
#  '器用': ['き', 'よう'],
#  '偶々': ['たま', 'たま'],
#  '子': ['こ'],
#  '縄': ['なわ'],
#  '食品': ['しょく', 'ひん'],
#  '救い': ['すく', 'い'],
#  '締切': ['しめ', 'きり'],
#  '勝ち': ['か', 'ち'],
#  '生る': ['な', 'る'],
#  '両側': ['りょう', 'がわ'],
#  '漏れる': ['も', 'れ', 'る'],
#  '健康': ['けん', 'こう'],
#  '夕刊': ['ゆう', 'かん'],
#  '祖先': ['そ', 'せん'],
#  '飴': ['あめ'],
#  '真ん丸い': ['ま', 'ん', 'まる', 'い'],
#  '抜かす': ['ぬ', 'か', 'す'],
#  '短大': ['たん', 'だい'],
#  '教室': ['きょう', 'しつ'],
#  '鋏': ['はさみ'],
#  '観衆': ['かん', 'しゅう'],
#  '残金': ['ざん', 'きん'],
#  '波': ['なみ'],
#  '市場': ['いち', 'ば'],
#  '唸る': ['うな', 'る'],
#  '混ざる': ['ま', 'ざ', 'る'],
#  '際': ['さい'],
#  '石油': ['せき', 'ゆ'],
#  '金': ['きん'],
#  '作り': ['つく', 'り'],
#  '渡り鳥': ['わた', 'り', 'どり'],
#  '取り扱い': ['と', 'り', 'あつか', 'い'],
#  '生まれ': ['う', 'ま', 'れ'],
#  '将来': ['しょう', 'らい'],
#  '加える': ['くわ', 'え', 'る'],
#  '流す': ['なが', 'す'],
#  '煮える': ['に', 'え', 'る'],
#  '心情': ['しん', 'じょう'],
#  '尽くす': ['つ', 'く', 'す'],
#  '集金': ['しゅう', 'きん'],
#  '様相': ['よう', 'そう'],
#  '表す': ['あらわ', 'す'],
#  '腹立ち': ['はら', 'だ', 'ち'],
#  '処置': ['しょ', 'ち'],
#  '感慨': ['かん', 'がい'],
#  '背後': ['はい', 'ご'],
#  '整う': ['ととの', 'う'],
#  '期待': ['き', 'たい'],
#  '算盤': ['そろ', 'ばん'],
#  '奥さん': ['おく', 'さ', 'ん'],
#  '可': ['か'],
#  '完成': ['かん', 'せい'],
#  '止む': ['や', 'む'],
#  'いい加減': ['い', 'い', 'か', 'げん'],
#  '情報': ['じょう', 'ほう'],
#  '特定': ['とく', 'てい'],
#  '出切る': ['で', 'き', 'る'],
#  '以上': ['い', 'じょう'],
#  '酸': ['さん'],
#  '天体': ['てん', 'たい'],
#  '映る': ['うつ', 'る'],
#  '引く': ['ひ', 'く'],
#  '商売': ['しょう', 'ばい'],
#  '導入': ['どう', 'にゅう'],
#  '生臭い': ['なま', 'ぐさ', 'い'],
#  '何分': ['なに', 'ぶん'],
#  '踵': ['かかと'],
#  '閉鎖': ['へい', 'さ'],
#  '介抱': ['かい', 'ほう'],
#  '習う': ['なら', 'う'],
#  '靴': ['くつ'],
#  '残り': ['のこ', 'り'],
#  '横綱': ['よこ', 'づな'],
#  '稲光': ['いな', 'びかり'],
#  '大切': ['たい', 'せつ'],
#  '格別': ['かく', 'べつ'],
#  '従来': ['じゅう', 'らい'],
#  '衆': ['しゅう'],
#  '加工': ['か', 'こう'],
#  '森': ['もり'],
#  '忙しい': ['いそが', 'し', 'い'],
#  '診療': ['しん', 'りょう'],
#  '姪': ['めい'],
#  '掴む': ['つか', 'む'],
#  '十': ['とお'],
#  '満足': ['まん', 'ぞく'],
#  '差し支える': ['さ', 'し', 'つか', 'え', 'る'],
#  '手術': ['しゅ', 'じゅつ'],
#  '毎晩': ['まい', 'ばん'],
#  '起源': ['き', 'げん'],
#  '始める': ['はじ', 'め', 'る'],
#  '瓦': ['かわら'],
#  '手拭い': ['て', 'ぬぐ', 'い'],
#  '適用': ['てき', 'よう'],
#  '知恵': ['ち', 'え'],
#  '精密': ['せい', 'みつ'],
#  '非難': ['ひ', 'なん'],
#  '訴える': ['うった', 'え', 'る'],
#  '組む': ['く', 'む'],
#  '蔵相': ['ぞう', 'しょう'],
#  '囀る': ['さえず', 'る'],
#  '仕組み': ['し', 'く', 'み'],
#  '拒否': ['きょ', 'ひ'],
#  '問屋': ['とい', 'や'],
#  '迷信': ['めい', 'しん'],
#  '歯磨き': ['は', 'みが', 'き'],
#  '漏らす': ['も', 'ら', 'す'],
#  '代る': ['かわ', 'る'],
#  '事情': ['じ', 'じょう'],
#  '桁': ['けた'],
#  '導く': ['みちび', 'く'],
#  '兎': ['うさぎ'],
#  '天候': ['てん', 'こう'],
#  '膜': ['まく'],
#  '重': ['え'],
#  '酷い': ['ひど', 'い'],
#  '存じる': ['ぞん', 'じ', 'る'],
#  '自信': ['じ', 'しん'],
#  '焦点': ['しょう', 'てん'],
#  '逃走': ['とう', 'そう'],
#  '採る': ['と', 'る'],
#  '製': ['せい'],
#  '獲物': ['え', 'もの'],
#  '活躍': ['かつ', 'やく'],
#  '勤務': ['きん', 'む'],
#  '選考': ['せん', 'こう'],
#  '記録': ['き', 'ろく'],
#  '価格': ['か', 'かく'],
#  '元首': ['げん', 'しゅ'],
#  '期間': ['き', 'かん'],
#  '捻子': ['ね', 'じ'],
#  '専用': ['せん', 'よう'],
#  '絹': ['きぬ'],
#  '受身': ['うけ', 'み'],
#  '言論': ['げん', 'ろん'],
#  'お先に': ['お', 'さき', 'に'],
#  '重大': ['じゅう', 'だい'],
#  '汗': ['あせ'],
#  '近々': ['きん', 'きん'],
#  '左利き': ['ひだり', 'き', 'き'],
#  '抜ける': ['ぬ', 'け', 'る'],
#  '蓋': ['ふた'],
#  '寺': ['てら'],
#  '旅行': ['りょ', 'こう'],
#  '夏': ['なつ'],
#  '会話': ['かい', 'わ'],
#  '雄': ['おす'],
#  '包む': ['つつ', 'む'],
#  '見事': ['み', 'ごと'],
#  '好意': ['こう', 'い'],
#  '気配': ['け', 'はい'],
#  '在る': ['あ', 'る'],
#  '動作': ['どう', 'さ'],
#  '防犯': ['ぼう', 'はん'],
#  '家出': ['いえ', 'で'],
#  '気の毒': ['き', 'の', 'どく'],
#  '家': ['いえ'],
#  '流行': ['りゅう', 'こう'],
#  '教わる': ['おそ', 'わ', 'る'],
#  '貸間': ['かし', 'ま'],
#  '捜査': ['そう', 'さ'],
#  '評価': ['ひょう', 'か'],
#  '威力': ['い', 'りょく'],
#  '匙': ['さじ'],
#  '初旬': ['しょ', 'じゅん'],
#  '写生': ['しゃ', 'せい'],
#  '通り': ['とお', 'り'],
#  '争う': ['あらそ', 'う'],
#  '年長': ['ねん', 'ちょう'],
#  '地下鉄': ['ち', 'か', 'てつ'],
#  '語学': ['ご', 'がく'],
#  '脂肪': ['し', 'ぼう'],
#  '施行': ['し', 'ぎょう'],
#  'お供': ['お', 'とも'],
#  '誓う': ['ちか', 'う'],
#  '損害': ['そん', 'がい'],
#  '原文': ['げん', 'ぶん'],
#  '高級': ['こう', 'きゅう'],
#  '尿': ['にょう'],
#  '果てる': ['は', 'て', 'る'],
#  '評判': ['ひょう', 'ばん'],
#  '小遣い': ['こ', 'づか', 'い'],
#  '演出': ['えん', 'しゅつ'],
#  '嘸': ['さぞ'],
#  '子供': ['こ', 'ども'],
#  '鳥居': ['とり', 'い'],
#  '肌着': ['はだ', 'ぎ'],
#  '今晩は': ['こん', 'ばん', 'は'],
#  '若しかして': ['も', 'し', 'か', 'し', 'て'],
#  '外観': ['がい', 'かん'],
#  '河川': ['か', 'せん'],
#  '購買': ['こう', 'ばい'],
#  '且つ': ['か', 'つ'],
#  '極めて': ['きわ', 'め', 'て'],
#  '居間': ['い', 'ま'],
#  '巧妙': ['こう', 'みょう'],
#  '家事': ['か', 'じ'],
#  '合間': ['あい', 'ま'],
#  '主張': ['しゅ', 'ちょう'],
#  '脅す': ['おど', 'す'],
#  '個性': ['こ', 'せい'],
#  '通勤': ['つう', 'きん'],
#  '資格': ['し', 'かく'],
#  '休業': ['きゅう', 'ぎょう'],
#  '字引': ['じ', 'びき'],
#  '船': ['ふね'],
#  '乗る': ['の', 'る'],
#  '製造': ['せい', 'ぞう'],
#  '受話器': ['じゅ', 'わ', 'き'],
#  '尖る': ['とが', 'る'],
#  '気風': ['き', 'ふう'],
#  '係り': ['かか', 'り'],
#  '強いる': ['し', 'い', 'る'],
#  '眩しい': ['まぶ', 'し', 'い'],
#  '膳': ['ぜん'],
#  'お代わり': ['お', 'か', 'わ', 'り'],
#  '消す': ['け', 'す'],
#  '本体': ['ほん', 'たい'],
#  '乾電池': ['かん', 'でん', 'ち'],
#  '点検': ['てん', 'けん'],
#  '暴れる': ['あば', 'れ', 'る'],
#  'この頃': ['こ', 'の', 'ごろ'],
#  '催す': ['もよお', 'す'],
#  '退院': ['たい', 'いん'],
#  '冗談': ['じょう', 'だん'],
#  '予防': ['よ', 'ぼう'],
#  '注目': ['ちゅう', 'もく'],
#  '追い出す': ['お', 'い', 'だ', 'す'],
#  '物差し': ['もの', 'さ', 'し'],
#  '偏': ['へん'],
#  '素敵': ['す', 'てき'],
#  '箇箇': ['こ', 'こ'],
#  '側': ['そば'],
#  '工業': ['こう', 'ぎょう'],
#  '経過': ['けい', 'か'],
#  '固有': ['こ', 'ゆう'],
#  '始めまして': ['はじ', 'め', 'ま', 'し', 'て'],
#  '風土': ['ふう', 'ど'],
#  '水平線': ['すい', 'へい', 'せん'],
#  '答案': ['とう', 'あん'],
#  '優美': ['ゆう', 'び'],
#  '割れる': ['わ', 'れ', 'る'],
#  '邸宅': ['てい', 'たく'],
#  '勇気': ['ゆう', 'き'],
#  '震わせる': ['ふる', 'わ', 'せ', 'る'],
#  '理性': ['り', 'せい'],
#  '風呂': ['ふ', 'ろ'],
#  'ねじ回し': ['ね', 'じ', 'まわ', 'し'],
#  '交える': ['まじ', 'え', 'る'],
#  '馬': ['うま'],
#  '栄養': ['えい', 'よう'],
#  '雇う': ['やと', 'う'],
#  '言い出す': ['い', 'い', 'だ', 'す'],
#  '硬い': ['かた', 'い'],
#  '会社': ['かい', 'しゃ'],
#  '成長': ['せい', 'ちょう'],
#  '五': ['ご'],
#  '上げる': ['あ', 'げ', 'る'],
#  '付き': ['つ', 'き'],
#  '裂く': ['さ', 'く'],
#  '政権': ['せい', 'けん'],
#  '増強': ['ぞう', 'きょう'],
#  '主催': ['しゅ', 'さい'],
#  '大空': ['おお', 'ぞら'],
#  '南極': ['なん', 'きょく'],
#  '変遷': ['へん', 'せん'],
#  '暮れ': ['く', 'れ'],
#  '独立': ['どく', 'りつ'],
#  '肉': ['にく'],
#  '密な': ['みつ', 'な'],
#  '寸法': ['すん', 'ぽう'],
#  '意味': ['い', 'み'],
#  '彫る': ['ほ', 'る'],
#  '運動': ['うん', 'どう'],
#  '痛む': ['いた', 'む'],
#  'とり肉': ['と', 'り', 'にく'],
#  '苦心': ['く', 'しん'],
#  '冷静': ['れい', 'せい'],
#  '幾ら': ['いく', 'ら'],
#  '自主': ['じ', 'しゅ'],
#  '余裕': ['よ', 'ゆう'],
#  '終了': ['しゅう', 'りょう'],
#  '気体': ['き', 'たい'],
#  '兄弟': ['きょう', 'だい'],
#  '迷惑': ['めい', 'わく'],
#  '哉': ['や'],
#  '差': ['さ'],
#  'ご座います': ['ご', 'ざ', 'い', 'ま', 'す'],
#  '驚かす': ['おどろ', 'か', 'す'],
#  '手際': ['て', 'ぎわ'],
#  '洪水': ['こう', 'ずい'],
#  '同意': ['どう', 'い'],
#  '冷房': ['れい', 'ぼう'],
#  '衝撃': ['しょう', 'げき'],
#  '存続': ['そん', 'ぞく'],
#  '若しかしたら': ['も', 'し', 'か', 'し', 'た', 'ら'],
#  '鈴': ['すず'],
#  '解答': ['かい', 'とう'],
#  '天気': ['てん', 'き'],
#  '切れる': ['き', 'れ', 'る'],
#  '通用': ['つう', 'よう'],
#  '思わず': ['おも', 'わ', 'ず'],
#  '漏る': ['も', 'る'],
#  '冷える': ['ひ', 'え', 'る'],
#  '富': ['とみ'],
#  '妥結': ['だ', 'けつ'],
#  '補足': ['ほ', 'そく'],
#  'ジェット機': ['ジ', 'ェ', 'ッ', 'ト', 'き'],
#  '周辺': ['しゅう', 'へん'],
#  '見学': ['けん', 'がく'],
#  '降ろす': ['お', 'ろ', 'す'],
#  '企業': ['き', 'ぎょう'],
#  '逃がす': ['に', 'が', 'す'],
#  '街角': ['まち', 'かど'],
#  '治まる': ['おさ', 'ま', 'る'],
#  '半ば': ['なか', 'ば'],
#  '中央': ['ちゅう', 'おう'],
#  '科目': ['か', 'もく'],
#  '方言': ['ほう', 'げん'],
#  '公式': ['こう', 'しき'],
#  '削除': ['さく', 'じょ'],
#  '執着': ['しゅう', 'じゃく'],
#  '和服': ['わ', 'ふく'],
#  '無理': ['む', 'り'],
#  '水分': ['すい', 'ぶん'],
#  '砕ける': ['くだ', 'け', 'る'],
#  '余計': ['よ', 'けい'],
#  '赤らむ': ['あか', 'ら', 'む'],
#  '現像': ['げん', 'ぞう'],
#  '何': ['なに'],
#  '虫': ['むし'],
#  '剥ぐ': ['は', 'ぐ'],
#  '坊さん': ['ぼう', 'さ', 'ん'],
#  '穴': ['あな'],
#  '言伝': ['こと', 'づて'],
#  '利益': ['り', 'えき'],
#  '温暖': ['おん', 'だん'],
#  '写る': ['うつ', 'る'],
#  '社説': ['しゃ', 'せつ'],
#  '受け止める': ['う', 'け', 'と', 'め', 'る'],
#  '一面': ['いち', 'めん'],
#  '乾かす': ['かわ', 'か', 'す'],
#  '比較': ['ひ', 'かく'],
#  '樹立': ['じゅ', 'りつ'],
#  '当たり前': ['あ', 'た', 'り', 'まえ'],
#  '原子': ['げん', 'し'],
#  '分母': ['ぶん', 'ぼ'],
#  '腰掛ける': ['こし', 'か', 'け', 'る'],
#  '縁': ['ふち'],
#  '織る': ['お', 'る'],
#  '耕作': ['こう', 'さく'],
#  '親善': ['しん', 'ぜん'],
#  '制': ['せい'],
#  '送り仮名': ['おく', 'り', 'が', 'な'],
#  '下': ['しも'],
#  '畜産': ['ちく', 'さん'],
#  '定義': ['てい', 'ぎ'],
#  '安っぽい': ['やす', 'っ', 'ぽ', 'い'],
#  '騒ぐ': ['さわ', 'ぐ'],
#  '思い出す': ['おも', 'い', 'だ', 'す'],
#  '水平': ['すい', 'へい'],
#  '測量': ['そく', 'りょう'],
#  '台': ['だい'],
#  '矢鱈に': ['や', 'たら', 'に'],
#  '了': ['りょう'],
#  '香辛料': ['こう', 'しん', 'りょう'],
#  '裁縫': ['さい', 'ほう'],
#  '再': ['さい'],
#  '優位': ['ゆう', 'い'],
#  '祝う': ['いわ', 'う'],
#  '悩ます': ['なや', 'ま', 'す'],
#  '外部': ['がい', 'ぶ'],
#  '愉快': ['ゆ', 'かい'],
#  '状': ['じょう'],
#  '高層': ['こう', 'そう'],
#  '予感': ['よ', 'かん'],
#  '関連': ['かん', 'れん'],
#  '庖丁': ['ほう', 'ちょう'],
#  '使う': ['つか', 'う'],
#  '育つ': ['そだ', 'つ'],
#  '厳しい': ['きび', 'し', 'い'],
#  '遊び': ['あそ', 'び'],
#  '夕立': ['ゆう', 'だち'],
#  '兆': ['きざし'],
#  '再発': ['さい', 'はつ'],
#  '体付き': ['からだ', 'つ', 'き'],
#  '帰る': ['かえ', 'る'],
#  '花火': ['はな', 'び'],
#  '紅茶': ['こう', 'ちゃ'],
#  '強引': ['ごう', 'いん'],
#  '弱まる': ['よわ', 'ま', 'る'],
#  '抱く': ['いだ', 'く'],
#  '革': ['かわ'],
#  '過ごす': ['す', 'ご', 'す'],
#  '農場': ['のう', 'じょう'],
#  '葬る': ['ほうむ', 'る'],
#  '一': ['いち'],
#  '帰宅': ['き', 'たく'],
#  '再現': ['さい', 'げん'],
#  '見合い': ['み', 'あ', 'い'],
#  '而も': ['しか', 'も'],
#  '炭鉱': ['たん', 'こう'],
#  '添う': ['そ', 'う'],
#  '翻訳': ['ほん', 'やく'],
#  '交差': ['こう', 'さ'],
#  '創立': ['そう', 'りつ'],
#  '挟む': ['はさ', 'む'],
#  '付ける': ['つ', 'け', 'る'],
#  '几帳面': ['き', 'ちょう', 'めん'],
#  '捕える': ['とら', 'え', 'る'],
#  '申し込み': ['もう', 'し', 'こ', 'み'],
#  '対談': ['たい', 'だん'],
#  '名付ける': ['な', 'づ', 'け', 'る'],
#  '団体': ['だん', 'たい'],
#  '水産': ['すい', 'さん'],
#  '法学': ['ほう', 'がく'],
#  '片言': ['かた', 'こと'],
#  '物議': ['ぶつ', 'ぎ'],
#  '愛でたい': ['め', 'で', 'た', 'い'],
#  '確率': ['かく', 'りつ'],
#  '馬鹿らしい': ['ば', 'か', 'ら', 'し', 'い'],
#  '上る': ['のぼ', 'る'],
#  '占める': ['し', 'め', 'る'],
#  '破産': ['は', 'さん'],
#  '雑談': ['ざつ', 'だん'],
#  '想像': ['そう', 'ぞう'],
#  '細い': ['ほそ', 'い'],
#  '大方': ['おお', 'かた'],
#  '券': ['けん'],
#  '小麦': ['こ', 'むぎ'],
#  '譲歩': ['じょう', 'ほ'],
#  '畑': ['はたけ'],
#  '範囲': ['はん', 'い'],
#  '席': ['せき'],
#  '密度': ['みつ', 'ど'],
#  '有効': ['ゆう', 'こう'],
#  '奉仕': ['ほう', 'し'],
#  '正': ['せい'],
#  '名詞': ['めい', 'し'],
#  '生計': ['せい', 'けい'],
#  '見出し': ['み', 'だ', 'し'],
#  '休息': ['きゅう', 'そく'],
#  '跨ぐ': ['また', 'ぐ'],
#  '生意気': ['なま', 'い', 'き'],
#  '宙返り': ['ちゅう', 'がえ', 'り'],
#  '生まれつき': ['う', 'ま', 'れ', 'つ', 'き'],
#  '分かる': ['わ', 'か', 'る'],
#  '安易': ['あん', 'い'],
#  '窮屈': ['きゅう', 'くつ'],
#  '食糧': ['しょく', 'りょう'],
#  '前者': ['ぜん', 'しゃ'],
#  '捜す': ['さが', 'す'],
#  'お互い': ['お', 'たが', 'い'],
#  '並行': ['へい', 'こう'],
#  '約': ['やく'],
#  '吹く': ['ふ', 'く'],
#  '感ずる': ['かん', 'ず', 'る'],
#  '経度': ['けい', 'ど'],
#  '文体': ['ぶん', 'たい'],
#  '架空': ['か', 'くう'],
#  '遣り通す': ['や', 'り', 'とお', 'す'],
#  '勤める': ['つと', 'め', 'る'],
#  '似る': ['に', 'る'],
#  '畳む': ['たた', 'む'],
#  '漠然': ['ばく', 'ぜん'],
#  '衣食住': ['い', 'しょく', 'じゅう'],
#  '期限': ['き', 'げん'],
#  '遥か': ['はる', 'か'],
#  '本部': ['ほん', 'ぶ'],
#  '久しぶり': ['ひさ', 'し', 'ぶ', 'り'],
#  '金銭': ['きん', 'せん'],
#  '得る': ['え', 'る'],
#  '無駄遣い': ['む', 'だ', 'づか', 'い'],
#  '及ぶ': ['およ', 'ぶ'],
#  '跡': ['あと'],
#  '去年': ['きょ', 'ねん'],
#  '工場': ['こう', 'ば'],
#  '誇る': ['ほこ', 'る'],
#  '申請': ['しん', 'せい'],
#  '返還': ['へん', 'かん'],
#  '落る': ['おち', 'る'],
#  '金槌': ['かな', 'づち'],
#  '手数': ['て', 'かず'],
#  '出動': ['しゅつ', 'どう'],
#  '全体': ['ぜん', 'たい'],
#  '拝見': ['はい', 'けん'],
#  '仕事': ['し', 'ごと'],
#  '弟': ['おとうと'],
#  '高度': ['こう', 'ど'],
#  '巻': ['まき'],
#  '学歴': ['がく', 'れき'],
#  '示す': ['しめ', 'す'],
#  '否決': ['ひ', 'けつ'],
#  '年齢': ['ねん', 'れい'],
#  '土曜日': ['ど', 'よう', 'び'],
#  '引力': ['いん', 'りょく'],
#  '惜しむ': ['お', 'し', 'む'],
#  '運送': ['うん', 'そう'],
#  '或る': ['あ', 'る'],
#  '前もって': ['まえ', 'も', 'っ', 'て'],
#  '積もり': ['つ', 'も', 'り'],
#  '人差指': ['ひと', 'さし', 'ゆび'],
#  '削る': ['けず', 'る'],
#  '叶う': ['かな', 'う'],
#  '第一': ['だい', 'いち'],
#  '枠': ['わく'],
#  '堂々': ['どう', 'どう'],
#  '諦める': ['あきら', 'め', 'る'],
#  '逆様': ['さか', 'さま'],
#  '鉄道': ['てつ', 'どう'],
#  '驚く': ['おどろ', 'く'],
#  '遊牧': ['ゆう', 'ぼく'],
#  '上司': ['じょう', 'し'],
#  '出入口': ['で', 'いり', 'ぐち'],
#  '答える': ['こた', 'え', 'る'],
#  '撃つ': ['う', 'つ'],
#  '無言': ['む', 'ごん'],
#  '協議': ['きょう', 'ぎ'],
#  '髭': ['ひげ'],
#  '逆さ': ['さか', 'さ'],
#  '請求': ['せい', 'きゅう'],
#  '独り': ['ひと', 'り'],
#  '錯誤': ['さく', 'ご'],
#  '語句': ['ご', 'く'],
#  'ご苦労様': ['ご', 'く', 'ろう', 'さま'],
#  '名産': ['めい', 'さん'],
#  '垂れる': ['た', 'れ', 'る'],
#  '図書': ['と', 'しょ'],
#  '煙る': ['けむ', 'る'],
#  '国境': ['くに', 'ざかい'],
#  '登場': ['とう', 'じょう'],
#  '推薦': ['すい', 'せん'],
#  '初級': ['しょ', 'きゅう'],
#  '融資': ['ゆう', 'し'],
#  '近寄る': ['ちか', 'よ', 'る'],
#  '賜る': ['たまわ', 'る'],
#  '発言': ['はつ', 'げん'],
#  '先に': ['さき', 'に'],
#  '消費': ['しょう', 'ひ'],
#  '見込み': ['み', 'こ', 'み'],
#  '怯える': ['おび', 'え', 'る'],
#  '新人': ['しん', 'じん'],
#  '分散': ['ぶん', 'さん'],
#  '着色': ['ちゃく', 'しょく'],
#  '母校': ['ぼ', 'こう'],
#  '例え': ['たと', 'え'],
#  '寮': ['りょう'],
#  '反る': ['かえ', 'る'],
#  '格差': ['かく', 'さ'],
#  '備わる': ['そな', 'わ', 'る'],
#  '気': ['き'],
#  '試し': ['ため', 'し'],
#  '合唱': ['がっ', 'しょう'],
#  '訓': ['くん'],
#  '幸せ': ['しあわ', 'せ'],
#  '分': ['ぶん'],
#  '仕舞う': ['し', 'ま', 'う'],
#  '覚える': ['おぼ', 'え', 'る'],
#  '痩せる': ['や', 'せ', 'る'],
#  '採点': ['さい', 'てん'],
#  '似通う': ['に', 'かよ', 'う'],
#  ...}

# %%
currentPronunciation['上']
# Out:
# ['じょう',
#  'じょう',
#  'のぼ',
#  'じょう',
#  'あ',
#  'のぼ',
#  'じょう',
#  'じょう',
#  'あ',
#  'じょう',
#  'あ',
#  'うえ',
#  'じょう',
#  'あ',
#  'じょう',
#  'あ',
#  'じょう',
#  'じょう',
#  'じょう',
#  'あ',
#  'のぼ',
#  'あ',
#  'あ',
#  'うえ',
#  'じょう',
#  'あ',
#  'じょう',
#  'じょう',
#  'あ',
#  'うわ',
#  'じょう',
#  'じょう',
#  'あ',
#  'じょう',
#  'あ',
#  'あ',
#  'あ',
#  'あ',
#  'あ',
#  'じょう',
#  'あ',
#  'じょう',
#  'じょう',
#  'うえ',
#  'あ',
#  'うわ',
#  'あ']

# %%
set(currentPronunciation['上'])
# Out:
# {'あ', 'うえ', 'うわ', 'じょう', 'のぼ'}

# %%
previousPronunciationCurrentPronunciation['小']
# Out:
# {'START': {'こ': 7, 'しょう': 6, 'ちい': 2}, 'しゅく': {'しょう': 1}, 'だい': {'しょう': 1}}

# %%
allKanjiCurrentPronunciation['子']
# Out:
# {False: {'こ': 3, 'し': 1}, True: {'こ': 2, 'ご': 1, 'し': 10, 'じ': 3, 'す': 3}}

# %%
currentPronunciation['子']
# Out:
# {'こ': 6, 'ご': 1, 'し': 13, 'じ': 3, 'す': 3}

# %%
plt.plot(range(5), list(currentPronunciation['子'].values()))#, list(currentPronunciation['子'].keys()))
plt.xticks(range(5), list(currentPronunciation['子'].keys()), size='large')
plt.show()

# %%
plt.plot(range(5), list(currentPronunciation['子'].values()))#, list(currentPronunciation['子'].keys()))
plt.xticks(range(5), list(currentPronunciation['子'].keys()), size='large')
plt.show()

# %%
plt.plot(range(5), list(currentPronunciation['子'].values()))#, list(currentPronunciation['子'].keys()))
plt.xticks(range(5), list(currentPronunciation['子'].keys()), size='large')
plt.show()

# %%
list(currentPronunciation['子'].keys())
# Out:
# ['し', 'こ', 'じ', 'す', 'ご']

# %%
currentPronunciation['子'].values()
# Out:
# dict_values([13, 6, 3, 3, 1])

# %%
allKanjiCurrentPronunciation['上']
# Out:
# {False: {'うえ': 1}, True: {'うえ': 2, 'じょう': 7}}

# %%
currentPronunciation['上']
# Out:
# {'あ': 19, 'うえ': 3, 'うわ': 2, 'じょう': 20, 'のぼ': 3}

# %%
previousPronunciationCurrentPronunciation['小']
# Out:
# {'START': {'こ': 7, 'しょう': 6, 'ちい': 2}, 'しゅく': {'しょう': 1}, 'だい': {'しょう': 1}}

# %%
previousPronunciationCurrentPronunciation['上']
# Out:
# {'START': {'あ': 3, 'うわ': 2, 'じょう': 14, 'のぼ': 2},
#  'い': {'じょう': 1},
#  'おく': {'じょう': 1},
#  'き': {'あ': 3},
#  'こう': {'じょう': 1},
#  'さか': {'のぼ': 1},
#  'さん': {'じょう': 1},
#  'し': {'あ': 7},
#  'ち': {'あ': 2},
#  'ちょう': {'じょう': 1},
#  'て': {'あ': 1},
#  'と': {'じょう': 1},
#  'の': {'うえ': 1},
#  'ま': {'うえ': 1},
#  'み': {'あ': 1},
#  'め': {'うえ': 1},
#  'り': {'あ': 2}}
