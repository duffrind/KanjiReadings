# %%
# I will be making a BayesNet that takes in a vector of features, sums up the vector,
# and then outputs a vector of probabilities.

# First - Finish the data
# Second - import data and extract features (can be preliminary)
# Third - Sum up features and calculate probabilities
# Fourth - Output probabilities for a given word (context)
# Fifth - Turn probabilities into a pronunciation by checking against the given ON/KUN pronunciations
# Lastly - Output and format the data beautifully (create into a blackbox)

#### PLEASE NOTE - ALLKANJI NOW CONTAINS SINGLE CHARACTER WORDS AS WELL ####

# %%
import re
#import unicodedata
import pickle

# %%
true_dict = pickle.load(open('true.p','rb')) # This is the dictionary that contains all of the regular vocab

# %%
########## FULL PRONUNCIATIONS ###########

## TODO: Also get length of vocabulary word (single character words probably use KUNYOMI/follow a pattern, etc)

### all dictionaries except for globals start with curKanji...

### This means that all dictionaries are [curKanji][arg1][arg2] = counter (or error if not in dictionary)
### Essentially backwards
#def init():
currentPronunciation = dict() # 

previousPronunciationCurrentPronunciation = dict() # prev, curPron -- (V) curPron, prev
nextPronunciationCurrentPronunciation = dict() # 
previousCharacterCurrentPronunciation = dict() # 
nextCharacterCurrentPronunciation = dict() # 
allKanjiCurrentPronunciation = dict() # 

# Features given pronunciation
currentPronunciationPreviousPronunciation = dict() #
currentPronunciationNextPronunciation = dict() # 
currentPronunciationPreviousCharacter = dict() # 
currentPronunciationNextCharacter = dict() # 
currentPronunciationAllKanji = dict() # 

currentKanjiPreviousPronunciation = dict() #
currentKanjiNextPronunciation = dict() # 
currentKanjiPreviousCharacter = dict() # 
currentKanjiNextCharacter = dict() # 
currentKanjiAllKanji = dict() # 
currentKanjiOneChar = dict()

# New for totals... ###
globalPreviousPronunciation = dict() ### -> dict() -> [prevPron][curPron]
globalPreviousCharacter = dict() ### -> [prevChar][curPron]
globalNextPronunciation = dict() ### -> [nextPron][curPron]
globalNextCharacter = dict() ### -> [nextChar][curPron]
##GLOBALGLOBALS
allKanjiCurrentPronunciation = dict() # [curPron]
allKanjiCurrentPronunciationPreviousPronunciation = dict() # [curPron][prevPron]
allKanjiCurrentPronunciationNextPronunciation = dict()
allKanjiCurrentPronunciationPreviousCharacter = dict()
allKanjiCurrentPronunciationNextCharacter = dict()
allKanjiCurrentPronunciationAllKanji = dict()

###
# number of characters in word
# 

def updateAllKanji(curKanji, curPron, allKanji):
    global allKanjiCurrentPronunciation, currentPronunciationAllKanji, currentKanjiAllKanji
    currentKanjiAllKanji[curKanji] = currentKanjiAllKanji.get(curKanji, dict())
    currentKanjiAllKanji[curKanji][allKanji] = currentKanjiAllKanji[curKanji].get(allKanji, 0) + 1
    currentPronunciationAllKanji[curKanji] = currentPronunciationAllKanji.get(curKanji, dict())
    currentPronunciationAllKanji[curKanji][curPron] = currentPronunciationAllKanji[curKanji].get(curPron, {True:0,False:0})
    currentPronunciationAllKanji[curKanji][curPron][allKanji] = currentPronunciationAllKanji[curKanji][curPron][allKanji] + 1
    allKanjiCurrentPronunciation[curKanji] = allKanjiCurrentPronunciation.get(curKanji, dict())
    allKanjiCurrentPronunciation[curKanji][allKanji] = allKanjiCurrentPronunciation[curKanji].get(allKanji, dict())
    allKanjiCurrentPronunciation[curKanji][allKanji][curPron] = allKanjiCurrentPronunciation[curKanji][allKanji].get(curPron,0) + 1
    
def updateCurPron(curKanji, curPron, oneChar):
    global currentPronunciation, v_cur_pron
    currentPronunciation[curKanji] = currentPronunciation.get(curKanji, dict())
    currentPronunciation[curKanji][curPron] = currentPronunciation[curKanji].get(curPron, 0) + 1
    currentKanjiOneChar[curKanji] = currentKanjiOneChar.get(curKanji, dict())
    currentKanjiOneChar[curKanji][oneChar] = currentKanjiOneChar[curKanji].get(oneChar, dict())
    currentKanjiOneChar[curKanji][oneChar][curPron] = currentKanjiOneChar[curKanji][oneChar].get(curPron, 0) + 1
    

def updatePrevPron(curKanji, prevPron, curPron):
    global previousPronunciationCurrentPronunciation, currentPronunciationPreviousPronunciation, globalPreviousPronunciation, currentKanjiPreviousPronunciation
    currentKanjiPreviousPronunciation[curKanji] = currentKanjiPreviousPronunciation.get(curKanji, dict())
    currentKanjiPreviousPronunciation[curKanji][prevPron] = currentKanjiPreviousPronunciation[curKanji].get(prevPron, 0) + 1
    previousPronunciationCurrentPronunciation[curKanji] = previousPronunciationCurrentPronunciation.get(curKanji, dict())
    previousPronunciationCurrentPronunciation[curKanji][prevPron] = previousPronunciationCurrentPronunciation[curKanji].get(prevPron, dict())
    previousPronunciationCurrentPronunciation[curKanji][prevPron][curPron] = previousPronunciationCurrentPronunciation[curKanji][prevPron].get(curPron,0) + 1
    currentPronunciationPreviousPronunciation[curKanji] = currentPronunciationPreviousPronunciation.get(curKanji, dict())
    currentPronunciationPreviousPronunciation[curKanji][curPron] = currentPronunciationPreviousPronunciation[curKanji].get(curPron, dict())
    currentPronunciationPreviousPronunciation[curKanji][curPron][prevPron] = currentPronunciationPreviousPronunciation[curKanji][curPron].get(prevPron,0) + 1
    globalPreviousPronunciation[prevPron] = globalPreviousPronunciation.get(prevPron, dict())
    globalPreviousPronunciation[prevPron][curPron] = globalPreviousPronunciation[prevPron].get(curPron, 0) + 1
    
def updatePrevChar(curKanji, prevChar, curPron):
    global previousCharacterCurrentPronunciation, currentPronunciationNextCharacter, globalPreviousCharacter, currentKanjiPreviousCharacter
    currentKanjiPreviousCharacter[curKanji] = currentKanjiPreviousCharacter.get(curKanji, dict())
    currentKanjiPreviousCharacter[curKanji][prevChar] = currentKanjiPreviousCharacter[curKanji].get(prevChar, 0) + 1
    previousCharacterCurrentPronunciation[curKanji] = previousCharacterCurrentPronunciation.get(curKanji, dict())
    previousCharacterCurrentPronunciation[curKanji][prevChar] = previousCharacterCurrentPronunciation[curKanji].get(prevChar, dict())
    previousCharacterCurrentPronunciation[curKanji][prevChar][curPron] = previousCharacterCurrentPronunciation[curKanji][prevChar].get(curPron,0) + 1
    currentPronunciationPreviousCharacter[curKanji] = currentPronunciationPreviousCharacter.get(curKanji, dict())
    currentPronunciationPreviousCharacter[curKanji][curPron] = currentPronunciationPreviousCharacter[curKanji].get(curPron, dict())
    currentPronunciationPreviousCharacter[curKanji][curPron][prevChar] = currentPronunciationPreviousCharacter[curKanji][curPron].get(prevChar,0) + 1
    globalPreviousCharacter[prevChar] = globalPreviousCharacter.get(prevChar, dict())
    globalPreviousCharacter[prevChar][curPron] = globalPreviousCharacter[prevChar].get(curPron, 0) + 1
    
def updateNextPron(curKanji, nextPron, curPron):
    global nextPronunciationCurrentPronunciation, currentPronunciationNextPronunciation, globalNextPronunciation, currentKanjiNextPronunciation
    currentKanjiNextPronunciation[curKanji] = currentKanjiNextPronunciation.get(curKanji, dict())
    currentKanjiNextPronunciation[curKanji][nextPron] = currentKanjiNextPronunciation[curKanji].get(nextPron, 0) + 1
    nextPronunciationCurrentPronunciation[curKanji] = nextPronunciationCurrentPronunciation.get(curKanji, dict())
    nextPronunciationCurrentPronunciation[curKanji][nextPron] = nextPronunciationCurrentPronunciation[curKanji].get(nextPron, dict())
    nextPronunciationCurrentPronunciation[curKanji][nextPron][curPron] = nextPronunciationCurrentPronunciation[curKanji][nextPron].get(curPron,0) + 1
    currentPronunciationNextPronunciation[curKanji] = currentPronunciationNextPronunciation.get(curKanji, dict())
    currentPronunciationNextPronunciation[curKanji][curPron] = currentPronunciationNextPronunciation[curKanji].get(curPron, dict())
    currentPronunciationNextPronunciation[curKanji][curPron][nextPron] = currentPronunciationNextPronunciation[curKanji][curPron].get(nextPron,0) + 1
    globalNextPronunciation[nextPron] = globalNextPronunciation.get(nextPron, dict())
    globalNextPronunciation[nextPron][curPron] = globalNextPronunciation[nextPron].get(curPron, 0) + 1
    
def updateNextChar(curKanji, nextChar, curPron):
    global nextCharacterCurrentPronunciation, currentPronunciationNextCharacter, globalNextCharacter, currentKanjiNextCharacter
    currentKanjiNextCharacter[curKanji] = currentKanjiNextCharacter.get(curKanji, dict())
    currentKanjiNextCharacter[curKanji][nextChar] = currentKanjiNextCharacter[curKanji].get(nextChar, 0) + 1
    nextCharacterCurrentPronunciation[curKanji] = nextCharacterCurrentPronunciation.get(curKanji, dict())
    nextCharacterCurrentPronunciation[curKanji][nextChar] = nextCharacterCurrentPronunciation[curKanji].get(nextChar, dict())
    nextCharacterCurrentPronunciation[curKanji][nextChar][curPron] = nextCharacterCurrentPronunciation[curKanji][nextChar].get(curPron,0) + 1
    currentPronunciationNextCharacter[curKanji] = currentPronunciationNextCharacter.get(curKanji, dict())
    currentPronunciationNextCharacter[curKanji][curPron] = currentPronunciationNextCharacter[curKanji].get(curPron, dict())
    currentPronunciationNextCharacter[curKanji][curPron][nextChar] = currentPronunciationNextCharacter[curKanji][curPron].get(nextChar,0) + 1
    globalNextCharacter[nextChar] = globalNextCharacter.get(nextChar, dict())
    globalNextCharacter[nextChar][curPron] = globalNextCharacter[nextChar].get(curPron, 0) + 1

# %%
########## PARTIAL PRONUNCIATIONS ###########

## TODO: Also get length of vocabulary word (single character words probably use KUNYOMI/follow a pattern, etc)

previousPronunciationEndCurrentPronunciationStart = dict()
nextPronunciationStartCurrentPronunciationEnd = dict()
previousCharacterCurrentPronunciationStart = dict()
nextCharacterCurrentPronunciationEnd = dict()

def init():
    previousPronunciationEndCurrentPronunciationStart = dict()
    nextPronunciationStartCurrentPronunciationEnd = dict()
    previousCharacterCurrentPronunciationStart = dict()
    nextCharacterCurrentPronunciationEnd = dict()
    currentPronunciation = dict() # 
    previousPronunciationCurrentPronunciation = dict() # prev, curPron -- (V) curPron, prev
    nextPronunciationCurrentPronunciation = dict() # 
    previousCharacterCurrentPronunciation = dict() # 
    nextCharacterCurrentPronunciation = dict() # 
    allKanjiCurrentPronunciation = dict() # 
    currentPronunciationPreviousPronunciation = dict() #
    currentPronunciationNextPronunciation = dict() # 
    currentPronunciationPreviousCharacter = dict() # 
    currentPronunciationNextCharacter = dict() # 
    currentPronunciationAllKanji = dict() # 
    currentKanjiPreviousPronunciation = dict() #
    currentKanjiNextPronunciation = dict() # 
    currentKanjiPreviousCharacter = dict() # 
    currentKanjiNextCharacter = dict() # 
    currentKanjiAllKanji = dict() # 
    currentKanjiOneChar = dict()
    globalPreviousPronunciation = dict() ### -> dict() -> [prevPron][curPron]
    globalPreviousCharacter = dict() ### -> [prevChar][curPron]
    globalNextPronunciation = dict() ### -> [nextPron][curPron]
    globalNextCharacter = dict() ### -> [nextChar][curPron]
    allKanjiCurrentPronunciation = dict() # [curPron]
    allKanjiCurrentPronunciationPreviousPronunciation = dict() # [curPron][prevPron]
    allKanjiCurrentPronunciationNextPronunciation = dict()
    allKanjiCurrentPronunciationPreviousCharacter = dict()
    allKanjiCurrentPronunciationNextCharacter = dict()
    allKanjiCurrentPronunciationAllKanji = dict()

def updatePreviousPronunciation(curPron, prevChar, prevPron):
    if len(prevPron) != 1 and prevPron[-1] in ['ゃ','ゅ','ょ','っ'] and prevPron != 'START':
        prevPron = prevPron[-2:-1]
    else:
        prevPron = prevPron[-1]
    if len(curPron) != 1 and curPron[1] in ['ゃ','ゅ','ょ','っ']:
        curPron = curPron[0:1]
    else:
        curPron = curPron[0]
    previousPronunciationEndCurrentPronunciationStart[prevPron] = previousPronunciationEndCurrentPronunciationStart.get(prevPron,dict())
    previousPronunciationEndCurrentPronunciationStart[prevPron][curPron] = previousPronunciationEndCurrentPronunciationStart[prevPron].get(curPron,0) + 1
    previousCharacterCurrentPronunciationStart[prevChar] = previousCharacterCurrentPronunciationStart.get(prevChar,dict())
    previousCharacterCurrentPronunciationStart[prevChar][curPron] = previousCharacterCurrentPronunciationStart[prevChar].get(curPron,0) + 1
    
def updateNextPronunciation(curPron, nextChar, nextPron):
    if len(nextPron) != 1 and nextPron[1] in ['ゃ','ゅ','ょ','っ'] and nextPron != 'END':
        nextPron = nextPron[0:1]
    else:
        nextPron = nextPron[-1]
    if len(curPron) != 1 and curPron[-1] in ['ゃ','ゅ','ょ','っ']:
        curPron = curPron[-2:-1]
    else:
        curPron = curPron[0]
    nextPronunciationStartCurrentPronunciationEnd[nextPron] = nextPronunciationStartCurrentPronunciationEnd.get(nextPron,dict())
    nextPronunciationStartCurrentPronunciationEnd[nextPron][curPron] = nextPronunciationStartCurrentPronunciationEnd[nextPron].get(curPron,0) + 1
    nextCharacterCurrentPronunciationEnd[nextChar] = nextCharacterCurrentPronunciationEnd.get(nextChar,dict())
    nextCharacterCurrentPronunciationEnd[nextChar][curPron] = nextCharacterCurrentPronunciationEnd[nextChar].get(curPron,0) + 1

# %%
def createBayes():
    """Creates the Bayesian Network by creating dictionaries of occurences"""
    init()
    for kanji, pronunciation in true_dict.items():
        oneChar = False
        if len(kanji) == 1:
            oneChar = True
        if re.search("""[\u3040-\u30ff]+""", kanji) == None and len(kanji) != 0: # Finds kana
            kanjiWord = True
        else: # either kana is present or the word is a singular character
            kanjiWord = False
        for i in range(len(kanji)):
            updateCurPron(kanji[i], pronunciation[i], oneChar)
            if i == 0: # First and last characters are special cases
                updatePrevPron(kanji[i], 'START', pronunciation[i])
                updatePrevChar(kanji[i], 'START', pronunciation[i])
                updatePreviousPronunciation(pronunciation[i], 'START', 'START')
            else:
                updatePrevPron(kanji[i], pronunciation[i-1], pronunciation[i])
                updatePrevChar(kanji[i], kanji[i-1], pronunciation[i])
                updatePreviousPronunciation(pronunciation[i], kanji[i-1], pronunciation[i-1])
            if i == (len(kanji) - 1):
                updateNextPron(kanji[i], 'END', pronunciation[i])
                updateNextChar(kanji[i], 'END', pronunciation[i])
                updateNextPronunciation(pronunciation[i], 'END', 'END')
            else:
                updateNextPron(kanji[i], pronunciation[i+1], pronunciation[i])
                updateNextChar(kanji[i], kanji[i+1], pronunciation[i])
                updateNextPronunciation(pronunciation[i], kanji[i+1], pronunciation[i+1])
        updateAllKanji(kanji[i], pronunciation[i], kanjiWord)

# %%
createBayes()

# %%
temp = sorted(previousPronunciationEndCurrentPronunciationStart['い'].items(), key=lambda kv: kv[1], reverse=True)
### Does this follow Zipf's Law?
y = []
i = 1
x = []
for _,a in temp:
    x.append(i)
    i = i + 1
    y.append(a)
    
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(x,y)
plt.yscale('log')
plt.xscale('log')
plt.show()

print(sorted(previousPronunciationEndCurrentPronunciationStart['い'].items(), key=lambda kv: kv[1], reverse=True))
# dictionaries for each vector
# value = d.get(key, "empty")
#
# prev_pron, prev_char, all_kanji, reading (kanji: on[1], kun[0]), kanji_pron (kanji: prons), POS?, radicals?,
# singlechar?, 
# check for mixed reading
# Out:
# [('し', 66), ('き', 38), ('じ', 38), ('か', 34), ('せ', 27), ('こ', 25), ('り', 25), ('さ', 24), ('け', 20), ('て', 19), ('が', 18), ('い', 16), ('す', 15), ('れ', 15), ('と', 14), ('よ', 14), ('た', 14), ('ぶ', 13), ('そ', 13), ('ど', 13), ('る', 11), ('ほ', 10), ('だ', 10), ('ち', 9), ('ね', 9), ('ぞ', 9), ('ぼ', 8), ('ぎ', 8), ('げ', 8), ('ば', 8), ('に', 8), ('ふ', 8), ('わ', 7), ('ら', 7), ('め', 7), ('ご', 7), ('つ', 6), ('み', 6), ('ろ', 5), ('や', 5), ('ま', 5), ('く', 5), ('ぜ', 5), ('で', 5), ('ひ', 5), ('は', 5), ('あ', 5), ('の', 4), ('な', 4), ('え', 4), ('へ', 4), ('べ', 4), ('ざ', 4), ('も', 4), ('び', 3), ('ぐ', 3), ('ゆ', 3), ('う', 3), ('お', 2), ('ず', 2), ('む', 1)]

# %%
#allKanjiCurrentPronunciation['人']
currentKanjiOneChar#[curKanji][oneChar] = currentKanjiOneChar[curKanji].get(oneChar, dict())
# Out:
# {'屡': {True: {'しばしば': 1}},
#  '靴': {False: {'くつ': 1}, True: {'くつ': 1}},
#  '習': {False: {'しゅう': 12, 'なら': 1}},
#  '秤': {True: {'はかり': 1}},
#  '態': {False: {'たい': 5, 'わざ': 2}},
#  '戒': {False: {'かい': 1}},
#  '繁': {False: {'はん': 3, 'ぱん': 1}},
#  '病': {False: {'びょう': 5, 'や': 1}, True: {'やまい': 1}},
#  '択': {False: {'たく': 2}},
#  '了': {False: {'りょう': 5}, True: {'りょう': 1}},
#  '濫': {False: {'らん': 2}},
#  '摩': {False: {'ま': 1}},
#  '保': {False: {'たも': 1, 'ほ': 13}},
#  '象': {False: {'しょう': 6}, True: {'ぞう': 1}},
#  '採': {False: {'さい': 7, 'と': 1}},
#  '嘸': {True: {'さぞ': 1}},
#  '植': {False: {'う': 3, 'しょく': 2}},
#  '忠': {False: {'ちゅう': 2}},
#  '並': {False: {'な': 3, 'なみ': 1, 'なら': 3, 'へい': 2}},
#  '怪': {False: {'あや': 1, 'かい': 1, 'け': 1}},
#  '奥': {False: {'おく': 1}, True: {'おく': 1}},
#  '束': {False: {'そく': 3, 'つか': 1}, True: {'たば': 1}},
#  '箋': {False: {'せん': 1}},
#  '半': {False: {'なか': 1, 'はん': 6}, True: {'はん': 1}},
#  '粗': {False: {'あら': 2, 'そ': 1}},
#  '迷': {False: {'めい': 2}},
#  '有': {False: {'あ': 2, 'う': 1, 'ゆう': 14}},
#  '捜': {False: {'さが': 1, 'そう': 2}},
#  '画': {False: {'かく': 3, 'が': 6}, True: {'かく': 1}},
#  'な': {False: {'な': 36}},
#  'げ': {False: {'げ': 33}},
#  '弁': {False: {'べん': 8}},
#  'ね': {False: {'ね': 9}},
#  '寒': {False: {'かん': 2, 'さむ': 1}},
#  '双': {False: {'ふた': 1}},
#  '毯': {False: {'たん': 1}},
#  '臨': {False: {'のぞ': 1, 'りん': 1}},
#  '推': {False: {'すい': 6}},
#  '寿': {False: {'じゅ': 1}},
#  'ー': {False: {'ー': 1}},
#  '於': {False: {'お': 1}, True: {'お': 1}},
#  '能': {False: {'のう': 14}, True: {'のう': 1}},
#  '碌': {False: {'ろく': 2}},
#  '清': {False: {'きよ': 2, 'せい': 6}},
#  '秒': {True: {'びょう': 1}},
#  '相': {False: {'あい': 3, 'しょう': 3, 'そう': 9}, True: {'あい': 1}},
#  '爆': {False: {'ばく': 4}},
#  '理': {False: {'り': 26}},
#  '換': {False: {'か': 3, 'かん': 4}},
#  '蜜': {False: {'みつ': 1}, True: {'みつ': 1}},
#  '枝': {True: {'えだ': 1}},
#  '輝': {False: {'かがや': 1}},
#  '俵': {False: {'ひょう': 1}},
#  '故': {False: {'こ': 4}, True: {'こ': 1}},
#  '傍': {False: {'かたわ': 1}},
#  '向': {False: {'こう': 6, 'む': 7, 'むか': 1}},
#  '団': {False: {'だん': 6, 'とん': 2}},
#  '譲': {False: {'じょう': 1, 'ゆず': 1}},
#  '気': {False: {'き': 47, 'け': 3, 'げ': 2}, True: {'き': 1}},
#  '博': {False: {'はく': 1}},
#  '池': {False: {'ち': 2}, True: {'いけ': 1}},
#  '乙': {True: {'おつ': 1}},
#  '癖': {True: {'くせ': 1}},
#  '疲': {False: {'つか': 2, 'ひ': 1}},
#  '霞': {False: {'かす': 1}},
#  '吊': {False: {'つ': 3, 'つる': 1}},
#  '先': {False: {'さき': 5, 'せん': 19, 'ま': 1}, True: {'さき': 1}},
#  '別': {False: {'べつ': 10, 'わか': 2}, True: {'べつ': 1}},
#  '妥': {False: {'だ': 3}},
#  '唯': {False: {'ゆい': 1}, True: {'ただ': 1}},
#  '拳': {False: {'けん': 1}},
#  '凡': {False: {'およ': 1, 'ぼん': 1}},
#  '掴': {False: {'つか': 1}},
#  '製': {False: {'せい': 6}, True: {'せい': 1}},
#  '膨': {False: {'ふく': 3, 'ぼう': 2}},
#  '乱': {False: {'みだ': 2, 'らん': 4}},
#  '集': {False: {'あつ': 3, 'しゅう': 13}},
#  '濯': {False: {'すす': 1, 'たく': 1}},
#  '享': {False: {'きょう': 1}},
#  '構': {False: {'かま': 3, 'こう': 4}},
#  '敏': {False: {'びん': 1}},
#  '猿': {True: {'さる': 1}},
#  '銘': {False: {'めい': 1}},
#  '奇': {False: {'き': 3}},
#  '感': {False: {'かん': 22}},
#  '凹': {False: {'へこ': 1, 'ぼこ': 1}},
#  '創': {False: {'そう': 5}},
#  '諺': {True: {'ことわざ': 1}},
#  '傷': {False: {'きず': 1, 'しょう': 3}, True: {'きず': 1}},
#  '法': {False: {'ほう': 11, 'ぽう': 3}, True: {'ほう': 1}},
#  '前': {False: {'ぜん': 10, 'まえ': 9}, True: {'まえ': 1}},
#  '朗': {False: {'ほが': 1, 'ろう': 2}},
#  '権': {False: {'けん': 7}, True: {'けん': 1}},
#  '仲': {False: {'ちゅう': 1, 'なか': 3}, True: {'なか': 1}},
#  'こ': {False: {'こ': 13}},
#  '職': {False: {'しょく': 9}, True: {'しょく': 1}},
#  '基': {False: {'き': 6, 'もと': 1}, True: {'もと': 1}},
#  '字': {False: {'じ': 14}, True: {'じ': 1}},
#  '渋': {False: {'しぶ': 1, 'じゅう': 1}},
#  '駄': {False: {'た': 1, 'だ': 4}},
#  '抑': {False: {'よく': 2}},
#  '噌': {False: {'そ': 1}},
#  'ェ': {False: {'ェ': 1}},
#  '農': {False: {'のう': 10}},
#  '呂': {False: {'ろ': 3}},
#  '無': {False: {'な': 5, 'ぶ': 6, 'む': 25}, True: {'む': 1}},
#  '誠': {False: {'せい': 1}, True: {'まこと': 1}},
#  '負': {False: {'お': 2, 'ふ': 3, 'ぶ': 1, 'ま': 4}},
#  '塵': {False: {'ちり': 2}, True: {'ごみ': 1}},
#  '唇': {True: {'くちびる': 1}},
#  '麻': {False: {'ま': 2}, True: {'あさ': 1}},
#  '祭': {False: {'さい': 1, 'まつ': 2}, True: {'まつり': 1}},
#  '貫': {False: {'かん': 1, 'つらぬ': 1}},
#  'べ': {False: {'べ': 13}},
#  '兵': {False: {'へい': 3}},
#  '副': {False: {'ふく': 1}},
#  '眼': {False: {'がん': 4}},
#  'る': {False: {'る': 745}},
#  '切': {False: {'き': 17, 'きり': 1, 'ぎ': 4, 'せつ': 6}},
#  '段': {False: {'だん': 7}, True: {'だん': 1}},
#  '庭': {False: {'てい': 2}, True: {'にわ': 1}},
#  '垂': {False: {'すい': 1, 'た': 1}},
#  '護': {False: {'ご': 7}},
#  '咲': {False: {'さ': 1}},
#  '広': {False: {'こう': 1, 'ひろ': 7, 'びろ': 1}},
#  '礎': {False: {'そ': 1}},
#  '行': {False: {'い': 2, 'おこな': 2, 'ぎょう': 6, 'こう': 26, 'ゆ': 3},
#   True: {'ぎょう': 1}},
#  '閣': {False: {'かく': 1}},
#  '議': {False: {'ぎ': 22}},
#  '盛': {False: {'さか': 2, 'じょう': 1, 'せい': 3, 'も': 2}},
#  '襟': {True: {'えり': 1}},
#  'さ': {False: {'さ': 23}},
#  '己': {False: {'こ': 1}},
#  '椅': {False: {'い': 1}},
#  '批': {False: {'ひ': 2}},
#  '嵐': {True: {'あらし': 1}},
#  'ぜ': {False: {'ぜ': 3}},
#  '牲': {False: {'せい': 1}},
#  '契': {False: {'けい': 2, 'ちぎ': 1}},
#  '徴': {False: {'ちょう': 3}},
#  '愚': {False: {'おろ': 1, 'ぐ': 1}},
#  '武': {False: {'ぶ': 4}},
#  '多': {False: {'おお': 1, 'た': 8}},
#  '怯': {False: {'おび': 1, 'きょう': 1}},
#  '掻': {False: {'か': 3, 'が': 1}},
#  '饂': {False: {'う': 1}},
#  '削': {False: {'けず': 1, 'さく': 2}},
#  '悩': {False: {'なや': 4}},
#  '孫': {False: {'そん': 1}, True: {'まご': 1}},
#  'せ': {False: {'せ': 30}},
#  '仰': {False: {'あお': 1, 'お': 1, 'こう': 1}},
#  '囲': {False: {'い': 3, 'かこ': 1}},
#  '脚': {False: {'きゃく': 2}},
#  '率': {False: {'そつ': 2, 'ひき': 1, 'りつ': 5}, True: {'りつ': 1}},
#  '満': {False: {'まん': 8, 'み': 2}},
#  '踊': {False: {'おど': 2}},
#  '昼': {False: {'ちゅう': 2, 'ひる': 5}, True: {'ひる': 1}},
#  '堀': {True: {'ほり': 1}},
#  '仏': {False: {'ぶつ': 1}, True: {'ほとけ': 1}},
#  '築': {False: {'きず': 1, 'ちく': 2}},
#  '黒': {False: {'くろ': 3, 'こく': 1}, True: {'くろ': 1}},
#  '郵': {False: {'ゆう': 3}},
#  '殆': {False: {'ほとん': 1}},
#  '幼': {False: {'おさな': 1, 'よう': 3}},
#  '慮': {False: {'りょ': 3}},
#  '伊': {False: {'い': 1}},
#  '掌': {False: {'しょう': 1}, True: {'たなごころ': 1}},
#  '頻': {False: {'しき': 1, 'ひん': 1}},
#  'そ': {False: {'そ': 7}},
#  '芽': {False: {'が': 1}, True: {'め': 1}},
#  '履': {False: {'は': 1, 'り': 2}},
#  '弟': {False: {'だい': 1}, True: {'おとうと': 1}},
#  '肉': {False: {'にく': 7}, True: {'にく': 1}},
#  'う': {False: {'う': 103}},
#  '確': {False: {'かく': 11, 'たし': 2}},
#  '勢': {False: {'いきお': 1, 'せい': 6, 'ぜい': 1}},
#  '珍': {False: {'めずら': 1}},
#  '林': {False: {'りん': 3}, True: {'はやし': 1}},
#  '顧': {False: {'かえり': 1}},
#  'す': {False: {'す': 204}},
#  '朴': {False: {'ぼく': 1}},
#  '憶': {False: {'おく': 1}},
#  '暖': {False: {'あたた': 3, 'だん': 2}},
#  '隠': {False: {'いん': 1, 'かく': 2}},
#  '衛': {False: {'えい': 6}},
#  '鈴': {True: {'すず': 1}},
#  '耗': {False: {'もう': 1}},
#  '貢': {False: {'こう': 1}},
#  '軋': {False: {'きし': 1}},
#  '屎': {False: {'し': 1}},
#  '谷': {True: {'たに': 1}},
#  '放': {False: {'はな': 2, 'ほう': 12}},
#  '歴': {False: {'れき': 4}},
#  '塊': {True: {'かたまり': 1}},
#  '俗': {False: {'ぞく': 2}},
#  '版': {False: {'はん': 2}, True: {'はん': 1}},
#  '叶': {False: {'かな': 2}},
#  '辺': {False: {'あた': 1, 'へん': 2, 'べ': 1}, True: {'へん': 1}},
#  '班': {True: {'はん': 1}},
#  '論': {False: {'ろ': 1, 'ろん': 18}},
#  '濃': {False: {'こ': 1, 'のう': 1}},
#  '脇': {True: {'わき': 1}},
#  '抜': {False: {'ぬ': 4, 'ばつ': 1}},
#  '雛': {True: {'ひな': 1}},
#  '去': {False: {'きょ': 2, 'こ': 1, 'さ': 1}},
#  '頭': {False: {'ず': 2, 'とう': 4}, True: {'あたま': 1}},
#  '他': {False: {'た': 4}, True: {'た': 1}},
#  '札': {False: {'さつ': 1, 'ふだ': 1}, True: {'さつ': 1}},
#  '甲': {True: {'きのえ': 1}},
#  '僧': {True: {'そう': 1}},
#  '述': {False: {'じゅつ': 3, 'の': 1}},
#  '郡': {True: {'ぐん': 1}},
#  '調': {False: {'しら': 4, 'ちょう': 16}},
#  '醜': {False: {'みにく': 1}},
#  '密': {False: {'ひそ': 1, 'みつ': 6}},
#  '君': {False: {'くん': 2}, True: {'くん': 1}},
#  '飛': {False: {'と': 5, 'ひ': 3}},
#  '蹴': {False: {'け': 2}},
#  '私': {False: {'し': 5}, True: {'わたし': 1}},
#  '汽': {False: {'き': 2}},
#  '蛋': {False: {'たん': 1}},
#  '齎': {False: {'もた': 1}},
#  '希': {False: {'き': 1}},
#  '攻': {False: {'こう': 2, 'せ': 2}},
#  '略': {False: {'りゃく': 6}},
#  '上': {False: {'あ': 19, 'うえ': 3, 'うわ': 2, 'じょう': 19, 'のぼ': 3},
#   True: {'じょう': 1}},
#  '咳': {True: {'せき': 1}},
#  '点': {False: {'つ': 2, 'てん': 25}, True: {'てん': 1}},
#  '紳': {False: {'しん': 1}},
#  '焦': {False: {'あせ': 1, 'こ': 3, 'しょう': 1}},
#  'か': {False: {'か': 82}},
#  '兄': {False: {'きょう': 1}, True: {'あに': 1}},
#  '浜': {False: {'はま': 1}, True: {'はま': 1}},
#  '発': {False: {'た': 1, 'はつ': 13, 'ぱつ': 1}, True: {'はつ': 1}},
#  '離': {False: {'はな': 2, 'り': 3}},
#  '暗': {False: {'あん': 4, 'くら': 2, 'ぐら': 1}},
#  '賃': {False: {'ちん': 3}},
#  '延': {False: {'えん': 2, 'の': 3}},
#  '止': {False: {'し': 7, 'と': 4, 'ど': 1, 'や': 3, 'よ': 1}},
#  '漠': {False: {'ばく': 2}},
#  '爪': {True: {'つめ': 1}},
#  '市': {False: {'いち': 1, 'し': 3}, True: {'し': 1}},
#  '模': {False: {'ぼ': 1, 'も': 5}},
#  '処': {False: {'しょ': 5}},
#  '柵': {True: {'さく': 1}},
#  '交': {False: {'か': 1, 'こう': 15, 'ま': 3, 'まじ': 2}},
#  '積': {False: {'せき': 4, 'つ': 3}},
#  '旧': {False: {'きゅう': 2}, True: {'きゅう': 1}},
#  '蛇': {False: {'じゃ': 1}},
#  '栓': {True: {'せん': 1}},
#  '利': {False: {'き': 1, 'り': 15}},
#  '栄': {False: {'えい': 2, 'さか': 1}},
#  '凸': {False: {'でこ': 1}},
#  '瀬': {False: {'せ': 1}},
#  '嫋': {False: {'しなや': 1}},
#  '桐': {True: {'きり': 1}},
#  '極': {False: {'きょく': 5, 'きわ': 1, 'ごく': 1}, True: {'きょく': 1}},
#  '跡': {False: {'あと': 2, 'せき': 2}, True: {'あと': 1}},
#  '同': {False: {'おな': 2, 'どう': 20}, True: {'どう': 1}},
#  '村': {False: {'そん': 2}, True: {'むら': 1}},
#  '締': {False: {'し': 5, 'しめ': 1}},
#  '附': {False: {'ふ': 1}},
#  '局': {False: {'きょく': 2}, True: {'きょく': 1}},
#  '紡': {False: {'ぼう': 1}},
#  '与': {False: {'あた': 1, 'よ': 4}},
#  '増': {False: {'ぞう': 6, 'ふ': 2, 'ま': 2}},
#  '賛': {False: {'さん': 2}},
#  '鏡': {False: {'きょう': 3}, True: {'かがみ': 1}},
#  '錯': {False: {'さく': 1}},
#  '刊': {False: {'かん': 4}},
#  '漫': {False: {'まん': 1}},
#  '偶': {False: {'ぐう': 3, 'たま': 2}},
#  '逃': {False: {'とう': 2, 'に': 3, 'のが': 3}},
#  '糸': {False: {'いと': 1}, True: {'いと': 1}},
#  '支': {False: {'ささ': 1, 'し': 9, 'つか': 2}},
#  '凄': {False: {'すご': 2}},
#  '軌': {False: {'き': 1}},
#  '景': {False: {'けい': 5}},
#  '恥': {False: {'は': 3}, True: {'はじ': 1}},
#  'お': {False: {'お': 37}},
#  'く': {False: {'く': 122}},
#  '欠': {False: {'か': 2, 'けつ': 2}},
#  '望': {False: {'のぞ': 4, 'ぼう': 10}},
#  '墜': {False: {'つい': 1}},
#  '忘': {False: {'わす': 3}},
#  '馳': {False: {'ち': 3}},
#  '低': {False: {'てい': 2, 'ひく': 1}},
#  '飩': {False: {'どん': 1}},
#  '娘': {True: {'むすめ': 1}},
#  '争': {False: {'あらそ': 2, 'そう': 5}},
#  '身': {False: {'しん': 6, 'み': 8}, True: {'み': 1}},
#  '鬱': {False: {'うっ': 1, 'うつ': 1}},
#  '裸': {True: {'はだか': 1}},
#  '益': {False: {'えき': 3, 'ます': 1}},
#  '囀': {False: {'さえず': 1}},
#  '偏': {False: {'かたよ': 1, 'へん': 1}, True: {'へん': 1}},
#  '挑': {False: {'いど': 1, 'ちょう': 1}},
#  '電': {False: {'でん': 17}},
#  '或': {False: {'あ': 1, 'ある': 1}, True: {'ある': 1}},
#  '号': {False: {'ごう': 5}, True: {'ごう': 1}},
#  '揃': {False: {'そろ': 3}},
#  '告': {False: {'こく': 8, 'つ': 1}},
#  '区': {False: {'く': 8}, True: {'く': 1}},
#  '輪': {False: {'りん': 2, 'わ': 2}, True: {'わ': 1}},
#  '情': {False: {'じょう': 15, 'なさ': 2}, True: {'じょう': 1}},
#  '暮': {False: {'く': 4, 'ぐ': 1}},
#  '閉': {False: {'し': 2, 'と': 1, 'へい': 3}},
#  'む': {False: {'む': 93}},
#  '星': {False: {'せい': 4}, True: {'ほし': 1}},
#  '癌': {True: {'がん': 1}},
#  '稀': {True: {'まれ': 1}},
#  'ッ': {False: {'ッ': 1}},
#  '指': {False: {'さ': 1, 'さし': 1, 'ざ': 1, 'し': 6, 'ゆび': 7}, True: {'ゆび': 1}},
#  '食': {False: {'く': 2, 'しょく': 15, 'た': 2}},
#  '着': {False: {'き': 6, 'ぎ': 3, 'じゃく': 1, 'ちゃく': 8, 'つ': 5}, True: {'ちゃく': 1}},
#  '太': {False: {'たい': 2, 'ふと': 2}},
#  '業': {False: {'ぎょう': 25}, True: {'ごう': 1}},
#  '撫': {False: {'な': 1}},
#  '悔': {False: {'かい': 1, 'く': 1, 'くや': 1}},
#  '便': {False: {'たよ': 1, 'びん': 4, 'べん': 6}, True: {'びん': 1}},
#  '含': {False: {'ふく': 2}},
#  '戯': {False: {'ぎ': 1}},
#  '音': {False: {'おと': 1, 'おん': 7, 'ね': 1}, True: {'おと': 1}},
#  '提': {False: {'てい': 6}},
#  '施': {False: {'し': 2, 'ほどこ': 1}},
#  '雑': {False: {'ざつ': 5, 'ぞう': 1}, True: {'ざつ': 1}},
#  '顕': {False: {'けん': 1}},
#  '口': {False: {'くち': 6, 'ぐち': 7, 'こう': 7}, True: {'くち': 1}},
#  'り': {False: {'り': 166}},
#  '句': {False: {'く': 5}, True: {'く': 1}},
#  '晴': {False: {'せい': 2, 'は': 3, 'ば': 1}},
#  '犠': {False: {'ぎ': 1}},
#  '懸': {False: {'けん': 1}},
#  '達': {False: {'たつ': 5, 'だち': 1}},
#  '傘': {True: {'かさ': 1}},
#  '堪': {False: {'た': 1, 'たま': 1}},
#  '熟': {False: {'じゅく': 3}},
#  '防': {False: {'ふせ': 1, 'ぼう': 9}},
#  '検': {False: {'けん': 5}},
#  '証': {False: {'しょう': 5}, True: {'あかし': 1}},
#  '盤': {False: {'ばん': 4}},
#  '捨': {False: {'しゃ': 1, 'す': 1}},
#  '庖': {False: {'ほう': 1}},
#  '廷': {False: {'てい': 1}},
#  '訪': {False: {'おとず': 1, 'たず': 1, 'ほう': 1}},
#  '右': {False: {'ゆう': 1}, True: {'みぎ': 1}},
#  '膜': {True: {'まく': 1}},
#  '優': {False: {'すぐ': 1, 'やさ': 1, 'ゆう': 9}, True: {'やさ': 1}},
#  '人': {False: {'じん': 32, 'にん': 14, 'ひと': 7, 'びと': 1, 'り': 5}, True: {'ひと': 1}},
#  '伐': {True: {'ばつ': 1}},
#  '干': {False: {'かん': 1, 'ほ': 2, 'ぼし': 1}},
#  '速': {False: {'そく': 10, 'はや': 1}},
#  '報': {False: {'ほう': 8, 'ぽう': 1}},
#  '戚': {False: {'せき': 1}},
#  '歎': {True: {'たん': 1}},
#  '酒': {False: {'さか': 1, 'さけ': 1}, True: {'さけ': 1}},
#  '釣': {False: {'つ': 3, 'つり': 1}, True: {'つり': 1}},
#  '子': {False: {'こ': 5, 'ご': 1, 'し': 13, 'じ': 3, 'す': 3}, True: {'こ': 1}},
#  '泡': {True: {'あわ': 1}},
#  '未': {False: {'ま': 1, 'み': 8}, True: {'ひつじ': 1}},
#  '彙': {False: {'い': 1}},
#  '粧': {False: {'しょう': 1}},
#  '撃': {False: {'う': 1, 'げき': 5}},
#  '歌': {False: {'うた': 1, 'か': 3}, True: {'うた': 1}},
#  '謙': {False: {'けん': 2, 'へりくだ': 1}},
#  '衰': {False: {'おとろ': 1, 'すい': 1}},
#  '費': {False: {'つい': 1, 'ひ': 5}, True: {'ひ': 1}},
#  '険': {False: {'けわ': 1, 'けん': 3}},
#  '徒': {False: {'と': 2}},
#  '困': {False: {'こま': 1, 'こん': 2}},
#  '候': {False: {'こう': 3}},
#  '債': {False: {'さい': 1}},
#  '裂': {False: {'さ': 2, 'れつ': 2}},
#  '彫': {False: {'ちょう': 1, 'ほ': 1}},
#  '喉': {True: {'のど': 1}},
#  '拗': {False: {'こじ': 1}},
#  '春': {False: {'しゅん': 1}, True: {'はる': 1}},
#  '律': {False: {'りつ': 3}},
#  '甥': {True: {'おい': 1}},
#  '尋': {False: {'たず': 1}},
#  '詰': {False: {'つ': 3, 'づめ': 2}},
#  '巨': {False: {'きょ': 1}},
#  '沼': {True: {'ぬま': 1}},
#  '民': {False: {'みん': 14}},
#  '尚': {False: {'しょう': 1, 'なお': 1}, True: {'なお': 1}},
#  '鼓': {False: {'こ': 1}},
#  '覆': {False: {'おお': 1, 'くつがえ': 1, 'ふく': 1}},
#  '捗': {False: {'はかど': 1}},
#  '豆': {True: {'まめ': 1}},
#  '朽': {False: {'く': 1}},
#  '皮': {False: {'がわ': 1, 'ひ': 2}, True: {'かわ': 1}},
#  '紙': {False: {'かみ': 1, 'がみ': 3, 'し': 3}, True: {'かみ': 1}},
#  '圏': {True: {'けん': 1}},
#  '押': {False: {'お': 5, 'おさ': 1}},
#  '従': {False: {'したが': 2, 'じゅう': 3}},
#  '縦': {False: {'じゅう': 1}, True: {'たて': 1}},
#  '恵': {False: {'え': 1, 'けい': 1, 'めぐ': 3}},
#  '虜': {False: {'りょ': 1}},
#  '六': {False: {'むい': 1, 'むっ': 1}, True: {'ろく': 1}},
#  '丼': {True: {'どんぶり': 1}},
#  '加': {False: {'か': 12, 'くわ': 3}},
#  '夥': {False: {'おびただ': 1}},
#  '代': {False: {'か': 5, 'かわ': 1, 'が': 1, 'だい': 13}, True: {'しろ': 1}},
#  '経': {False: {'けい': 10, 'た': 1, 'へ': 1}},
#  '被': {False: {'かぶ': 2, 'ひ': 1}},
#  '沙': {False: {'さ': 3}},
#  '舟': {True: {'ふね': 1}},
#  '掘': {False: {'くつ': 1, 'ほ': 1}},
#  '蓮': {True: {'はす': 1}},
#  '仮': {False: {'か': 4, 'が': 3}, True: {'か': 1}},
#  '真': {False: {'しん': 6, 'ま': 12, 'まこと': 1}},
#  '教': {False: {'おし': 2, 'おそ': 1, 'きょう': 16}},
#  '痩': {False: {'や': 1}},
#  '綻': {False: {'ほころ': 1}},
#  '済': {False: {'さい': 2, 'ざい': 1, 'す': 5}},
#  '刻': {False: {'きざ': 1, 'こく': 5}},
#  '緩': {False: {'かん': 1, 'ゆる': 4}},
#  '漸': {False: {'ようや': 1}},
#  '控': {False: {'こう': 1, 'ひか': 1, 'ひかえ': 1}},
#  '油': {False: {'あぶら': 1, 'ゆ': 5}, True: {'あぶら': 1}},
#  '損': {False: {'そこ': 1, 'そん': 4}, True: {'そん': 1}},
#  '休': {False: {'きゅう': 11, 'やす': 7}},
#  '遣': {False: {'けん': 1, 'つか': 1, 'づか': 4, 'や': 2}},
#  '柄': {False: {'がら': 5}, True: {'がら': 1}},
#  '掬': {False: {'すく': 1}},
#  '懲': {False: {'こ': 1}},
#  '直': {False: {'じか': 1, 'じき': 1, 'す': 2, 'ただ': 1, 'ちょく': 9, 'なお': 6}},
#  '掛': {False: {'か': 20, 'が': 5}},
#  '几': {False: {'き': 1}},
#  '余': {False: {'あま': 2, 'よ': 6}},
#  '説': {False: {'せつ': 7, 'ぜつ': 1, 'と': 1}, True: {'せつ': 1}},
#  '嘩': {False: {'か': 1}},
#  'ら': {False: {'ら': 57}},
#  '曇': {False: {'くも': 2}},
#  '錠': {False: {'じょう': 1}},
#  '頬': {True: {'ほほ': 1}},
#  '欲': {False: {'ほ': 1, 'よく': 5}},
#  '箪': {False: {'たん': 1}},
#  '復': {False: {'ふく': 4}},
#  '地': {False: {'じ': 12, 'ち': 33}, True: {'ち': 1}},
#  '杯': {False: {'ぱい': 1}, True: {'さかずき': 1}},
#  '念': {False: {'ねん': 5}, True: {'ねん': 1}},
#  '式': {False: {'しき': 10}, True: {'しき': 1}},
#  '遮': {False: {'さえぎ': 1}},
#  '鉢': {True: {'はち': 1}},
#  '継': {False: {'けい': 2, 'つ': 4}},
#  '剖': {False: {'ぼう': 1}},
#  '講': {False: {'こう': 8}},
#  '膚': {False: {'ふ': 1}},
#  '砂': {False: {'さ': 2, 'じゃ': 1}, True: {'すな': 1}},
#  '釈': {False: {'しゃく': 1}},
#  '明': {False: {'あ': 7, 'あか': 1, 'あき': 1, 'みょう': 1, 'めい': 12}},
#  '鋏': {True: {'はさみ': 1}},
#  '院': {False: {'いん': 7}},
#  '郷': {False: {'きょう': 3}},
#  '佳': {False: {'か': 1}},
#  '至': {False: {'いた': 2, 'し': 2}},
#  '蝶': {True: {'ちょう': 1}},
#  '汰': {False: {'た': 3}},
#  '左': {False: {'さ': 3, 'ひだり': 1}, True: {'ひだり': 1}},
#  '枢': {False: {'すう': 1}},
#  '質': {False: {'しつ': 9, 'じち': 1}, True: {'しつ': 1}},
#  '噛': {False: {'か': 2}},
#  '皿': {False: {'さら': 1, 'ざら': 1}, True: {'さら': 1}},
#  '寛': {False: {'かん': 1}},
#  '米': {False: {'べい': 2}, True: {'こめ': 1}},
#  '蔑': {False: {'べつ': 1}},
#  'き': {False: {'き': 73}},
#  '雲': {True: {'くも': 1}},
#  '妊': {False: {'にん': 1}},
#  '称': {False: {'しょう': 2}},
#  '誘': {False: {'さそ': 1, 'ゆう': 3}},
#  '隣': {True: {'となり': 1}},
#  '語': {False: {'かた': 1, 'がた': 1, 'ご': 17}, True: {'ご': 1}},
#  '霊': {False: {'れい': 1}},
#  '渦': {True: {'うず': 1}},
#  '反': {False: {'かえ': 1, 'そ': 1, 'はん': 13}, True: {'たん': 1}},
#  '固': {False: {'かた': 3, 'こ': 4}},
#  '詩': {False: {'し': 1}, True: {'し': 1}},
#  '精': {False: {'せい': 3}},
#  '随': {False: {'ずい': 2}},
#  '悲': {False: {'かな': 2, 'ひ': 4}},
#  '零': {False: {'こぼ': 2, 'れい': 1}, True: {'れい': 1}},
#  '倉': {False: {'そう': 1}},
#  '添': {False: {'そ': 2}},
#  '旅': {False: {'りょ': 4}, True: {'たび': 1}},
#  '揚': {False: {'あ': 1}},
#  '不': {False: {'ふ': 32}, True: {'ふ': 1}},
#  '察': {False: {'さつ': 4}},
#  '寂': {False: {'さび': 1}},
#  '振': {False: {'しん': 3, 'ふ': 4, 'ふる': 1, 'ぶ': 2}},
#  '風': {False: {'かざ': 1, 'ふ': 3, 'ふう': 10, 'ぷう': 1}, True: {'かぜ': 1}},
#  '伝': {False: {'つた': 2, 'つだ': 3, 'つて': 1, 'づて': 1, 'でん': 7}},
#  '麓': {True: {'ふもと': 1}},
#  '七': {False: {'なな': 1, 'なの': 1}, True: {'なな': 1}},
#  '箸': {True: {'はし': 1}},
#  '託': {False: {'たく': 1}},
#  '型': {False: {'けい': 2}, True: {'かた': 1}},
#  '混': {False: {'こ': 1, 'こん': 5, 'ま': 4}},
#  '喜': {False: {'き': 1, 'よろこ': 2}},
#  '識': {False: {'しき': 6}},
#  '掲': {False: {'かか': 1, 'けい': 2}},
#  '琴': {True: {'こと': 1}},
#  '死': {False: {'し': 5}, True: {'し': 1}},
#  '緑': {True: {'みどり': 1}},
#  '衣': {False: {'い': 5}},
#  '袋': {False: {'ぶくろ': 1}, True: {'ふくろ': 1}},
#  '津': {False: {'つ': 1}},
#  '平': {False: {'たい': 1, 'ひら': 2, 'びょう': 1, 'へい': 14}},
#  '学': {False: {'がく': 42, 'まな': 1}, True: {'がく': 1}},
#  '千': {True: {'せん': 1}},
#  '需': {False: {'じゅ': 2}},
#  '原': {False: {'げん': 17, 'はら': 1}, True: {'はら': 1}},
#  '殖': {False: {'しょく': 1, 'ふ': 2}},
#  '承': {False: {'うけたまわ': 1, 'しょう': 4}},
#  '司': {False: {'し': 3, 'つかさど': 1}},
#  '場': {False: {'じょう': 12, 'ば': 13}, True: {'ば': 1}},
#  '底': {False: {'てい': 2}, True: {'そこ': 1}},
#  '々': {False: {'いち': 1,
#    'いや': 1,
#    'いろ': 1,
#    'きん': 1,
#    'こ': 1,
#    'しょ': 1,
#    'しょう': 1,
#    'じゅん': 1,
#    'ぞく': 1,
#    'たび': 1,
#    'たま': 1,
#    'だん': 1,
#    'ちゃく': 1,
#    'つぎ': 1,
#    'てん': 1,
#    'とう': 1,
#    'どう': 1,
#    'なが': 1,
#    'なに': 1,
#    'び': 1,
#    'べつ': 1,
#    'ま': 1,
#    'ます': 1,
#    'まる': 1,
#    'めい': 1,
#    'もと': 1,
#    'ゆう': 1,
#    'わざ': 1,
#    'われ': 1}},
#  'ぼ': {False: {'ぼ': 3}},
#  '辟': {False: {'へき': 1}},
#  '愁': {False: {'しゅう': 1}},
#  '繋': {False: {'つな': 4}},
#  '設': {False: {'せつ': 4, 'もう': 1}},
#  '克': {False: {'こく': 1}},
#  '親': {False: {'おや': 3, 'した': 2, 'しん': 7}, True: {'おや': 1}},
#  '諦': {False: {'あきら': 2}},
#  '碗': {False: {'わん': 1}, True: {'わん': 1}},
#  '用': {False: {'もち': 1, 'よう': 34}, True: {'よう': 1}},
#  '功': {False: {'こう': 2}},
#  '腐': {False: {'くさ': 1, 'ふ': 1}},
#  '厭': {False: {'いや': 1}},
#  '唾': {True: {'つば': 1}},
#  '南': {False: {'なん': 3}, True: {'みなみ': 1}},
#  '訂': {False: {'てい': 2}},
#  '環': {False: {'かん': 2}},
#  '聖': {False: {'せい': 2}},
#  '元': {False: {'がん': 2, 'げん': 4, 'もと': 3}, True: {'もと': 1}},
#  '刃': {True: {'は': 1}},
#  '胞': {False: {'ぼう': 1}},
#  '遜': {False: {'そん': 1}},
#  '税': {False: {'ぜい': 6}, True: {'ぜい': 1}},
#  '客': {False: {'かく': 1, 'きゃく': 4}, True: {'きゃく': 1}},
#  '請': {False: {'こ': 1, 'せい': 3}},
#  '洪': {False: {'こう': 1}},
#  '端': {False: {'たん': 3, 'ぱ': 1}, True: {'はし': 1}},
#  '枯': {False: {'か': 1}},
#  '内': {False: {'うち': 2, 'ない': 11}, True: {'うち': 1}},
#  '世': {False: {'せ': 8, 'せい': 2, 'よ': 1}, True: {'よ': 1}},
#  '稼': {False: {'かせ': 2}},
#  '液': {False: {'えき': 3}, True: {'えき': 1}},
#  '運': {False: {'うん': 14, 'はこ': 1}, True: {'うん': 1}},
#  '捩': {False: {'ねじ': 1}},
#  '馴': {False: {'な': 4}},
#  '痴': {False: {'ち': 1}},
#  '橋': {False: {'きょう': 1, 'はし': 1}, True: {'はし': 1}},
#  '項': {False: {'こう': 2}},
#  '眠': {False: {'ねむ': 4, 'みん': 2}},
#  '侮': {False: {'ぶ': 1}},
#  '朝': {False: {'あさ': 3}, True: {'あさ': 1}},
#  '劣': {False: {'おと': 1}},
#  '倹': {False: {'けん': 1}},
#  '駐': {False: {'ちゅう': 2}},
#  '則': {False: {'そく': 4}},
#  '航': {False: {'こう': 2}},
#  '胆': {False: {'たん': 1}},
#  '尿': {False: {'にょう': 1}, True: {'にょう': 1}},
#  '御': {False: {'お': 3, 'おん': 1, 'ご': 12}, True: {'お': 1}},
#  '描': {False: {'か': 1, 'びょう': 1}},
#  '珠': {False: {'じゅ': 1}},
#  '逸': {False: {'そ': 2}},
#  '呼': {False: {'こ': 1, 'よ': 4}},
#  '桜': {True: {'さくら': 1}},
#  '芸': {False: {'げい': 7}},
#  '厳': {False: {'おごそ': 1, 'きび': 1, 'げん': 2}},
#  '漢': {False: {'かん': 3}},
#  '揺': {False: {'ゆ': 3, 'よう': 1}},
#  '化': {False: {'か': 14, 'け': 1, 'ば': 1}},
#  '誤': {False: {'あやま': 2, 'ご': 4}},
#  '帯': {False: {'お': 1, 'たい': 7}, True: {'おび': 1}},
#  '慎': {False: {'しん': 1, 'つつし': 1}},
#  '役': {False: {'やく': 11}, True: {'やく': 1}},
#  '短': {False: {'たん': 9, 'みじか': 1}},
#  '麦': {False: {'むぎ': 1}},
#  '辻': {False: {'つじ': 1}},
#  '下': {False: {'お': 2, 'か': 13, 'くだ': 4, 'げ': 8, 'さ': 4, 'した': 11},
#   True: {'しも': 1}},
#  '雪': {True: {'ゆき': 1}},
#  '比': {False: {'くら': 1, 'ひ': 6}},
#  '対': {False: {'たい': 19}, True: {'つい': 1}},
#  '衆': {False: {'しゅう': 4}, True: {'しゅう': 1}},
#  '松': {True: {'まつ': 1}},
#  '陳': {False: {'ちん': 1}},
#  '聴': {False: {'ちょう': 3}},
#  '那': {False: {'な': 1}},
#  '監': {False: {'かん': 2}},
#  '勝': {False: {'か': 2, 'しょう': 4, 'まさ': 1}},
#  '鍵': {True: {'かぎ': 1}},
#  '炭': {False: {'たん': 3}},
#  '幸': {False: {'こう': 3, 'さいわ': 1, 'しあわ': 1}},
#  '香': {False: {'かお': 1, 'こう': 2}},
#  '福': {False: {'ふく': 2}, True: {'ふく': 1}},
#  '炒': {False: {'いた': 1}},
#  '競': {False: {'きょう': 2, 'けい': 1}},
#  '夏': {False: {'なつ': 1}, True: {'なつ': 1}},
#  '域': {False: {'いき': 5}},
#  '劇': {False: {'げき': 5}, True: {'げき': 1}},
#  '裕': {False: {'ゆう': 1}},
#  '分': {False: {'ぶ': 1, 'ぶん': 36, 'わ': 6, 'わけ': 1}, True: {'ぶん': 1}},
#  '既': {False: {'き': 1, 'すで': 1}},
#  '煙': {False: {'えん': 2, 'けむ': 3}, True: {'けむり': 1}},
#  '純': {False: {'じゅん': 4}},
#  '灰': {False: {'はい': 2}, True: {'はい': 1}},
#  '魔': {False: {'ま': 4}},
#  '縫': {False: {'ぬ': 1, 'ほう': 1}},
#  '士': {False: {'し': 6}},
#  '糊': {True: {'のり': 1}},
#  '状': {False: {'じょう': 5}, True: {'じょう': 1}},
#  '参': {False: {'さん': 6, 'まい': 2}},
#  '男': {False: {'おとこ': 2, 'だん': 2, 'なん': 1}, True: {'おとこ': 1}},
#  '微': {False: {'かす': 1, 'び': 4}},
#  '為': {False: {'い': 1, 'ため': 1, 'な': 3}, True: {'ため': 1}},
#  '躍': {False: {'やく': 1}},
#  '胡': {False: {'こ': 1}},
#  '丸': {False: {'まる': 8}, True: {'まる': 1}},
#  '桁': {True: {'けた': 1}},
#  '氾': {False: {'はん': 1}},
#  '魂': {True: {'こん': 1}},
#  '狙': {False: {'ねら': 2}},
#  '筈': {False: {'はず': 1}, True: {'はず': 1}},
#  '種': {False: {'しゅ': 4}, True: {'たね': 1}},
#  '釘': {True: {'くぎ': 1}},
#  '彼': {False: {'かの': 1, 'かれ': 1}, True: {'かれ': 1}},
#  '格': {False: {'かく': 11}, True: {'かく': 1}},
#  '莫': {False: {'ばく': 1}},
#  '狂': {False: {'くる': 1}},
#  '拓': {False: {'たく': 1}},
#  '慰': {False: {'なぐさ': 1}},
#  '忙': {False: {'いそが': 1, 'ぼう': 1}},
#  '奪': {False: {'うば': 1, 'だつ': 1}},
#  '名': {False: {'な': 11, 'みょう': 2, 'めい': 19}, True: {'な': 1}},
#  '英': {False: {'えい': 6}},
#  '依': {False: {'い': 3, 'よ': 1}, True: {'い': 1}},
#  '昧': {False: {'まい': 1}},
#  '隔': {False: {'かく': 2, 'へだ': 2}},
#  '虫': {False: {'ちゅう': 1, 'むし': 1}, True: {'むし': 1}},
#  '勉': {False: {'べん': 2}},
#  '診': {False: {'しん': 4, 'み': 1}},
#  'ゴ': {False: {'ゴ': 1}},
#  '品': {False: {'しな': 1, 'じな': 1, 'ひん': 16}, True: {'ひん': 1}},
#  '氏': {False: {'し': 1}, True: {'し': 1}},
#  'ぶ': {False: {'ぶ': 20}},
#  '妙': {False: {'みょう': 3}, True: {'みょう': 1}},
#  '偉': {False: {'い': 1, 'えら': 1}},
#  '雷': {True: {'かみなり': 1}},
#  '拵': {False: {'こしら': 1}},
#  '唱': {False: {'しょう': 1, 'とな': 1}},
#  '宿': {False: {'しゅく': 5}, True: {'やど': 1}},
#  '効': {False: {'き': 2, 'こう': 5}},
#  '獄': {False: {'ごく': 1}},
#  '爽': {False: {'さわ': 1}},
#  '刷': {False: {'さつ': 1, 'す': 2}},
#  '褒': {False: {'ほ': 1, 'ほう': 1}},
#  '戻': {False: {'もど': 4}},
#  '蚊': {True: {'か': 1}},
#  '夜': {False: {'や': 7, 'よ': 4}, True: {'よ': 1}},
#  '卑': {False: {'いや': 1, 'ひ': 1}},
#  '泳': {False: {'えい': 1, 'およ': 3}},
#  '降': {False: {'お': 2, 'こう': 4, 'ふ': 2}},
#  '櫛': {True: {'くし': 1}},
#  '専': {False: {'せん': 4, 'もっぱ': 1}},
#  '銃': {True: {'じゅう': 1}},
#  '金': {False: {'かな': 1, 'かね': 2, 'がね': 1, 'きん': 23, 'ぎん': 1, 'ごん': 1},
#   True: {'きん': 1}},
#  '騙': {False: {'だま': 1}},
#  '偽': {False: {'ぎ': 1}},
#  '森': {False: {'しん': 1}, True: {'もり': 1}},
#  'し': {False: {'し': 158}},
#  '竿': {True: {'さお': 1}},
#  '綴': {False: {'と': 1}},
#  '詐': {False: {'さ': 1}},
#  '募': {False: {'つの': 1, 'ぼ': 4}},
#  '枚': {False: {'まい': 1}, True: {'まい': 1}},
#  '手': {False: {'しゅ': 12, 'ず': 1, 'て': 39, 'で': 1}, True: {'て': 1}},
#  '更': {False: {'こう': 1, 'さら': 3, 'ふ': 3}},
#  '猛': {False: {'もう': 1}},
#  '街': {False: {'かい': 1, 'がい': 2, 'まち': 1}, True: {'まち': 1}},
#  '走': {False: {'そう': 5, 'はし': 1}},
#  '舶': {False: {'ぱく': 1}},
#  '醤': {False: {'しょう': 1}},
#  '本': {False: {'ほん': 24, 'ぽん': 1}, True: {'ほん': 1}},
#  '性': {False: {'せい': 13}, True: {'せい': 1}},
#  '盟': {False: {'めい': 2}},
#  '粘': {False: {'ねば': 2}},
#  '餌': {True: {'えさ': 1}},
#  '災': {False: {'さい': 5}},
#  '胸': {True: {'むね': 1}},
#  '嬢': {False: {'じょう': 1}, True: {'じょう': 1}},
#  '銭': {False: {'せん': 1, 'ぜに': 1}},
#  '瞳': {True: {'ひとみ': 1}},
#  '返': {False: {'かえ': 8, 'がえ': 3, 'へん': 4}},
#  '瞬': {False: {'しゅん': 1, 'またた': 1}},
#  '担': {False: {'かつ': 1, 'たん': 4, 'にな': 1}},
#  '遂': {False: {'つい': 1, 'と': 2}},
#  '恩': {False: {'おん': 1}, True: {'おん': 1}},
#  '供': {False: {'きょう': 2, 'とも': 1, 'ども': 1}, True: {'きょう': 1}},
#  '義': {False: {'ぎ': 7}},
#  '呟': {False: {'つぶや': 1}},
#  '獣': {False: {'じゅう': 1}, True: {'けだもの': 1}},
#  '斜': {False: {'しゃ': 2, 'なな': 1}},
#  '孤': {False: {'こ': 3}},
#  '溢': {False: {'あふ': 1}},
#  '寮': {True: {'りょう': 1}},
#  '邦': {False: {'ぽう': 1}},
#  '矛': {False: {'む': 1}},
#  '諾': {False: {'だく': 1}},
#  '撮': {False: {'さつ': 1, 'と': 1}},
#  '囁': {False: {'ささや': 1}},
#  '悉': {False: {'ことごと': 1}},
#  '味': {False: {'あじ': 2, 'み': 15}, True: {'あじ': 1}},
#  '岬': {True: {'みさき': 1}},
#  '頑': {False: {'がん': 2}},
#  '過': {False: {'あやま': 1, 'か': 12, 'す': 4}},
#  '都': {False: {'つ': 1, 'と': 4}, True: {'と': 1}},
#  '慣': {False: {'かん': 5, 'な': 4}},
#  '枕': {True: {'まくら': 1}},
#  '係': {False: {'かか': 2, 'けい': 1}, True: {'かかり': 1}},
#  '磁': {False: {'じ': 3}},
#  '等': {False: {'とう': 6, 'どう': 1, 'ひと': 1, 'ら': 1}, True: {'など': 1}},
#  '鍛': {False: {'きた': 1}},
#  '色': {False: {'いろ': 6, 'しき': 1, 'しょく': 3}, True: {'いろ': 1}},
#  '陶': {False: {'とう': 2}},
#  '次': {False: {'し': 1, 'じ': 1, 'つ': 3, 'つぎ': 1}, True: {'つぎ': 1}},
#  '婚': {False: {'こん': 5}},
#  '肘': {True: {'ひじ': 1}},
#  '替': {False: {'か': 4, 'が': 1, 'がえ': 1, 'たい': 1}},
#  '諮': {False: {'はか': 1}},
#  '堅': {False: {'かた': 1}},
#  '庫': {False: {'こ': 5}},
#  '臣': {False: {'じん': 2}},
#  '寸': {False: {'すん': 1}},
#  '宴': {False: {'えん': 1}},
#  '務': {False: {'つと': 2, 'む': 12}},
#  '脱': {False: {'ぬ': 1}},
#  '玉': {True: {'たま': 1}},
#  '百': {True: {'ひゃく': 1}},
#  '蛍': {False: {'けい': 1}},
#  '持': {False: {'じ': 5, 'も': 9}},
#  '俄': {True: {'にわか': 1}},
#  '維': {False: {'い': 2}},
#  '嫌': {False: {'いや': 1, 'きら': 3, 'げん': 1}, True: {'いや': 1}},
#  '祈': {False: {'いの': 2}},
#  '栽': {False: {'さい': 1}},
#  '届': {False: {'とど': 3}},
#  '焼': {False: {'しょう': 1, 'や': 4}},
#  '臓': {False: {'ぞう': 2}},
#  '起': {False: {'お': 4, 'おこ': 1, 'き': 4}},
#  '億': {True: {'おく': 1}},
#  '鑑': {False: {'かん': 4}},
#  '哀': {False: {'あわ': 1}},
#  '迅': {False: {'じん': 1}},
#  '郊': {False: {'こう': 2}},
#  '弾': {False: {'だん': 2, 'はず': 1, 'ひ': 1}, True: {'たま': 1}},
#  '籤': {False: {'くじ': 1}},
#  '崖': {True: {'がけ': 1}},
#  '際': {False: {'ぎわ': 1, 'さい': 2}, True: {'さい': 1}},
#  '蕩': {False: {'とろ': 1}},
#  '協': {False: {'きょう': 6}},
#  '歩': {False: {'あゆ': 2, 'ある': 1, 'ほ': 3, 'ぽ': 2}, True: {'ふ': 1}},
#  '必': {False: {'かなら': 2, 'ひつ': 3}},
#  '訓': {False: {'くん': 2}, True: {'くん': 1}},
#  '哲': {False: {'てつ': 1}},
#  'ん': {False: {'ん': 16}},
#  '勧': {False: {'かん': 2, 'すす': 2}},
#  '送': {False: {'おく': 4, 'そう': 8}},
#  '但': {False: {'ただ': 1}},
#  '睨': {False: {'にら': 1}},
#  '活': {False: {'い': 1, 'かつ': 6}},
#  '瞑': {False: {'つぶ': 1}},
#  '京': {False: {'きょう': 2}},
#  '輸': {False: {'ゆ': 5}},
#  '算': {False: {'さん': 6, 'ざん': 6, 'そろ': 1}},
#  '革': {False: {'かく': 4, 'かわ': 1}, True: {'かわ': 1}},
#  '海': {False: {'うみ': 1, 'かい': 10}, True: {'うみ': 1}},
#  '糖': {False: {'とう': 1}},
#  '登': {False: {'と': 1, 'とう': 3, 'のぼ': 1}},
#  '鉄': {False: {'てつ': 4}, True: {'てつ': 1}},
#  '祉': {False: {'し': 1}},
#  '草': {False: {'ぞう': 1}, True: {'くさ': 1}},
#  '息': {False: {'いき': 2, 'そく': 4}, True: {'いき': 1}},
#  '驚': {False: {'おどろ': 3, 'きょう': 1}},
#  '皆': {False: {'みな': 1}, True: {'みな': 1}},
#  '方': {False: {'かた': 7, 'がた': 2, 'ほう': 15, 'ぽう': 1}, True: {'ほう': 1}},
#  '正': {False: {'しょう': 4, 'せい': 15, 'ただ': 1, 'まさ': 2}, True: {'せい': 1}},
#  '叩': {False: {'たた': 1}},
#  '刀': {True: {'かたな': 1}},
#  '鋭': {False: {'するど': 1}},
#  '川': {False: {'せん': 1}, True: {'かわ': 1}},
#  '波': {False: {'なみ': 1, 'ぱ': 2}, True: {'なみ': 1}},
#  '愉': {False: {'ゆ': 1}},
#  '歪': {False: {'いが': 1}},
#  '髭': {True: {'ひげ': 1}},
#  '線': {False: {'せん': 15}, True: {'せん': 1}},
#  '貯': {False: {'ちょ': 3}},
#  '成': {False: {'せい': 17, 'な': 6}},
#  '塩': {False: {'えん': 1, 'しお': 1}, True: {'しお': 1}},
#  '染': {False: {'し': 1, 'せん': 3, 'そ': 2}},
#  '冬': {False: {'とう': 1}, True: {'ふゆ': 1}},
#  '鉱': {False: {'こう': 4}},
#  '働': {False: {'どう': 1, 'はたら': 2, 'ばたら': 1}, True: {'どう': 1}},
#  '町': {False: {'まち': 1}, True: {'まち': 1}},
#  '励': {False: {'はげ': 2, 'れい': 2}},
#  '概': {False: {'がい': 6}},
#  '門': {False: {'もん': 2}, True: {'もん': 1}},
#  '鉛': {False: {'えん': 1}, True: {'なまり': 1}},
#  '抵': {False: {'てい': 2}},
#  '峰': {True: {'みね': 1}},
#  '吟': {False: {'ぎん': 1}},
#  '立': {False: {'た': 10, 'たち': 2, 'だ': 5, 'だち': 1, 'だて': 1, 'りつ': 14}},
#  '東': {False: {'とう': 3}, True: {'ひがし': 1}},
#  '台': {False: {'たい': 2, 'だい': 6}, True: {'だい': 1}},
#  '畜': {False: {'ちく': 4}},
#  '補': {False: {'おぎな': 1, 'ほ': 7}},
#  '量': {False: {'はか': 1, 'りょう': 6}, True: {'りょう': 1}},
#  '責': {False: {'せ': 1, 'せき': 2}},
#  '編': {False: {'あ': 1, 'あみ': 1, 'へん': 2, 'ぺん': 1}, True: {'へん': 1}},
#  '移': {False: {'い': 5, 'うつ': 2}},
#  '沢': {False: {'たく': 3}},
#  '舗': {False: {'ほ': 1}},
#  '価': {False: {'か': 5}},
#  '根': {False: {'こん': 6, 'ね': 4}, True: {'ね': 1}},
#  '鎖': {False: {'さ': 2}, True: {'くさり': 1}},
#  '券': {False: {'けん': 3}, True: {'けん': 1}},
#  '佚': {True: {'いつ': 1}},
#  '窮': {False: {'きゅう': 2}},
#  '拡': {False: {'かく': 4}},
#  '禄': {False: {'ろく': 1}},
#  '投': {False: {'とう': 4, 'な': 2}},
#  '最': {False: {'さい': 8, 'もっと': 1}},
#  '答': {False: {'こた': 2, 'とう': 4, 'どう': 1}, True: {'こたえ': 1}},
#  '否': {False: {'ひ': 3}, True: {'いや': 1}},
#  '断': {False: {'ことわ': 1, 'だん': 12}},
#  '準': {False: {'じゅん': 8}},
#  '滲': {False: {'にじ': 1}},
#  '城': {False: {'じょう': 1}, True: {'しろ': 1}},
#  '戦': {False: {'せん': 10, 'たたか': 2}, True: {'いくさ': 1}},
#  '枠': {True: {'わく': 1}},
#  '致': {False: {'いた': 1, 'ち': 2}},
#  '洗': {False: {'あら': 4, 'せん': 3}},
#  '凍': {False: {'こお': 1, 'こご': 1, 'とう': 1}},
#  '砕': {False: {'くだ': 2}},
#  '企': {False: {'き': 2}},
#  '管': {False: {'かん': 2}, True: {'くだ': 1}},
#  '飴': {True: {'あめ': 1}},
#  '将': {False: {'しょう': 2}},
#  '数': {False: {'かず': 1, 'かぞ': 1, 'すう': 19}, True: {'すう': 1}},
#  '知': {False: {'し': 5, 'ち': 12}},
#  '髪': {False: {'かみ': 1}, True: {'かみ': 1}},
#  '存': {False: {'そん': 4, 'ぞん': 4}},
#  '腸': {True: {'ちょう': 1}},
#  '危': {False: {'あぶ': 1, 'あや': 2, 'き': 3}},
#  '終': {False: {'お': 3, 'おわ': 1, 'しゅう': 5, 'じゅう': 1}},
#  '畏': {False: {'かしこ': 1}},
#  '探': {False: {'さが': 1, 'さぐ': 1, 'たん': 1}},
#  '冠': {True: {'かんむり': 1}},
#  '浸': {False: {'ひた': 1}},
#  '体': {False: {'からだ': 1, 'たい': 27, 'てい': 1}, True: {'からだ': 1}},
#  '濡': {False: {'ぬ': 3}},
#  '青': {False: {'あお': 2, 'せい': 3}, True: {'あお': 1}},
#  '富': {False: {'と': 1, 'ふ': 2}, True: {'とみ': 1}},
#  '剥': {False: {'は': 3, 'む': 1}},
#  '憎': {False: {'にく': 5}},
#  '異': {False: {'い': 8, 'こと': 1}},
#  '鞠': {True: {'まり': 1}},
#  '源': {False: {'げん': 6}, True: {'みなもと': 1}},
#  '烈': {False: {'れつ': 2}},
#  '抽': {False: {'ちゅう': 2}},
#  '華': {False: {'か': 3, 'はな': 1}},
#  '計': {False: {'けい': 10, 'はか': 1}},
#  '睡': {False: {'すい': 1}},
#  '憂': {False: {'ゆう': 1}},
#  '涼': {False: {'すず': 2}},
#  '亡': {False: {'な': 2, 'ぼう': 3}},
#  '貰': {False: {'もら': 1}},
#  '繕': {False: {'ぜん': 1, 'つくろ': 1}},
#  '揮': {False: {'き': 1}},
#  '遡': {False: {'さかのぼ': 1}},
#  '深': {False: {'しん': 2, 'ふか': 4, 'ぶか': 1}},
#  '乏': {False: {'とぼ': 1, 'ぼう': 3}},
#  '療': {False: {'りょう': 3}},
#  '賑': {False: {'にぎ': 2}},
#  '師': {False: {'し': 7}},
#  '樹': {False: {'じゅ': 2}},
#  '蓄': {False: {'たくわ': 1, 'ちく': 2}},
#  '詫': {False: {'わ': 2}},
#  '申': {False: {'しん': 2, 'もう': 9, 'もうし': 1}},
#  '贅': {False: {'ぜい': 1}},
#  '虚': {False: {'きょ': 1}},
#  '距': {False: {'きょ': 1}},
#  '宝': {False: {'ほう': 3}, True: {'たから': 1}},
#  '側': {False: {'がわ': 2, 'そく': 1}, True: {'そば': 1}},
#  '還': {False: {'かん': 3}},
#  '派': {False: {'は': 3}, True: {'は': 1}},
#  '抱': {False: {'いだ': 1, 'かか': 1, 'ほう': 1, 'ぼう': 1}},
#  '雨': {False: {'あま': 2, 'う': 2}, True: {'あめ': 1}},
#  '歳': {False: {'ざい': 1}, True: {'さい': 1}},
#  '旗': {True: {'はた': 1}},
#  '拝': {False: {'おが': 1, 'はい': 4}},
#  '野': {False: {'や': 8}, True: {'の': 1}},
#  '悠': {False: {'ゆう': 1}},
#  '遇': {False: {'ぐう': 2}},
#  '温': {False: {'おん': 9}},
#  '充': {False: {'じゅう': 3}},
#  '校': {False: {'こう': 8}, True: {'こう': 1}},
#  '株': {False: {'かぶ': 1}, True: {'かぶ': 1}},
#  '島': {False: {'とう': 1}, True: {'しま': 1}},
#  '駅': {True: {'えき': 1}},
#  '少': {False: {'しょう': 7, 'すく': 2, 'すこ': 2}},
#  '訟': {False: {'しょう': 1}},
#  'ト': {False: {'ト': 1}},
#  '憲': {False: {'けん': 1}},
#  '循': {False: {'じゅん': 1}},
#  '胃': {True: {'い': 1}},
#  '叫': {False: {'さけ': 2}},
#  '躾': {True: {'しつけ': 1}},
#  '沸': {False: {'わ': 2}},
#  '火': {False: {'か': 11, 'ひ': 1, 'び': 2}, True: {'ひ': 1}},
#  '秘': {False: {'ひ': 2, 'ぴ': 1}},
#  '僚': {False: {'りょう': 2}},
#  '央': {False: {'おう': 1}},
#  '騒': {False: {'さわ': 3, 'そう': 2}},
#  '赤': {False: {'あか': 5, 'せき': 1}, True: {'あか': 1}},
#  '兆': {False: {'きざ': 1}, True: {'きざし': 1}},
#  '塗': {False: {'ぬ': 1}},
#  '骨': {False: {'こつ': 1}, True: {'ほね': 1}},
#  '容': {False: {'よう': 10}},
#  '棄': {False: {'き': 4}},
#  '孝': {False: {'こう': 1}},
#  '罰': {False: {'ばっ': 1, 'ばつ': 2}, True: {'ばち': 1}},
#  '呆': {False: {'あき': 1, 'ぼう': 1}},
#  '怠': {False: {'おこた': 1, 'たい': 1, 'なま': 1}},
#  '曲': {False: {'きょく': 3, 'ま': 2}, True: {'きょく': 1}},
#  '遠': {False: {'えん': 5, 'とお': 4, 'どお': 1}},
#  '徐': {False: {'じょ': 1}},
#  '般': {False: {'ぱん': 1}},
#  '蔵': {False: {'ぞう': 5}, True: {'くら': 1}},
#  '円': {False: {'えん': 4, 'まる': 1}, True: {'えん': 1}},
#  '授': {False: {'さず': 1, 'じゅ': 3}},
#  '由': {False: {'ゆ': 1, 'ゆう': 3}},
#  '旦': {False: {'だん': 1}},
#  '褄': {False: {'つま': 1}},
#  '蔭': {False: {'かげ': 2}},
#  '悪': {False: {'あ': 1, 'あく': 3, 'わる': 5}, True: {'あく': 1}},
#  '崩': {False: {'くず': 2, 'ほう': 1}},
#  'ぬ': {False: {'ぬ': 1}},
#  '茎': {True: {'くき': 1}},
#  '逞': {False: {'たくま': 1}},
#  '石': {False: {'しゃく': 1, 'せき': 5}, True: {'いし': 1}},
#  '酌': {False: {'く': 1}},
#  '慨': {False: {'がい': 2}},
#  '遷': {False: {'せん': 1}},
#  '塞': {False: {'ふさ': 2}},
#  '淡': {False: {'たん': 2}},
#  '沿': {False: {'えん': 2, 'そ': 1, 'ぞ': 1}},
#  '紹': {False: {'しょう': 1}},
#  '聞': {False: {'き': 3, 'ぶん': 2}},
#  '扱': {False: {'あつか': 4}},
#  '昇': {False: {'しょう': 2, 'のぼ': 1}},
#  '盾': {False: {'じゅん': 1}, True: {'たて': 1}},
#  '潮': {True: {'うしお': 1}},
#  '餅': {True: {'もち': 1}},
#  '乾': {False: {'かわ': 2, 'かん': 3}, True: {'かん': 1}},
#  '途': {False: {'と': 7}},
#  '合': {False: {'あ': 26, 'あい': 9, 'がっ': 3, 'ごう': 19}},
#  '箒': {True: {'ほうき': 1}},
#  '譜': {False: {'ふ': 1}},
#  '選': {False: {'えら': 1, 'せん': 6}},
#  '耐': {False: {'た': 1}},
#  '萎': {False: {'しな': 1, 'しぼ': 1}},
#  '善': {False: {'ぜん': 4, 'よ': 1}, True: {'ぜん': 1}},
#  '戴': {False: {'いただ': 1}},
#  '界': {False: {'かい': 3}},
#  '丈': {False: {'じょう': 3, 'たけ': 1}, True: {'だけ': 1}},
#  '脆': {False: {'もろ': 1}},
#  '稲': {False: {'いな': 1}, True: {'いね': 1}},
#  'で': {False: {'で': 14}},
#  '脈': {False: {'みゃく': 2}, True: {'みゃく': 1}},
#  '流': {False: {'なが': 4, 'りゅう': 10}, True: {'りゅう': 1}},
#  '勿': {False: {'もち': 1}},
#  '首': {False: {'くび': 3, 'しゅ': 6}, True: {'くび': 1}},
#  '洋': {False: {'よう': 6}},
#  'ム': {False: {'ム': 1}},
#  '穀': {False: {'こく': 1}},
#  '国': {False: {'くに': 1, 'こく': 15, 'ごく': 1}, True: {'くに': 1}},
#  '示': {False: {'しめ': 1, 'じ': 5}},
#  '特': {False: {'とく': 14}},
#  'っ': {False: {'っ': 43}},
#  '患': {False: {'かん': 1}},
#  '豚': {False: {'ぶた': 1}},
#  '鼾': {True: {'いびき': 1}},
#  '貴': {False: {'き': 2, 'たっと': 1}},
#  '腿': {True: {'もも': 1}},
#  ...}

# %%
def getProbabilitiesDebug(kanji=None,prevPron=None,prevChar=None,nextPron=None,nextChar=None,allKanji=None):
    """Inputs: kanji, prevPron?, prevChar?, nextPron?, nextChar?, allKanji?
? = optional
Output: A List of Dictionaries of occurences
TODO: Feed the list of dictionaries to computeProbabilities
This function returns all of the statistics for the current Kanji in
all contexts, independent of each other. This means that the nextPronunciation
dictionary will not be affected by the presence of an allKanji flag.

The order of the dictionaries are:
curPron, prevPron, prevChar, nextPron, nextChar, allKanji
"""
    ### TODO: Update with CurrentKanjiOneChar
    dictionary_list = []
    dictionary_list.append(currentPronunciation.get(kanji, dict()))
    if prevPron == None:
        dictionary_list.append(previousPronunciationCurrentPronunciation.get(kanji, dict()))
    else:
        dictionary_list.append(previousPronunciationCurrentPronunciation.get(kanji, dict()).get(prevPron, dict()))
    if prevChar == None:
        dictionary_list.append(previousCharacterCurrentPronunciation.get(kanji, dict()))
    else:
        dictionary_list.append(previousCharacterCurrentPronunciation.get(kanji, dict()).get(prevChar, dict()))
    if nextPron == None:
        dictionary_list.append(nextPronunciationCurrentPronunciation.get(kanji, dict()))
    else:
        dictionary_list.append(nextPronunciationCurrentPronunciation.get(kanji, dict()).get(nextPron, dict()))
    if nextChar == None:
        dictionary_list.append(nextCharacterCurrentPronunciation.get(kanji, dict()))
    else:
        dictionary_list.append(nextCharacterCurrentPronunciation.get(kanji, dict()).get(nextChar, dict()))
    if allKanji == None:
        dictionary_list.append(allKanjiCurrentPronunciation.get(kanji, dict()))
    else:
        dictionary_list.append(allKanjiCurrentPronunciation.get(kanji, dict()).get(allKanji, dict()))
    return computeProbabilities(dictionary_list)

# %%
def getProbabilities(kanji=None,prevPron=None,prevChar=None,nextPron=None,nextChar=None,allKanji=None):
    """Inputs: kanji, prevPron?, prevChar?, nextPron?, nextChar?, allKanji?
? = optional
Output: A List of Dictionaries of occurences
TODO: Feed the list of dictionaries to computeProbabilities
This function returns all of the statistics for the current Kanji in
all contexts, independent of each other. This means that the nextPronunciation
dictionary will not be affected by the presence of an allKanji flag.

The order of the dictionaries are:
curPron, prevPron, prevChar, nextPron, nextChar, allKanji
"""
    dictionary_list = []
    keys = set(currentPronunciation.get(kanji, dict()).keys())
    dictionary_list.append(occurencesToPercentages(currentPronunciation.get(kanji, dict())))
    argument_list = []
    if prevPron != None:
        argument_list.append(prevPron)
        keys = keys | set(currentPronunciationPreviousPronunciation.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationPreviousPronunciation.get(kanji, dict()), prevPron))
    if prevChar != None:
        argument_list.append(prevChar)
        keys = keys | set(currentPronunciationPreviousCharacter.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationPreviousCharacter.get(kanji, dict()), prevChar))
    if nextPron != None:
        argument_list.append(nextPron)
        keys = keys | set(currentPronunciationNextPronunciation.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationNextPronunciation.get(kanji, dict()), nextPron))
    if nextChar != None:
        argument_list.append(nextChar)
        keys = keys | set(currentPronunciationNextCharacter.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationNextCharacter.get(kanji, dict()), nextChar))
    if allKanji != None:
        argument_list.append(allKanji)
        keys = keys | set(currentPronunciationAllKanji.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationAllKanji.get(kanji, dict()), allKanji))
    return bayesTheorem(dictionary_list, keys, argument_list)

# %%
def getGlobalProbabilities(kanji=None,prevPron=None,prevChar=None,nextPron=None,nextChar=None,allKanji=None):
    """Inputs: kanji, prevPron?, prevChar?, nextPron?, nextChar?, allKanji?
? = optional
Output: A List of Dictionaries of occurences
TODO: Feed the list of dictionaries to computeProbabilities
This function returns all of the statistics for the current Kanji in
all contexts, independent of each other. This means that the nextPronunciation
dictionary will not be affected by the presence of an allKanji flag.

The order of the dictionaries are:
curPron, prevPron, prevChar, nextPron, nextChar, allKanji
"""
    dictionary_list = []
    keys = set(currentPronunciation.get(kanji, dict()).keys())
    dictionary_list.append(occurencesToPercentages(currentPronunciation.get(kanji, dict())))
    argument_list = []
    if prevPron != None:
        argument_list.append(prevPron)
        keys = keys | set(currentPronunciationPreviousPronunciation.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationPreviousPronunciation.get(kanji, dict()), prevPron))
    if prevChar != None:
        argument_list.append(prevChar)
        keys = keys | set(currentPronunciationPreviousCharacter.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationPreviousCharacter.get(kanji, dict()), prevChar))
    if nextPron != None:
        argument_list.append(nextPron)
        keys = keys | set(currentPronunciationNextPronunciation.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationNextPronunciation.get(kanji, dict()), nextPron))
    if nextChar != None:
        argument_list.append(nextChar)
        keys = keys | set(currentPronunciationNextCharacter.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationNextCharacter.get(kanji, dict()), nextChar))
    if allKanji != None:
        argument_list.append(allKanji)
        keys = keys | set(currentPronunciationAllKanji.get(kanji, dict()).keys())
        dictionary_list.append(occurencesToPercentagesArg(currentPronunciationAllKanji.get(kanji, dict()), allKanji))
    return bayesTheorem(dictionary_list, keys, argument_list)

# %%
def bayesTheorem(dictionary_list, keys, argument_list): #kanji
    """Inputs: dictionary_list, keys, argument_list
Outputs: Sorted list of probabilities
This function follows the Bayesian Theorem that as defined
in the following paper https://dl.dropboxusercontent.com/u/62448029/DAG_for_email.pdf
Basic formula:
P(pronunciation|feature1, feature2, ...) =
P(pronunciation)*P(feature1|pronunciation)*P(feature2|pronunciation)* ...
Arguments is synonymous with features in this example
"""
    #print(dictionary_list)
    return_dict = dict()
    for key in keys:
        return_dict[key] = return_dict.get(key, 0) + dictionary_list[0].get(key, 0)
        for i in range(len(argument_list)):
            return_dict[key] = dictionary_list[i + 1].get(key, dict()).get(argument_list[i], 0) * return_dict[key]
    return_dict = occurencesToPercentages(return_dict)
    return sorted(return_dict.items(), key=lambda kv: kv[1], reverse=True)

# %%
getGlobalProbabilities('人', allKanji=True)  #, nextpron='び') ### Equivalent to getProbabilities
# Out:
# [('じん', 0.5853658536585366),
#  ('にん', 0.25609756097560976),
#  ('り', 0.09146341463414633),
#  ('ひと', 0.04878048780487804),
#  ('びと', 0.018292682926829267)]

# %%
def computeProbabilities(list_of_dicts):
    """Input: A single list of dictionaries
Output: A single dictionary of percentages as values
To be called from getProbabilities to convert
the list of dicts of occurences to a single
vector of probabilities."""
    print(list_of_dicts)
    number_of_dicts = len(list_of_dicts)
    if number_of_dicts == 0:
        return dict()
    elif number_of_dicts == 1:
        return occurencesToPercentages(list_of_dicts[0])
    else: ### Define what I am trying to calculate... intersection of percentage vectors??
        keys = set(list_of_dicts[0].keys()) ## copy bayes theorem here and ensure that I correctly copy the formula
        for dictionary in list_of_dicts:
            keys = keys | set(dictionary.keys()) # Get all keys
        return_dict = dict()
        for dictionary in list_of_dicts:
            dictionary = occurencesToPercentages(dictionary)
            for key in keys: ## Currently adding the occurences and then taking the percentage...
                # Bayes Theorem = P(a|b,c,...) = P(a,b,c,...)/P(b,c,...) -Proportional> P(a,b,c,...)
                # Which finally gives P(a)P(b|a)P(c|a)... [P(p)P(f1|a)P(f2|b)...]
                # https://dl.dropboxusercontent.com/u/62448029/DAG_for_email.pdf
                # times a normalizing factor (divide by the sum of all percentages)
                return_dict[key] = return_dict.get(key, 0) * dictionary.get(key, 0)
        return normalizePercentages(return_dict) ## normalize the vector

# %%
def occurencesToPercentagesArg(dict_of_occurences, argument):
    """Input: A single dictionary of occurences as values for some key
Output: A single dictionary of percentages as values for some key"""
    
    #for (_, value) in dict_of_occurences.items():
    #    sum = 0
    #    for (_, v) in value.items():
    #        sum += v
    sum_dict = dict()
    for (key1, value1) in dict_of_occurences.items():
        sum = 0
        for (key2, value2) in value1.items():
            sum = sum + value2
        sum_dict[key1] = sum_dict.get(key1, dict())
        sum_dict[key1]['sum'] = sum
        for (key2, value2) in value1.items():
            if sum_dict[key1]['sum'] != 0:
                dict_of_occurences[key1][key2] = value2 / sum_dict[key1]['sum']
    #dict_of_occurences = sorted(dict_of_occurences.items(), key=lambda kv: kv[1], reverse=True)
    return dict_of_occurences

# %%
def occurencesToPercentages(dict_of_occurences):
    """Input: A single dictionary of occurences as values for some key
Output: A single dictionary of percentages as values for some key"""
    sum = 0
    for (_, value) in dict_of_occurences.items(): sum += value
    if sum != 0:
        for (key, value) in dict_of_occurences.items():
            dict_of_occurences[key] = value / sum
    #dict_of_occurences = sorted(dict_of_occurences.items(), key=lambda kv: kv[1], reverse=True)
    return dict_of_occurences

# %%
def normalizePercentages(dict_of_occurences):
    """Input: A single dictionary of occurences as values for some key
Output: A single, ordered list of percentages as values for some key"""
    sum = 0
    for (_, value) in dict_of_occurences.items(): sum += value
    if sum != 0: ######
        for (key, value) in dict_of_occurences.items():
            dict_of_occurences[key] = value / sum
    dict_of_occurences = sorted(dict_of_occurences.items(), key=lambda kv: kv[1], reverse=True)
    return dict_of_occurences

# %%
getProbabilities('人', allKanji=False)  #, nextpron='び')
# Out:
# [('ひと', 1.0), ('びと', 0.0), ('り', 0.0), ('じん', 0.0), ('にん', 0.0)]

# %%
help(getProbabilities)
# Out:
# Help on function getProbabilities in module __main__:
#
# getProbabilities(kanji=None, prevPron=None, prevChar=None, nextPron=None, nextChar=None, allKanji=None)
#     Inputs: kanji, prevPron?, prevChar?, nextPron?, nextChar?, allKanji?
#     ? = optional
#     Output: A List of Dictionaries of occurences
#     TODO: Feed the list of dictionaries to computeProbabilities
#     This function returns all of the statistics for the current Kanji in
#     all contexts, independent of each other. This means that the nextPronunciation
#     dictionary will not be affected by the presence of an allKanji flag.
#
#     The order of the dictionaries are:
#     curPron, prevPron, prevChar, nextPron, nextChar, allKanji

# %%
#globalPreviousPronunciation
#globalPreviousCharacter
occurencesToPercentages(globalNextPronunciation['あ']) ## works with any dictionary of occurences
#globalNextCharacter['笑']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-744510037032> in <module>()
#       1 #globalPreviousPronunciation
#       2 #globalPreviousCharacter
# ----> 3 occurencesToPercentages(globalNextPronunciation['あ']) ## works with any dictionary of occurences
#       4 #globalNextCharacter['笑']
#
# NameError: name 'globalNextPronunciation' is not defined

# %%
### WHY ALLKANJI MATTERS: 微笑み hoho e mi　微笑 bi shou

# %%
### take all regular and[?] irregular words and push the pronunciations through globalPreviousPronunciation
### and globalNextPronunciation while holding small characters to the previous syllable

# %%
currentKanjiAllKanji['人']
# Out:
# {False: 2, True: 31}

# %%
currentPronunciation['人']
# Out:
# {'じん': 32, 'にん': 14, 'ひと': 8, 'びと': 1, 'り': 5}

# %%
# P(pronunciations of '人'| AllKanji = True) ->
# P(AllKanji = True | pronunciation of '人') P(pronunciations of '人') / P(AllKanji = True)
currentPronunciationAllKanji['人']
# Out:
# {'じん': {False: 0, True: 16},
#  'にん': {False: 0, True: 10},
#  'ひと': {False: 2, True: 1},
#  'びと': {False: 0, True: 1},
#  'り': {False: 0, True: 3}}

# %%
currentPronunciationNextCharacter['人']
# Out:
# {'じん': {'END': 16,
#   '体': 1,
#   '公': 1,
#   '口': 1,
#   '命': 1,
#   '工': 1,
#   '文': 1,
#   '材': 1,
#   '格': 1,
#   '民': 1,
#   '物': 1,
#   '生': 1,
#   '目': 1,
#   '科': 1,
#   '種': 1,
#   '造': 1,
#   '類': 1},
#  'にん': {'END': 10, '形': 1, '情': 1, '気': 1, '間': 1},
#  'ひと': {'END': 3, '差': 1, '柄': 1, '質': 1, '込': 1, '通': 1},
#  'びと': {'END': 1},
#  'り': {'END': 3, 'で': 1, '一': 1}}

# %%
currentPronunciation['人']
# Out:
# {'じん': 32, 'にん': 14, 'ひと': 8, 'びと': 1, 'り': 5}

# %%
currentPronunciationAllKanji['人'].get(False, dict())
# Out:
# {}

# %%
currentPronunciationNextCharacter['人']
# Out:
# {'じん': {'END': 16,
#   '体': 1,
#   '公': 1,
#   '口': 1,
#   '命': 1,
#   '工': 1,
#   '文': 1,
#   '材': 1,
#   '格': 1,
#   '民': 1,
#   '物': 1,
#   '生': 1,
#   '目': 1,
#   '科': 1,
#   '種': 1,
#   '造': 1,
#   '類': 1},
#  'にん': {'END': 10, '形': 1, '情': 1, '気': 1, '間': 1},
#  'ひと': {'END': 3, '差': 1, '柄': 1, '質': 1, '込': 1, '通': 1},
#  'びと': {'END': 1},
#  'り': {'END': 3, 'で': 1, '一': 1}}

# %%
createBayes()

# %%
currentPronunciationAllKanji.items()
# Out:
# dict_items([('我', {'が': {False: 0, True: 2}}), ('規', {'ぎ': {False: 0, True: 1}, 'き': {False: 0, True: 1}}), ('納', {'のう': {False: 0, True: 1}}), ('違', {'い': {False: 0, True: 1}}), ('景', {'けい': {False: 0, True: 3}}), ('西', {'にし': {False: 0, True: 1}, 'ざい': {False: 0, True: 1}}), ('珠', {'じゅ': {False: 0, True: 1}}), ('化', {'か': {False: 0, True: 7}}), ('婦', {'ふ': {False: 0, True: 2}}), ('野', {'の': {False: 0, True: 1}, 'や': {False: 0, True: 3}}), ('蔑', {'べつ': {False: 0, True: 1}}), ('斎', {'さい': {False: 0, True: 1}}), ('北', {'きた': {False: 0, True: 1}, 'ぼく': {False: 0, True: 1}}), ('任', {'にん': {False: 0, True: 6}}), ('簿', {'ぼ': {False: 0, True: 1}}), ('蚊', {'か': {False: 0, True: 1}}), ('細', {'さい': {False: 0, True: 1}}), ('南', {'みなみ': {False: 0, True: 1}}), ('久', {'きゅう': {False: 0, True: 1}}), ('許', {'きょ': {False: 0, True: 1}}), ('拓', {'たく': {False: 0, True: 1}}), ('志', {'し': {False: 0, True: 2}, 'こころざし': {False: 0, True: 1}}), ('励', {'れい': {False: 0, True: 2}}), ('佐', {'さ': {False: 0, True: 1}}), ('商', {'しょう': {False: 0, True: 1}}), ('内', {'うち': {False: 1, True: 1}, 'ない': {False: 0, True: 3}}), ('後', {'のち': {False: 0, True: 1}, 'ご': {False: 0, True: 8}}), ('子', {'す': {False: 0, True: 3}, 'ご': {False: 0, True: 1}, 'こ': {False: 3, True: 2}, 'じ': {False: 0, True: 3}, 'し': {False: 1, True: 10}}), ('す', {'す': {False: 182, True: 0}}), ('福', {'ふく': {False: 0, True: 2}}), ('超', {'ちょう': {False: 0, True: 1}}), ('箒', {'ほうき': {False: 0, True: 1}}), ('初', {'はつ': {False: 0, True: 1}, 'しょ': {False: 0, True: 1}}), ('林', {'りん': {False: 0, True: 2}, 'はやし': {False: 0, True: 1}}), ('隅', {'すみ': {False: 0, True: 1}}), ('週', {'しゅう': {False: 1, True: 8}}), ('領', {'りょう': {False: 0, True: 3}}), ('唱', {'しょう': {False: 0, True: 1}}), ('室', {'しつ': {False: 0, True: 8}}), ('像', {'ぞう': {False: 0, True: 5}}), ('数', {'かず': {False: 0, True: 1}, 'すう': {False: 0, True: 15}}), ('送', {'そう': {False: 0, True: 5}}), ('鬱', {'うつ': {False: 0, True: 1}}), ('巣', {'す': {False: 0, True: 1}}), ('川', {'せん': {False: 0, True: 1}, 'かわ': {False: 0, True: 1}}), ('王', {'おう': {False: 0, True: 3}}), ('算', {'さん': {False: 0, True: 5}, 'ざん': {False: 3, True: 3}}), ('鼓', {'こ': {False: 0, True: 1}}), ('姪', {'めい': {False: 0, True: 1}}), ('坂', {'さか': {False: 0, True: 1}}), ('女', {'おんな': {False: 0, True: 1}, 'じょ': {False: 0, True: 4}}), ('咳', {'せき': {False: 0, True: 1}}), ('僚', {'りょう': {False: 0, True: 2}}), ('黒', {'くろ': {False: 1, True: 1}}), ('べ', {'べ': {False: 4, True: 0}}), ('蓮', {'はす': {False: 0, True: 1}}), ('祖', {'ぞ': {False: 0, True: 1}}), ('決', {'けつ': {False: 0, True: 8}}), ('験', {'けん': {False: 0, True: 4}}), ('慮', {'りょ': {False: 0, True: 3}}), ('笛', {'ふえ': {False: 0, True: 1}}), ('菌', {'きん': {False: 0, True: 2}}), ('屋', {'や': {False: 0, True: 4}, 'おく': {False: 0, True: 1}}), ('現', {'げん': {False: 0, True: 3}}), ('伜', {'せがれ': {False: 0, True: 1}}), ('鹿', {'か': {False: 0, True: 1}}), ('抱', {'ぼう': {False: 0, True: 1}, 'ほう': {False: 0, True: 1}}), ('象', {'ぞう': {False: 0, True: 1}, 'しょう': {False: 0, True: 5}}), ('台', {'たい': {False: 0, True: 1}, 'だい': {False: 0, True: 4}}), ('栄', {'えい': {False: 0, True: 1}}), ('芸', {'げい': {False: 0, True: 5}}), ('静', {'せい': {False: 0, True: 2}}), ('湯', {'ゆ': {False: 1, True: 1}}), ('詩', {'し': {False: 0, True: 1}}), ('肘', {'ひじ': {False: 0, True: 1}}), ('鉄', {'てつ': {False: 0, True: 4}}), ('痛', {'つう': {False: 0, True: 2}}), ('素', {'そ': {False: 0, True: 6}}), ('工', {'こう': {False: 0, True: 2}, 'く': {False: 0, True: 2}}), ('父', {'ふ': {False: 0, True: 1}}), ('筆', {'ふで': {False: 0, True: 1}, 'ひつ': {False: 0, True: 2}, 'ぴつ': {False: 0, True: 1}}), ('低', {'てい': {False: 0, True: 1}}), ('適', {'てき': {False: 0, True: 1}}), ('搬', {'ぱん': {False: 0, True: 1}}), ('院', {'いん': {False: 0, True: 7}}), ('筋', {'すじ': {False: 0, True: 3}}), ('原', {'げん': {False: 0, True: 1}, 'はら': {False: 0, True: 1}}), ('期', {'き': {False: 0, True: 8}}), ('風', {'ふう': {False: 0, True: 5}, 'かぜ': {False: 0, True: 1}}), ('料', {'りょう': {False: 0, True: 14}}), ('歴', {'れき': {False: 0, True: 3}}), ('分', {'ぶ': {False: ...

# %%
for (k,v) in currentPronunciationAllKanji['人'].items():
    print(k, v)
# Out:
# り {False: 0.0, True: 0.5, 'sum': 1.0}
# じん {False: 0.0, True: 0.5, 'sum': 1.0}
# にん {False: 0.0, True: 0.5, 'sum': 1.0}
# びと {False: 0.0, True: 0.5, 'sum': 1.0}
# ひと {False: 0.3333333333333333, True: 0.16666666666666666, 'sum': 1.0}
